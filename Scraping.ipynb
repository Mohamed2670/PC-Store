# %%
import psycopg2
from psycopg2 import sql
from concurrent.futures import ThreadPoolExecutor
import requests
from bs4 import BeautifulSoup
import re

conn = psycopg2.connect(
    dbname="PcBuild",
    user="postgres",
    password="123",
    host="localhost",
    port="5432"
)
cursor = conn.cursor()
def upsert_store(cursor, store_name):
    cursor.execute('SELECT "Id" FROM "Stores" WHERE "Name" = %s', (store_name,))
    store_id = cursor.fetchone()
    if store_id:
        return store_id[0]
    insert_query = """
        INSERT INTO "Stores" ("Name")
        VALUES (%s)
        RETURNING "Id";
    """
    cursor.execute(insert_query, (store_name,))
    store_id = cursor.fetchone()
    
    # Return the ID of the newly inserted store
    return store_id[0] if store_id else None
def upsert_category(category_name):
    cursor.execute('SELECT "Id" FROM "Categories" WHERE "Name" = %s', (category_name,))
    category_id = cursor.fetchone()
    if category_id:
        return category_id[0]
    insert_query = """
        INSERT INTO "Categories" ("Name")
        VALUES (%s)
        RETURNING "Id";
    """
    cursor.execute(insert_query, (category_name,))
    category_id = cursor.fetchone()
    
    # Return the ID of the newly inserted store
    return category_id[0] if category_id else None

def fetch_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return BeautifulSoup(response.content, 'html.parser')
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

def upsert_product(store_name, product_data):
    try:
        query = """
            SELECT "Id" FROM "Stores" WHERE "Name" = %s;
        """
        cursor.execute(query, (store_name,))
        store_id = cursor.fetchone()
        
        if not store_id:
            print(f"Error: Store {store_name} not found.")
            return  
        store_id = store_id[0]
        cursor.execute(
            """
            SELECT "Id", "CurrentPrice" FROM "Products"
            WHERE "ProductUrl" = %s AND "StoreId" = %s;
            """,
            (product_data['link'], store_id)
        )
        product = cursor.fetchone()
        query = """
            SELECT "Id" FROM "Categories" WHERE "Name" = %s;
        """
        cursor.execute(query,(product_data['category'],))
        category_id = cursor.fetchone()
        if not category_id:
            print(f"Error: Category {product_data['category']} not found.")
            return
        category_id = category_id[0]
        

        if product:
            product_id, current_price = product
            if abs(float(current_price) - float(product_data['price'])) > 0.01: 
                cursor.execute(
                    """
                    UPDATE "Products"
                    SET "CurrentPrice" = %s
                    WHERE "Id" = %s;
                    """,
                    (product_data['price'], product_id)
                )
                cursor.execute(
                    """
                    INSERT INTO "Prices" ("Value", "ProductId", "Date")
                    VALUES (%s, %s, NOW());
                    """,
                    (product_data['price'], product_id)
                )
        else:
            print(f"Inserting product: {product_data['title']} - {product_data['price']}")

            cursor.execute(
                """
                INSERT INTO "Products" ("Name", "CurrentPrice", "StoreId", "ImageUrl", "ProductUrl","CategoryId")
                VALUES (%s, %s, %s, %s, %s,%s)
                RETURNING "Id";
                """,
                (
                    product_data['title'],
                    product_data['price'],
                    store_id,
                    product_data['image_url'],
                    product_data['link'],
                    category_id
                )
            )
            product_id = cursor.fetchone()[0]
            cursor.execute(
                """
                INSERT INTO "Prices" ("Value", "ProductId", "Date")
                VALUES (%s, %s, NOW());
                """,
                (product_data['price'], product_id)
            )
        conn.commit()
    except Exception as e:
        print(f"Error upserting product: {e}")
        conn.rollback()


# Function to scrape Sigma website
def scrape_sigma():
    base_url = "https://www.sigma-computer.com"
    main_page_url = f"{base_url}/home"
    main_soup = fetch_page(main_page_url)
    if not main_soup:
        return

    category_links = main_soup.select('div.sub-menu a.main-menu')
    for category_link in category_links:
        category_name = category_link.text.strip().lower()
        upsert_category(category_name)

        category_url = base_url + "/" + category_link['href']
        
        current_page_url = category_url + "&page=1"

        while True:
            soup = fetch_page(current_page_url)
            if not soup:
                break

            containers = soup.find_all('div', class_='product-item-container')
            for container in containers:
                anchor = container.find('a', href=True, title=True)
                title = anchor['title'] if anchor else "No title found"
                link = base_url + "/" + anchor['href'] if anchor else "No link found"
                price_span = container.find('span', class_='price-new')
                image_tag = container.find('img')
                image_url = base_url + "/" + image_tag['src'] if image_tag else "No image found"
                price = re.sub(r'[^\d.]', '', price_span.text.strip()) if price_span else None
                store_name = "Sigma Computer"

                if price:
                     add_to_cart_button = container.find('button', class_='addToCart')
                     if add_to_cart_button:
                        span_text = add_to_cart_button.find('span').text.strip().lower()
                        if "out of stock" not in span_text:
                            product_data = {
                                "title": title,
                                "price": price,
                                "link": link,
                                "image_url": image_url,
                                "category": category_name
                            }
                            upsert_product(store_name, product_data)
                        else :
                            print(title)

            pagination = soup.find('ul', class_='pagination')
            next_page = pagination.find('a', rel='next') if pagination else None
            if next_page:
                current_page_url = next_page['href']
            else:
                break

def scrape_elnour():
    base_url = "https://elnour-tech.com/en/"
    main_soup = fetch_page(base_url)
    if not main_soup:
        return

    category_links = main_soup.select('.menu-item.menu-item-type-taxonomy.menu-item-object-product_cat')
    for category_link in category_links:
        category_name = category_link.text.strip().lower()
        upsert_category(category_name)
        category_url = category_link.select_one('a').get('href') if category_link.select_one('a') else None
        if not category_url:
            continue

        page_num = 1
        while True:
            page_url = f"{category_url}/page/{page_num}"
            soup = fetch_page(page_url)
            if not soup:
                break

            products = soup.select('.wd-product.product-grid-item')
            for product in products:
                add_to_cart_btn = product.select_one('.add_to_cart_button')
                if add_to_cart_btn:
                    title = product.select_one('.wd-entities-title').text.strip() if product.select_one('.wd-entities-title') else None
                    price_text = product.select_one('bdi').text.strip() if product.select_one('bdi') else None
                    price = re.sub(r'[^\d.]', '', price_text) if price_text else None
                    link = product.select_one('.wd-entities-title a').get('href') if product.select_one('.wd-entities-title a') else None
                    img_url = product.select_one('.product-wrapper img').get('src') if product.select_one('.product-wrapper img') else None
                    store_name = "Elnour Tech"

                    if price:
                        product_data = {
                            "title": title,
                            "price": price,
                            "link": link,
                            "image_url": img_url,
                            "category": category_name
                        }
                        upsert_product(store_name, product_data)

            next_page = soup.select_one('a.page-numbers.next')
            if next_page:
                page_num += 1
            else:
                break
def scrape_and_store(store_names):
    with conn:
        with conn.cursor() as cursor:
            print("Upserting stores...")
            store_ids = {name: upsert_store(cursor, name) for name in store_names}
            conn.commit()

def main():
    websites = {
        "sigma": scrape_sigma,
        #"elnour": scrape_elnour
    }
    stores = ["Sigma Computer", "Elnour Tech"]
    scrape_and_store(stores)
    with ThreadPoolExecutor() as executor:
        future_to_website = {executor.submit(scraper): name for name, scraper in websites.items()}
        for future in future_to_website:
            website = future_to_website[future]
            try:
                future.result()
            except Exception as e:
                print(f"Error scraping {website}: {e}")

if __name__ == "__main__":
    main()

conn.close()
# Out:
# Upserting stores...
# MSI MAG X870 Tomahawk WiFi Gaming Motherboard  AMD Ryzen 9000 8000 7000 Series Processors  AM5  DDR5  PCIe 5.0  M.2 Gen5  SATA 6Gb s  USB 40Gbps  HDMI DP  Wi-Fi 7  Bluetooth 5.4  5Gbps LAN  ATX
# MSI PRO X870-P WIFI Motherboard  ATX - Supports AMD Ryzen 9000   8000   7000 Processors  AM5 - 60A SPS VRM  DDR5 Memory Boost 8200 MT s  OC   PCIe 5.0 x16   4.0 x16  M.2 Gen5  Wi-Fi 7  5G LAN
# ASUS ProArt X870E-CREATOR WiFi AMD AM5 X870E ATX Motherboard PCIe   5.0 x16 Slots with Full Support for Next-gen GPUs  16 2 2 Power Stages  DDR5  Dual USB4    10 Gb   2.5 Gb LAN  WiFi 7  Four M.2 Slots
# Error fetching https://www.sigma-computer.com/subcategory?id=1&cname=Desktop&id2=1&scname=Motherboard&page=2: 524 Server Error:  for url: https://www.sigma-computer.com/subcategory?id=1&cname=Desktop&id2=1&scname=Motherboard&page=2
# Antec IGPU VGA Bracket Holder - Prism Black
# ZOTAC Gaming GeForce RTX 4070 Ti Super Solid DLSS 3 16GB GDDR6X 256-bit 21 Gbps PCIE 4.0
# ZOTAC Gaming GeForce RTX 4070 Super Trinity Black Edion DLSS 3 12GB GDDR6X 192-bit 21 Gbps PCIE 4.0
# ZOTAC Gaming GeForce RTX 4060 Ti 16GB AMP DLSS 3 16GB GDDR6 128-bit 18 Gbps PCIE 4.0
# MSI GeForce RTX 4060 Ti Ventus 3X 8G OC  8GB GDDR6 PCI Express 4.0 2580MHz 18000MHz
# MSI Gaming RTX 4070 Super 12G Ventus 3X OC Graphics Card  NVIDIA RTX 4070 Super  192-Bit  Extreme Clock  2520 MHz  12GB GDRR6X 21 Gbps  HDMI DP  Ada Lovelace Architecture
# MSI GeForce RTX 4060 Ti Ventus 2X Black 16G OC Graphics Card - RTX 4060 Ti GPU  16GB GDDR6  18Gbps 128-bit   PCIe 4.0-2 x TORX Fan 4.0 - HDMI 2.1a  DisplayPort 1.4a
# ASUS TUF Gaming NVIDIA GeForce RTX    4070 Ti Super Gaming Graphics Card  PCIe 4.0  16GB GDDR6X  HDMI 2.1a  DisplayPort 1.4a
# GIGABYTE GeForce RTX 4070 Ti Super AERO OC 16G Graphics Card  3X WINDFORCE Fans  16GB 256-bit GDDR6X WHITE
# ASUS ROG Strix GeForce RTX 4080 SUPER 16GB GDDR6X White OC Edition
# Gigabyte GeForce RTX 4060 EAGLE OC ICE 8G
# ASUS ROG Strix GeForce RTX 4070 Ti SUPER 16GB GDDR6X OC Edition
# ASUS ROG Strix GeForce RTX 4080 SUPER 16GB GDDR6X OC Edition
# ASUS TUF Gaming GeForce RTX 4080 SUPER 16GB GDDR6X OC Edition
# ASUS TUF Gaming GeForce RTX 4070 Super OC Edition 12GB
# GeForce RTX    4070 SUPER WINDFORCE OC 12G GDDR6
# ZOTAC GeForce RTX 3050 6GB GDDR6 Solo
# GALAX GeForce RTX    4060 Ti 8GB EX 1-Click OC
# MSI GeForce RTX    4060 VENTUS 2X BLACK 8G OC
# ASUS Dual GeForce RTX    4070 SUPER OC Edition 12GB GDDR6X  PCIe 4.0  12GB GDDR6X  DLSS 3  HDMI 2.1a  DisplayPort 1.4a  2.5-slot design  Axial-tech fan design  0dB technology
# Gigabyte GeForce RTX    3050 EAGLE OC 6G.
# Gigabyte GeForce RTX    4080 SUPER GAMING OC 16G.
# Gigabyte GeForce RTX    4080 SUPER AERO OC 16G
# INNO3D-GEFORCE RTX 2060 SUPER TWIN X2 OC
#  Gigabyte-RTX4090 WINDFORCE OC 24GB DDR6X  TRIPLE FAN
# Gigabyte GeForce RTX    4060 WINDFORCE OC 8G DDR6  DUAL FAN
# AORUS GeForce RTX    4080 SUPER MASTER 16G
# Gigabyte-RTX4060TI AERO OC 8GB DDR6  Triple Fan -White
#  ASUS Dual GeForce RTX    4070 SUPER 12GB GDDR6X with two powerful Axial-tech fans and a 2.56-slot design for broad compatibility
#  ZOTAC GAMING GeForce GTX 1650 AMP Core GDDR6 ZT-T16520J-10L
# GALAX GeForce GT 730 4GB DDR3 4GB DDR3 128-Bit HDMI - DVI - VGA
# GALAX GeForce RTX    4060 1-Click OC 2X 8GB GDDR6 128-bit DP 3 HDMI 2.1 DLSS 3
# GIGABYTE RTX4070TI AORUS ELITE 12GB DDR6X  Triple Fan  GV-N407TAORUS E-12GD
# INNO3D RTX 4070 TWIN X2 OC  2505MHz 21Gbps  12GB GDDR6X 192-bit DP DP DP HDMI VA52N
# Inserting product: INNO3D RTX 4060 Ti 8GB TWIN X2  2535MHz 18Gbps 8GB GDDR6 128-bit DP DP DP HDMI VA53N AD1066711  - 20499
# Inserting product: INNO3D RTX 3070Ti  X3  1770Mhz 19Gbps  8GB GDDR6X 256-bit DP DP DP HDMI - 21499
# INNO3D- RTX 2060 TWIN X2  1680Mhz  14.0Gbps 6GB GDDR6  192-bit DPx3 HDMI VA15L
# Inserting product: Colorful GeForce GT730K 4GD3 V2-V - 2749
# Inserting product: Colorful GeForce GT730K 4GD3-V - 2749
# COLORFUL iGame GeForce RTX 3080 Ultra W OC 12G LHR-V
# GIGABAYT NVIDIA GeForce RTX    3060 12GB GDDR6
#  GIGABAYT NVIDIA-GV-N3060EAGLE OC-12GD  rev. 2.0
# Inserting product: GIGABYTE GeForce RTX 4060 Gaming OC 8G Graphics Card  3X WINDFORCE Fans  8GB 128-bit GDDR6  GV-N4060GAMING OC-8GD - 17200
# Gigabyte AORUS GeForce RTX 4070 MASTER 12GB Graphics Card - 12GB DDRX6 21Gbps 192bit Triple Fan
# Inserting product: PNY GeForce RTX 4060 Ti 16GB DFXPB1 VERTO Dual Fan - 24999
# ZOTAC GAMING GeForce GTX 1650 AMP Core 4GB GDDR6
# MSI Gaming GeForce RTX 3080 10GB GDRR6X 320-Bit  Nvlink Tri-Frozr 2 Ampere Architecture OC  RTX 3080 GAMING X TRIO 10G
# MSI Gaming GeForce RTX 3070 GAMING X TRIO 8GB GDRR6 RGB OC 256-Bit Tri-Frozr 2 TORX Fan 4.0 Ampere Architecture
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 OC 10G Edition Graphics Card
# ASUS TUF Gaming NVIDIA GeForce RTX 3070 OC Edition Graphics Card
# ASUS TUF Gaming X3 Radeon RX 5700 OC edition 8GB GDDR6
#  MSI GeForce GTX 1650 SUPER GAMING X 4GB GDDR6
# MSI Gaming GeForce GT 710 2GB GDRR3 64-bit Single Fan Low Profile Graphics Card  GT 710 2GD3 LP
# ASUS Dual EVO Gaming GeForce RTX 2060 Advanced edition 6GB GDDR6
# Asus DUAL GTX1660 SUPER MINI OC  6GB DDR6  DVI  HDMI  DP  1860MHz Clock
# ASUS TUF Gaming X3 GeForce GTX 1660 SUPER OC edition 6GB GDDR6
# ASUS Dual GeForce RTX 2060 OC edition EVO 6GB GDDR6
# PNY GeForce GTX 1660 Ti XLR8 Gaming Overclocked Dual Fan
# ZOTAC GAMING GeForce RTX 3080 Trinity OC  10GB GDDR6X ZT-A30800J-10PLHR
# ASUS ROG Strix GeForce RTX 3080 DirectX 12 ROG STRIX RTX3080 O10G GAMING
# ASUS TUF GAMING GeForce RTX 3080 GDDR6X 10GB buffed-up design with chart-topping thermal performance
# MSI GTX 1660 SUPER VENTUS XS OC 6GB GDRR6 Support DirectX 12 Dual Fan VR Ready
# SAPPHIRE PULSE RX 5500 XT 4GB GDDR6 OC
# Sapphire Radeon Pulse RX 5500 XT 8GB GDDR6 HDMI  Triple DP OC
# Sapphire  Radeon PULSE RX 5600 XT  6GB GDDR6 OC
# Sapphire  Radeon PULSE RX 5700 Xt 8GB OC GDDR6
# SAPPHIRE NITRO  RX 5700 XT OC  8G GDDR6
# GIGABYTE  GeForce RTX 2060 SUPER    WINDFORCE OC 8G
# GIGABYTE GeForce GTX 1650 D6 EAGLE OC 4G
# AORUS GeForce RTX    2080 Ti XTREME 11GB GDDR6
# ASUS Phoenix GeForceR GTX 1650 SUPER OC Edition 4GB GDDR6
# MSI Radeon RX 5600 XT GAMING X 6GB GDDR6
# MSI Gaming Radeon RX 5500 XT MECH OC  8GB GDDR6
# GIGABYTE Radeon RX 5600 XT GAMING OC 6GB GDDR6
# MSI RADEON RX 5500 XT MECH 4GB OC GDDR6
# AsRock Radeon RX 5600 XT Phantom Gaming D2 6G OC
# AsRock Radeon RX 5600 XT Phantom Gaming D3 6G OC
# AsRock Radeon RX 5700 Phantom Gaming D 8G OC
# ASRock Radeon RX 5700 XT Taichi X 8G OC  8GB
# ZOTAC GAMING GeForce RTX 2060H  6GB of GDDR6
# ZOTAC GAMING GeForce RTX 2060 K 6GB  GDDR6
# ZOTAC GAMING GeForce GTX 1650 SUPER Twin Fan GDDR6
# ASUS DUAL GEFORCE GTX1660 SUPER-A6G-EVO ADVANCED EDITION
# ASUS ROG Strix GeForce GTX 1660 Super Advanced 6GB Edition GDDR6
# Gigabyte AORUS GeForce RTX 2070 Super 8G GDDR6
# GIGABYTE AORUS GeForce RTX 2080 Super 8GB GDDR6
# AORUS Radeon    RX 5700 XT RGB Fusion 2.0 8G GDDR6
# GIGABYTE Radeon    RX 5600 XT WINDFORCE OC 6GB GDDR6
# ASUS STRIX EVO RX 5500XT RGB O8G RGB lighting on the shroud
# PNY GEFORCE RTX 2060 SUPER 8GB XLR8 GAMING OVERCLOCKED
# ASUS Dual GeForce   RTX 2080 SUPER    EVO V2 OC edition 8GB GDDR6
# Gigabyte GeForce GT 710 2GB Graphic Card
# PNY GeForce RTX 2070 8GB XLR8 Gaming Overclocked Edition
# PNY GeForce   GTX 1660 SUPER    Dual Fan 6GB GDDR6
# ASUS TUF 3-RX5600XT-O6G-EVO-GAMING GDDR6 6GB
# GIGABYTE GT 1030 Low Profile 2GB GDDR5
# GIGABYTE GeForce   RTX 2070 SUPER    GAMING OC 8G
# GIGABYTE Radeon    RX 5500 XT OC 4G
# GIGABYTE     RX 5500 XT GAMING OC 8G
# GIGABYTE GeForce   GTX 1650 SUPER OC 4G
# ASUS ROG Strix AMD Radeon RX 5700 3 fan 8G GDDR6
# ASUS Dual Evo rx5700 dual fan logo with heat pipe
# ASUS DUAL GTX 1660 SUPER  EVO DUAL FAN RGB LOGO OC - 6GB GDDR6
# Asus TUF Gaming GeForce GTX 1660 Super Overclocked 6GB Edition HDMI DP DVI Gaming Graphics Card
# ASUS GeForce RTX 2060 SUPER Overclocked 8G EVO GDDR6 Dual-Fan Edition VR Ready HDMI DisplayPort DVI Graphics Card
#  ASUS ROG Strix AMD Radeon RX 5700XT Overclocked 8G GDDR6 HDMI DisplayPort Gaming Graphics Card
# ASUS DUAL AMD Radeon RX 5500XT Overclocked O8G GDDR6
# Asrock Radeon RX 5500 XT Challenger D 4G OC
# Asrock Radeon RX 5700 XT Phantom Gaming D 8G OC
# Asrock Radeon RX 5700 XT Taichi X 8G OC
# PNY GeForce RTX    2080 Ti 11GB XLR8 Gaming Overclocked Edition
# Asus  ROG Strix GeForce   GTX 1650 SUPER    OC Edition 4GB GDDR6
# PNY GeForce   GTX 1650 XLR8
# ASROCK Radeon RX 5500 XT Challenger D 8G OC
# ASUS ROG Strix GeForce   RTX 2070 SUPER    OC edition 8GB GDDR6
# MSI Radeon RX 5500 XT GAMING X 8GB GDDR6
# ASUS ROG Strix AMD Radeon RX 5600 XT OC Edition PCIe 4.0  6GB  GDDR6
# MSI GeForce RTX 2080 SUPER    VENTUS XS OC 8GB GDDR6
# MSI RTX 2070 Super Gaming X 8GB GDRR6
# MSI GTX 1650 Super Ventus XS OC
# MSI GeForce GTX 1650 Super AERO ITX OC
# GIGABYTE Radeon    RX 5500 XT  OC 8G
# Gigabyte Radeon    RX 5500 XT GAMING OC 4G
# Patriot Viper Xtreme 5 48GB 2 x 24GB 288-Pin PC RAM DDR5 8000MHz CL38 Desktop Memory RGB Model PVXR548G80C38K
# Patriot Viper Xtreme 5 32GB  2 x 16GB  288-Pin PC RAM DDR5 8000MHz CL38  PC5 64000  Desktop Memory RGB Model PVXR532G80C38K
# LEXAR 8G DDR4 2666Mhz UDIMM
# LEXAR LD5U16G60C34LA-RGD 32GB 16 2 Kit DDR5-6000Mhz
# Lexar 16GB  2x8GB  ARES RGB DDR4 RAM 3600MT s CL18 1.35V Desktop Memory  Compatible with Intel XMP 2.0 and AMD Ryzen  Black  LD4BU008G-R3600GDLA
# Lexar Thor DDR4 RAM 32GB Kit  16GB x 2  3600 MHz  DRAM 288-Pin UDIMM Desktop Memory  XMP 2.0 High-Performance Computer Memory  CL18-22-22-42  1.35V  LD4BU016G-R3600GDWG
# Lexar LD4BU008G Hades RGB 16GB  2x8GB  DDR4 RAM 3600MHz CL19 Desktop Memory
# Patriot Viper Steel DDR4 16GB 3600MHz CL18
# Patriot Viper Steel RGB DDR4 RAM 16GB  1X16GB  3200MHz CL18 UDIMM Desktop Gaming Memory Module - PVSR416G320C8
# KLEVV DDR4 32GB  1x32GB  3200MHz CL22 1.2V UDIMM Desktop Ram Memory SK Hynix Chip  KD4BGUA80-32N220A
# CORSAIR 8G VENGEANCE LPX 8GB  1 x 8GB  D-CMK8GX4M1Z3200C16
# Kingston FURY Beast DDR5 8GB 6000MT s DDR5 CL40 DIMM Desktop Gaming Memory Single Module - KF560C40B 8
# CORSAIR VENGEANCE   RGB 32GB  2x16GB  DDR5 DRAM 5200MT s CL40 Memory Kit     Black
# KLEVV Bolt V DDR5 32GB  2x16GB  6000MHz CL30 A-DIE 1.35V Gaming Desktop Ram Memory SK Hynix Chip XMP 3.0   AMD Expo Ready
# Team T-Force Vulcan Z 16GB 3200 MHz CL16 1.35V
# Teamgroup T-Force Vulcan Z 8GB 3200MHz DDR4 Desktop Memory
# HP V8 RGB 16GB DDR4 3600MHz CL18 Desktop Memory.
# CORSAIR-32G-VENGEANCE DDR5 RAM 32GB  2x16GB  5600MHz CL40 AMD EXPO iCUE Compatible Computer Memory
# CORSAIR 32G-VENGEANCE   32GB  2x16GB  DDR5 DRAM 5200MT  Memory Kit     BLACK
# CORSAIR-48G-Dominator Titanium RGB DDR5 RAM 48GB  2x24GB  DDR5 7000MHz CL36 Intel XMP iCUE Compatible Computer Memory
# CORSAIR-32G-Dominator Titanium RGB DDR5 RAM 32GB  2x16GB  DDR5 6000MHz CL30 Intel XMP iCUE Compatible Computer Memory
# CORSAIR RAM 16G-Vengeance LPX-3200Hz-CL16-18-18-36  CMK16GX4M1E3200C16
# Corsair VENGEANCE LPX DDR4 RAM 32GB  2x16GB  3200MHz CL16 Intel XMP 2.0 Computer Memory - Black  CMK32GX4M2E3200C16
# Corsair 64GB  2X32GB  CMT64GX5M2B6600C32 Dominator Platinum RGB 6600Hz DDR5
# Corsair 32GB  2x16GB  CMH32GX5M2E6000C36 Vengeance RGB CL36 6000MHz DDR5
# Inserting product:  CORSAIR 16G VENGEANCE LPX- 2x8GB -3200Hz-CL16-20-20-38 CMK16GX4M2E3200C16 - 2349
# Inserting product:  TEAMGROUP 32G T-FORCE DELTA RGB BK  UD-D5 16GBx2 5600 DDR5 DESKTOP MEMORY - 7799
# TEAMGROUP 16G T-FORCE DELTA RGB WT UD-D5 16GB 5600 DDR5 DESKTOP MEMORY
# TEAMGROUP 16G T-FORCE DELTA RGB BK UD-D5 16GB 5600 DDR5 DESKTOP MEMORY
# Lexar ARES 16GB DDR5 P4800 Desktop RAM
# HP V8 RGB RAM 8GB 1 x 8GB DDR4 3600mHz U-dimm CL18
# Inserting product: CORSAIR DOMINATOR   PLATINUM RGB 32GB  2x16GB  DDR5 DRAM 6400MHz C32 Memory Kit     Black - 8999
# Inserting product: CORSAIR VENGEANCE   32GB  2x16GB  DDR5 DRAM 5600MT s C36 AMD EXPO Memory Kit. - 6799
# Inserting product: CORSAIR VENGEANCE   64GB  2x32GB  DDR5 DRAM 5600MHz C36 Memory Kit     Black. - 12222
# CORSAIR VENGEANCE   RGB 32GB  2x16GB  DDR5 DRAM 5600MHz C36 Memory Kit     White
# CORSAIR VENGEANCE   RGB 32GB  2x16GB  DDR5 DRAM 5600MHz C36 Memory Kit     Black
# CORSAIR VENGEANCE   RGB RS 32GB  2 x 16GB  DDR4 DRAM 3600MHz C18 Memory Kit.
# Inserting product: CORSAIR VENGEANCE   RGB RS 8GB  1 x 8GB  DDR4 DRAM 3600MHz C18 Memory - 1449
# CORSAIR-VENGEANCE   RGB RS 64GB  2 x 32GB  DDR4 DRAM 3200MHz C16 Memory Kit
# CORSAIR VENGEANCE   RGB RS 32GB  2 x 16GB  DDR4 DRAM 3200MHz C16 Memory Kit
# CORSAIR VENGEANCE   RGB RS 64GB  2 x 32GB  DDR4 DRAM 3600MHz C18 Memory Kit
# CORSAIR VENGEANCE   LPX 32GB  2x16GB  DDR5 DRAM 5200MHz C40 Memory Kit     Black
# Inserting product: CORSAIR VENGEANCE   RGB RS 16GB  1 x 16GB  DDR4 DRAM 3200MHz C16  CMG16GX4M1E3200C16 - 2399
# Inserting product: CORSAIR-16G-Vengeance RGB RS  1 16  3600Hz CL18-22-22-42  CMG16GX4M1D3600C18 -INTEL AMD - 2499
# Inserting product: Crucial RAM 8G DDR5 P4800 UDIMM CT8G48C40U5 PC - 1349
# RAM TEAM 16G DDR5 P4800 PC ELITE DESKTOP MEMORY
# Acer SD100 8GB RAM 3200 MHz DDR4 SO DIMM Laptop Memory
# Acer UD100 8GB Single RAM 3200 MHz DDR4 CL22 1.2V Desktop Computer Memory BL.9BWWA.222
# TEAM GROUP T-FORCE DELTA 32GB  RGB DDR4 3200MHZ DESKTOP MEMORY
# TEAM 32G VULCAN TUF Gaming Alliance 2X16 DDR4 PC3200 DESKTOP MEMORY YELLOW
# Kingston FURY Beast KF556C40BB-16 DDR5 Memory 16GB 5600Mhz CL40
# HP V10 RGB 32GB DDR4 3600MHz U-DIMM CL14 2x16G
# HP V10 RGB 16GB DDR4 3600MHz U-DIMM CL14 2x8
# A-DATA 8Gb Ddr4 Modules for Notebooks 3200Mhz Memory
# PNY 16GB  2x8GB  XLR8 RGB DDR4 3200MHz Desktop Memory      MD16GK2D4320016XRGB
# PNY 8GB XLR8 Gaming DDR4 3200MHz  MD8GD4320016LP
# AORUS Memory DDR5 32GB  2x16GB  5200MHz ARS32G52D5
# Acer HT100 DDR4 UDIMM 16GB 3600MHZ SILVER
# Acer HT100 DDR4 UDIMM 16GB 3200MHZ CL16 SILVER
# Acer HT100 DDR4 UDIMM 8GB 3200 CL16 SILVER
# TEAM GROUP T-FORCE DELTA TUF GAMING ALLIANCE RGB DDR4 8GB 3200MHZ CL16 Desktop Gaming Memory
# TEAMGROUP Memory module Team DDR4 16Gb KIT 2x8Gb  3200MHz Vulcan TUF Gaming Black Yellow
# TEAMGROUP T-Force Delta RGB DDR4 32GB  2x16GB  3200MHz  PC4-25600  CL16 Desktop Memory White
# Team group T-Force Delta TUF Gaming Alliance RGB 32GB  2 x 16GB  DDR4 3600 Desktop Memory
# Team Group T-Force Delta TUF Gaming Alliance RGB 32G DDR5  2x16  P5200  White
# Team Group T-FORCE-DELTA-32G-2X16-DDR5-5200HZ-TUF-Alliance-BLACK-RGB-CL40-40-40-76
# Crucial 32GB DDR5-4800mHZ UDIMM Desktop
# Team T-Force Delta RGB DDR4 16GB 3200MHz CL16  Black
# Team T-Force Delta RGB DDR4 16GB 3200MHz CL16  White
# Team T-Force Delta RGB DDR4 8GB 3200MHz CL16  Black
# Team T-Force Delta RGB DDR4 8GB 3200MHz CL16  White
# Team group T-Force Delta RGB 32GB  2 x 16GB  DDR4 3200  PC4 25600  Desktop Memory
#  Patriot Viper Steel DDR4 32GB  1 x 32GB  3200MHz - RGB -CL18
# PATRIOT VIPER VENOM rgb DDR5 RAM 32GB  2X16GB  5600MHz KIT cl36
# Patriot VIPER VENOM DDR5 RAM 16GB  2X8GB  5200MHz Kit cl36
# XPG SPECTRIX D50 32GB 2X16 3600Mhz DDR4 RGB Memory Module GREY
# XPG SPECTRIX D50 32GB  2X16  3600Mhz DDR4 RGB Memory Module WHITE
# XPG LANCER RGB 32GB DDR5 5200MHz  2x16GB   Desktop Memory RAM Kit
# XPG Caster RGB 32GB DDR5 6400MHz  2x16GB   Desktop Memory RAM Kit
# XPG Caster RGB 32GB DDR5 6000MHz  2x16GB   Desktop Memory RAM Kit
# Crucial 32GB DDR4-3200Mhz SODIMM Desktop
# Crucial 16GB DDR5-4800mHZ UDIMM V1.1 CL40 Desktop
# Samsung 8GB DDR5-4800MHz UDIMM Desktop RAM
# Inserting product: Samsung 16GB DDR5-4800MHz UDIMM CL40 Desktop RAM - 2449
# Kingston Fury Beast RGB KF432C16BB 32 32GB DDR4 3200MT s Non ECC DIMM
# Kingston Fury Beast KF432C16BB 32 32GB DDR4 3200MT s Non ECC DIMM
# Kingston FURY Beast 16GB DDR5 5200 MHz CL40 - KF552C40BB-16
# PNY 16GB XLR8 Gaming EPIC-X RGB DDR4 3200MHz Desktop Memory
# Crucial Ballistix 16GB Kit  2 x 8GB  DDR4-3600 Desktop Gaming Memory  Red
# Crucial Ballistix RGB 32GB Kit  2 x 16GB  DDR4-3200 Desktop Gaming Memory  White
# Crucial Ballistix 32GB Kit  2 x 16GB  DDR4-3200 Desktop Gaming Memory  Red
# TEAM XTREEM 64GB  2x32GB  3600mhz  ARGB DDR4 DESKTOP MEMORY - BLACK
# TEAM XTREEM 64GB  2x32GB  3600mhz  ARGB WHITE EDITION DDR4 DESKTOP MEMORY
# TEAM-16G-T-FORCE-DELTA-16G-2X8-4000HZ-XTREEM-BLUE-ARGB-CL18-22-22-42
# TEAM-16G-T-FORCE-DELTA-16G-2X8-4000HZ-XTREEM-WHITE-ARGB-CL18-22-22-42
# Team DELTA TUF Gaming 32GB  2x16GB  3200MHz Alliance RGB DDR4 DESKTOP MEMORY
# Inserting product: TEAMGROUP T-Force Delta TUF Gaming Alliance RGB DDR4 16GB  2x8GB  3200MHz CL16 Desktop Gaming Memory - 2599
# PNY XLR8 32GB DDR4 3200MHz Low Profile Desktop Memory  2x16GB
# Patriot Viper 4 Blackout Series DDR4 16GB 3200MHz Kit  2 x 8GB
# DATO Ram 16G KIT  2 8  P3200 RGB - BLACK  WHITE
# Samsung 16GB DDR4 2666Mhz Memory RAM DIMM-tray-pc
# Crucial Ballistix RGB 8GB DDR4-3200 Desktop Gaming Memory - Black
# Crucial Ballistix 8GB DDR4-3200 Desktop Gaming Memory  Black
# HIKVISION RAM 16GB DDR4 3200 PC
# TEAM DELTA RGB 32G-2X16 3200Hz DDR4 DESKTOP MEMORY-WHITE
# TEAM DELTA RGB 16G-2X8 3200Hz DDR4 DESKTOP MEMORY-WHITE
# Inserting product: Lexar 32GB DDR4-3200UDIMM Desktop Memory - 2950
# TEAM GROUP Elite 16 Gb Ddr4 3200 Mhz Cl22 Ted48g3200c22bk Pc
# HP V6 DDR4 16GB 3600Mhz CL18 Desktop Gaming Memory with Heatsink BLACK
# ADATA 16GB DDR4 2666 MHz UDIMM Memory Module for PC
# ADATA 8GB DDR4 2666 MHz UDIMM Memory Module for PC
# HP V6 DDR4 8GB 3600Mhz CL16 Desktop Gaming Memory
# TEAM DELTA RGB 32G-2X16 3200Hz DDR4 DESKTOP MEMORY-BLACK
# Team GROUP T-Force Delta RGB 16GB  2 x 8GB  288-Pin PC RAM DDR4 3200  PC4 25600  Desktop Memory BLACK
# TEAM DELTA TUF GAMING RGB 32G 3200Hz DDR4 DESKTOP MEMORY - yellow
# HP V6 DDR4 16GB 3200Mhz CL16 Desktop Gaming Memory with Heatsink BLACK
# Crucial Ballistix RGB 16GB Kit  2 x 8GB  DDR4-3200 Desktop Gaming Memory  black
# Inserting product: TEAM GROUP Elite 8 Gb Ddr4 3200 Mhz Cl22 TED48G3200C22BK Pc compatible with amd only - 775
# Inserting product: Crucial 16GB Desktop DDR4 3200MHz  UDIMM Memory Module - 1449
# Inserting product: Crucial 8GB DDR4-3200 UDIMM 1.2V CL22 PC - 775
# PNY Performance DDR4 2666MHz Desktop Memory 16GB Performance DDR4 2666MHz Desktop Memory  PC4-21300
# PNY Performance DDR4 2666MHz Desktop Memory 8GB Performance DDR4 2666MHz Desktop Memory  PC4-21300
# PNY XLR8 DDR4 3200MHz Low Profile Desktop Memory 16GB Kit  2x8GB  DDR4 3200MHz Desktop Memory  PC4-25200  CL16
# PNY XLR8 Gaming EPIC-X RGB    3200MHz Desktop Memory 16GB Kit  2x8GB  XLR8 Gaming EPIC-X RGB DDR4 3200MHz
# PNY XLR8 Gaming EPIC-X RGB    3200MHz Desktop Memory 32GB Kit  2x16GB  XLR8 Gaming EPIC-X RGB DDR4 3200MHz
# PNY XLR8 Gaming EPIC-X RGB    3600MHz Desktop Memory 32GB Kit  2x16GB  XLR8 Gaming EPIC-X RGB DDR4 3600MHz
# Kingston FURY Beast DDR5 Memory 16GB KF548C38BB-16 4800MHz
# HyperX Fury RGB 32GB 3600MHz DDR4 CL17 DIMM 2x16 RGB
# Kingston Fury Beast RGB KF437C19BBA 8 8GB DDR4 3733Mhz Non ECC DIMM
# Kingston Fury Beast KF437C19BB 8 8GB DDR4 3733Mhz Non ECC DIMM
# Kingston Fury Beast KF436C17BB 8 8GB DDR4 3600Mhz Non ECC DIMM
# XPG SPECTRIX D60 RGB Desktop Memory 32GB  2x16GB  DDR4 3600MHz GREY
# Kingston FURY 32GB 3600MHz DDR4 CL18 DIMM Fury Beast Black  KF436C18BB 32
# AORUS RGB Memory DDR4 16GB  2x8GB  3333MHz DDR4
# GIGABYTE DESIGNARE Memory 64GB  2x32GB  3200MHz DDR4
# AORUS RGB Memory DDR4 16GB  2x8GB  3733MHz DDR4
# Kingston Fury Beast RGB KF436C18BBA 16 16GB DDR4 3600Mhz Non ECC DIMM
# Kingston Fury Beast RGB KF436C17BBA 8 8GB DDR4 3600Mhz Non ECC DIMM
# Kingston Fury Beast RGB 8GB DDR4 3200MHz KF432C16BBA 8
# Kingston Fury Beast RGB 16GB DDR4 3200MHz CL 16-20-20  KF432C16BBA
# Inserting product: Kingston Fury Beast 16GB 3200MHz DDR4 CL16 KF432C16BB1 16 - 1799
# Inserting product: Kingston Fury Beast KF432C16BB 8- Desktop Memory  8GB  3200MHz  DDR4 CL16  - 949
# DATO RAM 16G P2666 PC DDR4 BLACK
# Patriot Signature 16GB DDR4 2666MHz PC4-21300 CL19 Memory Module  PSD416G26662
# XPG SPECTRIX D45g 16GB KIT   2x8 GB  4133MHZ
# XPG SPECTRIX D45g rgb 16GB  3600MHZ
# DATO RAM  8G P2666 PC DDR4 BLACK
# Patriot Viper Gaming RGB Series DDR4 DRAM 3200MHz 16GB Kit - White
# HP V8 RGB RAM  8GB  1 x 8GB DDR4  3200mHz U-dimm  CL16
# HP V8 RGB 16GB  2 x 8GB  DDR4 3600MHz U-DIMM CL18 Desktop Memory Kit - Black
# HP V6 DDR4 8GB 3200Mhz CL16 Desktop Gaming Memory with Heatsink BLACK
# Samsung 8GB DDR4 3200Mhz Memory RAM DIMM-tray-pc
# GIGABYTE Memory 8GB  1x8GB  2666MHz
# PNY XLR8 Gaming EPIC-X RGB 3600MHz Desktop Memory 16GB Kit 2x8GB XLR8 Gaming EPIC-X RGB DDR4 3600MHz
#  GIGABYTE-AORUS RGB Memory DDR4 16GB  2x8GB  4400MHz
# Team Zeus 8 GB 3200MHz DDR4 CL20
# Lexar   DDR4-3200Hz 8GB UDIMM Desktop Memory
# DATO PC 16GB 2X8 3200 MHz DDR4 RGB
# HyperX Fury HX437C19FB3 8 8GB DDR4 3733Mhz Non ECC Memory RAM DIMM
# XPG GAMMIX D20 16G 3200Hz DDR4 MEMORY MODULE
# XPG GAMMIX D20 8G 3200Hz DDR4 MEMORY MODULE
# ADATA XPG Spectrix D50 RGB LED 16GB Kit 2 x 8GB DDR4 3200MHz  - White
# ADATA XPG Spectrix D50 RGB LED 16GB Kit 2 x 8GB DDR4 3600MHz CL18-20-20 - White
# Crucial Ballistix 16GB Kit  2 x 8GB  DDR4-3600 Desktop Gaming Memory  White
# CORSAIR VENGEANCE RGB PRO 32GB  2 x 16GB  DDR4 DRAM 3200MHz C16 Memory Kit     Black
#  CORSAIR DOMINATOR PLATINUM RGB 32GB  2 x 16GB  DDR4 DRAM 3200MHz C16 Memory Kit
# HyperX Fury Black 16GB 3200MHz DDR4 CL16 DIMM Single Stick HX432C16FB4 16
# DATO PC 16GB 3200 MHz DDR4 RGB  Black
# Crucial Ballistix RGB 16GB Kit  2 x 8GB  DDR4-3200 Desktop Gaming Memory  White
# Crucial 16GB Ballistix Sport LT 3200 MHz DDR4 DRAM Desktop Gaming Memory Single CL16   White
# Crucial 8GB DDR3L-1600 UDIMM
# Crucial 32GB single DDR4-3200 UDIMM Memory
# Team T-FORCE DARK Z 8GB DDR4 3200 CL16 Gaming Memory
# TEAMGROUP T-Force Dark Z DDR4 16GB 3200MHz CL16 Gaming Memory
#  ADATA XPG GAMMIX D10 16GB  1x16GB  3200MHz  DDR4 Memory Module  Black
# Crucial Ballistix 32GB Kit  2 x 16GB  DDR4-3600 Desktop Gaming Memory  Red
# Crucial Ballistix 32GB Kit  2 x 16GB  DDR4-3200 Desktop Gaming Memory  Black
# Crucial Ballistix 32GB Kit  2 x 16GB  DDR4-3000 Desktop Gaming Memory  White
# PATRIOT Viper Gaming BLACK RGB 16GB DDR4 3200 PC4-25600
# CORSAIR VENGEANCE LPX 16GB  1 x 16GB  DDR4 DRAM 3200MHz C16-20-20-38 Memory Kit - Black
# XPG SPECTRIX D50 RGB Gaming Memory  16GB  2x8GB  DDR4 3200MHz CL16 Grey
# ADATA XPG Spectrix D50 RGB LED 16GB Kit 2 x 8GB DDR4 3600MHz CL18-22-22 - Grey
# ADATA XPG Spectrix D50 RGB LED 16GB Kit  2 x 8GB   DDR4  4133MHz CL19-23-23
# Crucial Ballistix 16GB Kit  2 x 8GB  DDR4-3200 Desktop Gaming Memory  Black
# Crucial 4GB DDR4-2666 UDIMM  288 Pin PC
# Patriot Viper Steel RGB DDR4 RAM 8GB  1X8GB  3200MHz CL18 UDIMM Desktop Gaming Memory Module - PVSR48G320C8
# TwinMos 16GB 2666MHZ DDR4 Mainstream Series PC
# TwinMos 8GB 2666MHZ DDR4  Mainstream Series PC
# GIGABYTE Memory 16GB  2x8GB  2666MHz
# AORUS RGB Memory 16GB  2x8GB  3600MHz
# BQ 4GB DDR3 1600MHz  Memory Module for PC
# CORSAIR VENGEANCE   RGB PRO 16GB  2 x 8GB  DDR4 DRAM 3600MHz C18 Memory Kit     Black
# Patriot Viper RGB 16GB  1 x 16GB  3600MHz Single
# PATRIOT Viper Steel DDR4 32GB  2 x 16GB  3200MHz Kit
# Patriot 16GB Viper Steel DDR4 3600 MHz UDIMM Memory Kit  2 x 8GB
# Patriot 16GB Viper Steel DDR4 3200 MHz UDIMM Memory Kit  2 x 8GB
# HyperX Fury 16GB 3200MHz DDR4 CL16 HX432C16FB316
# HyperX Fury HX437C19FB3A 8 Memory Module 8 GB 3733 MHz DDR4 CL19 DIMM 1Rx8 RGB
# HyperX Fury RGB KF437C19BB1A 16 16GB DDR4 3733Mhz Non ECC Memory RAM DIMM
# HyperX Fury HX437C19FB3 16 16GB DDR4 3733Mhz Non ECC Memory RAM DIMM
# G.SKILL Trident Z 32GB  2x16GB  DDR4-3200MHz CL16
# G.SKILL Flare X 32GB  2X16  DDR4-3200MHz CL16
# G.SKILL Ripjaws V 16GB  2x8GB  DDR4-3600MHz  1.35V
# G.SKILL Ripjaws V 32GB DDR4-3200MHz  1.35V   2x16GB
# G.SKILL Aegis 16GB  1x16GB   DDR4-3200MHz
# RAM G.SKILL AEGIS DDR4  8GB 3200MHz
# CORSAIR VENGEANCE   RGB PRO 32GB  2 x 16GB  DDR4 DRAM 3600MHz C18 Memory Kit
# HyperX Fury 8GB 3200MHz RGB DDR4 - HX432C16FB3A 8
# Patriot Viper Steel 16GB DDR4 3200 MHz CL16
# Patriot Viper 32GB 2x16 Kit Ram Gaming RGB DDR4 DRAM 3200MHz
# Patriot Viper Steel  DDR4 8GB 3200MHz CL16
# Patriot Viper Gaming RGB  DDR4 DRAM 3000MHz 16GB 2 8 Kit - Black - RGB
# Inserting product: Crucial 16GB DDR4 2666 MHz UDIMM Memory Module for PC - 1449
# Corsair VENGEANCE   RGB PRO 8GB  1 x 8GB  DDR4 DRAM 3200MHz Cl16 WITH RGB
# Corsair VENGEANCE   LPX 16GB  2 x 8GB  DDR4 DRAM 3600MHz C19 Memory Kit - Black
# Inserting product: CORSAIR 8G Vengeance LPX 3200Hz CL16-18-18-36  CMK8GX4M1Z3200C16  AMD Expo For Amd Cpu Better - 999
# CORSAIR VENGEANCE   RGB PRO 16GB  2 x 8GB  DDR4 DRAM 3000MHz C15 Memory Kit
# CRUCIAL 8GB DDR4 2666 PC
# XPG Gammix D10 3200MHz 8G Memory - BLACK
# XPG Hunter 8GB DDR4 3000Hz Memory Module U-DIMM
# XPG Hunter 16GB DDR4 3000MHz  1x16  Memory Module U-DIMM
# HyperX Fury 16GB 3200MHz RGB DDR4 - HX432C16FB4A 16
# XPG Gammix D10 3200MHz 8G Memory Module Red
# G.SKILL Trident Z Royal DDR4-3600MHz CL16-19-19-39 1.35V 32GB  2x16GB
# G.SKILL Trident Z Royal DDR4-3200MHz CL16-18-18-38 1.35V 16GB  2x8GB
#  XPG SPECTRIX  D60G 16G  2x8  DDR4  3200Mhz RGB  CL16 Desktop Memory RAM Kit
#  XPG SPECTRIX  D60G 16G  2x8  DDR4  3600Mhz CL18  RGB Desktop Memory RAM Kit
# AORUS RGB Memory 16GB     2x8GB     3200MHz
# Ballistix Sport LT White 8GB DDR4-3200 UDIMM
# Ballistix Tactical Tracer RGB 8GB DDR4-3200 UDIMM Gaming Memory
# Crucial Ballistix Tactical Tracer RGB 3000 MHz DDR4 DRAM Desktop Gaming Memory Single 8GB CL15
# G.SKILL Trident Z Neo  Series 32GB  2 x 16GB  RGB DDR4 SDRAM DDR4 3600
# G.SKILL Trident Z Neo Series 16GB  2 x 8GB  3600MHz RGB
# G-Skill Trident Z 32GB  2x16GB  DDR4-3200MHz CL16
# G-Skill Trident Z 16GB  2x8GB  DDR4-3200MHz CL16
# G skill Flare X 16G  2x8  DDR4-3200MHz CL16
# XPG Gammix D10 3000MHz 8G Memory Module Red
# XPG Gammix D10 3200MHz 16G Memory Module Red
#  XPG SPECTRIX  D60G 16G  2x8  DDR4  3000Mhz RGB  CL16
# G.SKILL Ripjaws V Series 16GB  2 x 8GB  SDRAM DDR4 3600
# Trident Z Neo DDR4-3200MHz CL16 32GB  2x16GB  RGB
# Trident Z Neo DDR4-3200MHz CL16 16GB  2x8GB  RGB
# G.Skill Ripjaws V Series 16GB  1x16 DDR4 SDRAM DDR4 3200 Memory
# Adata XPG Spectrix D80 RGB 16GB  16GBx1  DDR4 3000MHz Red Edition With Hybrid Liquid-Air Cooling
# Adata XPG Spectrix D80 RGB 8GB  8GBx1  DDR4 3000MHz Red Edition With Hybrid Liquid-Air Cooling
# G.SKILL 16GB  2 x 8GB  Ripjaws V Series DDR4  3200MHz Desktop Memory Model
# G.SKILL 32GB  2 x 16GB  Ripjaws V Series DDR4 3000MHz
# G.SKILL Ripjaws V Series 16GB  2 x 8GB  SDRAM DDR4 3000
# RAM G.Skill  Aegis 8GB  DDR4 3000 Cl16
# Patriot Viper Gaming RGB  DDR4 DRAM 3200MHz 16GB 2 8 Kit - Black - RGB
# RAM TEAM  VULCAN Z 8G DDR4 P3000 GAMING MEMORY
# Crucial Ballistix Sport LT 3200 MHz DDR4 DRAM Desktop Gaming Memory Single 16GB CL16
#  Crucial Ballistix Sport LT 3200 MHz DDR4 DRAM Desktop Gaming Memory Single 8GB CL16
# Crucial Ballistix Sport LT 3000 MHz DDR4 DRAM Desktop Gaming Memory Single 16GB CL16  Gray
# ...
# Fighter I5 13400F 7600 8GB -342- Intel-Core i5-13400F- MSI H610M-E DDR4- XFX QICK RX7600 8GB- T-Force Vulcan Z 2X8GB 3200MHZ -Western Digital BLACK SN750 250GB- COOLER MASTER CMP520 WITH NEX N600 PSU
# Fighter I5 13400F 4060TI 8GB -371- ASUS PRIME B760M-R- Intel Core i5-13400F- Vulcan Z 2X8GB 3200MHz-  INNO3D RTX 4060 Ti 8GB- LEXAR NM620 256GB M.2- Aerocool Designer ARGB CASE AND VX PLUS 650W PSU
# FIGHTER I5 12400F 3060 12GB -319- MSI H610M-E- Intel Core i5-12400F- Lexar 2x8GB 3200Mhz- GALAX RTX 3060 12GB- TEAMGROUP MP33 256GB- GAMDIAS AURA GC1 ELITE CASE AND AURA GP650 PSU
# FIGHTER R5 7600 4060 -316-AMD-RYZEN 5-7600 - MSI PRO A620M-E -  ALAX GeForce RTX 4060 1-Click OC 8GB - CORSAIR VENGEANCE LPX 32GB 2x16GB DDR5 DRAM 5200MHz - Lexar NQ100 480G - COOLER MASTER CMP 520 3FANS ARGB with Power 600W Elite V3.
# FIGHTER I5 13400F 3060 -414-Intel-Core i5-13400F-GIGABAYT H610M K DDR4-GALAX GeForce RTX 3060 1-Click OC 12GB-HP V6 DDR4 16GB 3200Mhz-Lexar NM620 M.2 2280 NVMe SSD 256GB-ilver Stone FARA B1 V2 Sleek ARGB 4 FAN PUS 700W 80 PLUS.
# Dragon R5 3600 1650 -209-CPU-AMD-RYZEN 5-3600-ASUS PRIME A520M-R-ASUS PRIME A520M-R-ZOTAC GAMING GeForce GTX 1650 AMP Core 4GB-KLEVV-8GB- DDR4 3200MHz-Hikvision E100 2.5 ssd 128GB-Antec NX360 - Mid-Tower ATX Gaming Case 4 Fan WITH PSU Antec
# Dragon R3 4100 RX580 -208-CPU-AMD-RYZEN 3-4100 tray with fan-ASUS PRIME A520M-R-ARKTEK VGA RADOEN RX580 DDR5 8GB-Crucial 8GB DDR4-3200-Western Digital BLACK SN750 SE 250GB-Antec NX360 - Mid-Tower ATX Gaming Case 4 Fan WITH PSU Antec atom V4
# FIGHTER I5 10400F RX 580 -207- INTEL I5-10400F Tray with fan-MSI Intel PRO-H510M-B-ARKTEK VGA RADOEN RX580 DDR5 8G-Crucial 16GB DDR4 2666 MHz-ahua C800A 256GB-XIGMATEK CASE HERO II AIR Z 4 Fan-POWER II Z750 500W PSU
#  Dragon R5 5500 RX 580 -206-CPU AMD RYZEN 5-5500 MPK 3.6GHz Tray with fan -MSI-AMD Motherboard B450M-A PRO-MAX II-ARKTEK VGA RADOEN RX580 DDR5 8G-CORSAIR VENGEANCE RGB RS 16GB - Dahua C800A 256GB - XIGMATEK CASE HERO II AIR Z 4 Fan-POWER II
# Dragon R3 4100 1660Ti -205-CPU-AMD-RYZEN 3-4100 tray with fan-MSI MOTHERBOARD AMD A520M-A PRO-PALIT GeForce GTX 1660 Ti Dual 6GB-Crucial 8GB DDR4-3200-Patriot P300 M.2 2280 256GB-REDRAGON GC-651 CASE 4 FAN with PSU 600w Bronz.
# Dragon R5 4500 1650 -224- MSI A520M-A PRO- AMD-RYZEN 5-4500- KLEVV-8GB- DDR4 3200MHz- palit GeForce GTX 1650 4gb- KLEVV CRAS C710 256GB- Antec NX360 - Mid-Tower ATX Gaming Case and atom V450w psu
# Dragon I3 12100F 1650 4GB -225- MSI PRO H610M-E DDR4- Core i3-12100F- KLEVV-8GB- DDR4 3200MHz- palit GeForce GTX 1650 4gb- KLEVV CRAS C710 256GB- Antec NX360 - Mid-Tower ATX Gaming Case and atom V450w psu
# Dragon I5 12400F 1660TI -204-CPU-INTEL-I5-12400F-BOX-GIGABAYT H610M K DDR4-PALIT GeForce GTX 1660 Ti Dual 6G-Crucial 16GB DDR4-3200-Patriot P300 M.2 2280 256GB-REDRAGON GC-651 CASE 4 FAN with PSU 600w Bronz.
#  NINJA 13700K 4080-410-Intel i7-13700K-ASUS-INTEL Z790-PRIME-P-DDR5-PNY RTX 4080 16GB TF VERTO Edition-PATRIOT VIPER VENOM 32GB-XPG GAMMIX S50 Lite 1TB-Cooler Master HAF500 PC Case-Silver Stone SST-DA850-G 80 PLUS Gold-COUGAR LIGUID COOLING
# NINJA 7600X 3070TI -407-AMD Ryzen 5 7600X-GIGABYTE AMD B650M DS3H-iGame RTX 3070 Ti Ultra W OC 8G-V-Patriot VIPER VENOM DDR5 RAM 16GB 2X8GB 5200MHz-PNY XLR8 CM3040 M.2 NVMe Gen4 500GB-BitFenix Enso Mesh Case Mesh 2FAN-EVGA-100-GD-0700-V2 PS
# NINJA 12900K 3090 -406- Intel Core i9-12900KASUS ROG Strix Z690-F Gaming WiFi PALIT GeForce RTX 3090 GamingPro OC-24G XPG LANCER RGB 64GB DDR5 5200MH Seagate BarraCuda 4TB Internal AORUS Gen4 7000s Prem. SSD 1TB NOCTUA COOLING AIR NH D15 AS
#   JINX R5 7500F 2060-009-AMD Ryzen 5 7500F Tray-ASUS TUF GAMING B650M-E-COLORFUL RTX2060 SUPER NB 8GB-Patriot VIPER VENOM DDR5 RAM 16GB 2X8GB 5200MHz-Lexar NM620 M.2 2280 NVMe SSD 1TB-GAMDIAS CASE AURA GC1 Elite 4xFRGB Whit GAMDIAS HELIOS E
# Jinx 13100F 3050 -007-Intel Core i3100F-GIGABYTE B660M D2H DDR4-GeForce RTX 3050 EAGLE OC 8Gb-Team T-Force Delta RGB DDR4 8GB 3200MHz  2x8 -HP EX900 Plus M.2 PCIe 3.0 x4 NVMe 256 GB-BitFenix Saber Case-Gigabyte P550B 80 PLUS Bronze 550W PSU
# Jinx 13400F 2060 006- Intel Core i5-13400F-GIGABAYT B660M DS3H DDR4-GIGABAYT GeForce RTX 2060 WINDFORCE OC 12G-HP V6 DDR4 16GB 3200Mhz 2x8 -Lexar NM620 M.2 256GB-COUGAR Case DUOFACE 3 FAN RGB POWER VTE X2 650W
# JINX 12100F 1660S  004-Intel Core i3-12100F-ASUS PRIME H610M-K D4-GAINWARD GTX 1660 SUPER Ghost 6G-Crucial 8GB DDR4-3200-HIKVISION E100 128GB-2B PW017 Ecstasy Gaming Mid Tower-COOLER MASTER ELITE 600W TRAY
# Redragon K552 Mechanical Gaming Keyboard LED RED Backlit Red Switches And Redragon M711 COBRA 12400 Dpi Gaming Mouse
# GIGABAYT B760M DS3H DDR4 rev. 1.0 And GIGABYTE GeForce RTX 3060 GAMING OC 12G
# MSI B450M PRO-VDH Max And Ryzen 7 5700 8 Core 16 Thread And Kingston Fury Beast 1x16GB 3200MHz
# ASUS PRIME B650M-R Micro-ATX motherboard DDR5 And CPU AMD RYZEN 5 7500F 6 Core 3.7GHz
# GIGABYTE B760M-DS3H AndGIGABYTE  RTX4060 GAMING OC 8GB DDR6 And ram Lexar 1x16GB 3200 DDR4
# Sigma Friday Bundl-23- GIGABYTE  B760M DS3H DDR4- Intel Core i5-13400F- Lexar 1x16GB 3200 DDR4- Gigabyte RTX 4060 8G- Patriot P300 265GB- XANDER VELOX ARGB 650W 80 PLUS WHITE
# laxus 4100 3050 6GB -01- MSI A520M-A PRO- AMD RYZEN 3-4100 TRAY- Lexar 2x8 DDR4 3200- PNY RTX 3050 6GB- LEXAR NM620-256G- XIGMATEK Hero II Air ARGB X-Power 600W 80 White PSU
# Sigma Friday -22- MSI A520M-A PRO- AMD RYZEN 5-5500 TRAY- Patriot Viper Steel 16GB DDR4 3200- MSI RTX 3050 8GB- TEAMGROUP MP33 256GB- XIGMATEK Hero II Air ARGB X-Power 600W 80 White PSU
# Sigma Friday Bundl-21- Gigabyte H610M-H DDR4- Intel Core i5-12400F TRAY- Lexar 2 8GB DDR4 3200Hz- Gigabyte RTX 3060 12G- TEAMGROUP MP33 256GB- XIGMATEK Hero II Air ARGB X-Power 600W- CPU COOLER Phantom HF-400 RGB
# Sigma Friday Bundl-20- GIGABYTE Motherboard INTEL-Core i5-13400F- B760MH DDR4- Gigabyte RTX 4070 OC 12G- Lexar NM620 NVMe 512GB M.2- XIGMATEK ZOSER ARGB TYPE C- Phantom HF-400 RGB CPU COOLER- Aerocool Integrator Gold 750W
# Sigma Friday Bundl-19- Gigabyte H610M-H DDR4- Intel Core i3-12100F- Lexar 2 8GB 3200Hz- Gigabyte RTX3050 6GB- LEXAR NM620-256G- GAMDIAS AURA GC2 Elite And HELIOS E1-600W psu- Phantom HF-400 RGB CPU COOLER
# Sigma Friday Bundl-18-ASUS PRIME B760M-R D4- Intel-Core i5-12400F- Lexar THOR DDR4 2x8GB 3200HZ- ASUS Dual RTX 3050 OC 8GB- TEAMGROUP MP33 256GB M.2- ARKTEK AK-I1107 ARGB PSU 650W
# Sigma Friday Bundl-17-MSI PRO B760M-E DDR4- Intel-Core i5-13400F- Lexar DDR4-3200Hz 8GB- GALAX GeForce RTX 4060 Ti 8GB OC- LEXAR-SSD-NM620-256G-M.2-NVMe-3D NAND- XANDER VELOX ARGB 650W 80 PLUS WHITE- Phantom HF-400 RGB CPU COOLER
# Sigma Friday Bundl-16-MSI PRO B760M-E DDR4- Intel-Core i5-13400F- Lexar DDR4-3200Hz 8GB- Inno3D RTX4060 Twin x2 8GB- LEXAR- NM620-256G-M.2-NVMe-3D NAND- XANDER VELOX ARGB 650W 80 PLUS WHITE- Phantom HF-400 RGB CPU COOLER
# Sigma Friday Bundl-15- MSI PRO B760M-E DDR4- Intel-Core i5-13400F TRAY- Lexar DDR4-3200Hz 8GB UDIMM- GALAX RTX 3060 12GB- LEXAR NM620-256G- XANDER VELOX ARGB 650W 80 PLUS WHITE- Phantom HF-400 RGB CPU COOLER
# Sigma Friday Bundl-14- MSI PRO B760M-E DDR4- Intel-Core i5-13400F TRAY- Lexar DDR4-3200Hz 8GB- XFX RX 7600 XT 16GB- LEXAR NM620-256G- XANDER VELOX ARGB 650W 80 PLUS WHITE- Phantom HF-400 RGB CPU COOLER
# Sigma Friday Bundl-13- MSI PRO B760M-E DDR4- Intel-Core i5-13400F TRAY- Lexar DDR4-3200Hz 8GB- XFX RX 6650 XT 8GB- LEXAR-NM620-256G- XANDER VELOX ARGB 650W 80 PLUS WHITE- Phantom HF-400 RGB CPU COOLER
# Sigma Friday Bundl-12- Gigabyte H610M-H DDR4- Intel-Core i5-12400F - Lexar 2 8GB 3200Hz- GALAX RTX 3060 12GB- LEXAR NM620 256G- XIGMATEK Hero II Air ARGB And X-Power 600W 80 White PSU- Phantom HF-400 RGB CPU COOLER
# Sigma Friday Bundl -11- Gigabyte H610M-H DDR4- Intel-Core i5-12400F - Lexar 2 8GB 3200Hz- Inno3D RTX4060 8GB- LEXAR NM620 256G- XIGMATEK Hero II Air ARGB And X-Power 600W 80 White PSU- Phantom HF-400 RGB CPU COOLER
# Sigma Friday Bundl -10- Gigabyte H610M-H DDR4- Intel-Core i5-12400F - Lexar 2 8GB 3200Hz- XFX RX 7600 8GB- LEXAR NM620 256G- XIGMATEK Hero II Air ARGB And X-Power 600W 80 White PSU- Phantom HF-400 RGB CPU COOLER
# Sigma Friday Bundl -09- Gigabyte H610M-H DDR4- Intel-Core i5-12400F - Lexar 2 8GB 3200Hz- XFX RX 6650 XT 8GB- LEXAR NM620 256G- XIGMATEK Hero II Air ARGB And X-Power 600W 80 White PSU- Phantom HF-400 RGB CPU COOLER
# BENQ MS550 SVGA Business Projector  DLP  3600 Lumens High Brightness  20000 1 High Contrast Ratio  Dual HDMI  VGA  Keystone Correction  Simple Setup  SmartEco Technology
# BenQ XGA Business Projector  MX560   DLP  4000 Lumens High Brightness  20000 1 High Contrast Ratio  Dual HDMI  VGA  Auto Keystone Correction  Simple Setup  SmartEco Technology
# BenQ MX532 - 3300 lumen XGA
# HP LaserJet Pro M404dn
# HP LaserJet Pro M15w Printer
# HP PRINTER - LASERJET-PRO M404n
# Canon Imageclass MF3010 Laser MFP ALL IN ONE
#  HP LaserJet Pro MFP M130a Multifunction Printer
# HP LaserJet Pro M404n Laser Printer with Built-in Ethernet   Security Features
# HP Laser MFP 135w Multifunction Printer  Print  copy  scan built-in Wi-Fi    White - 4ZB83A
#  HP LaserJet Pro M15w Printer USB 2.0 Hi-Speed Wi-Fi-Cartridge 44A
# HP 135A  MFP Laser Multifunction Printer
# HP LaserJet Pro MFP M130fw
# HP LaserJet Pro M28W Printer
# HP LaserJet Pro MFP M28a
# HP LaserJet Pro M15a Printer
# HP DeskJet Ink 3788 All-in-One Printer Wireless - Red
# Canon I-SENSYS LBP6030B Mono Laser Printer
# HP ScanJet Pro 2500 f1 Flatbed Scanner - L2747A
# Canon CanoScan LiDE 300
# LG GP65NB60 8X USB 2.0 Ultra Slim Portable DVD Writer Burner Drive
# ASUS ZenDrive U8M  SDRW-08U8M-U
# DVD-R 16x Recordable 4.7GB   120 Mins - Pack of 50
# DRW-24D5MT - 24X DVD-RW DL Drive
# TRANSCEND Transcend External DVD Writers
# ASUS DRW-24D5MT - 24X DVD-RW DL Drive
# HIKSEMI M.2 SSD COOLER HEATSINK MH1
# Remax RPP-139 LEADER Series 10000mAh Power Bank - white
# YK DESIGN YKP-021 10000MAH POWERBANK DUAL USB OUTPUT
# TOOLS-INGCO-Screwdriver set (9 Pcs) HKSD0928
# Ingco 6pcs mini plier set, jewelry pliers tools kit beading pliers set hmps06115
# HAVIT CHARGE HV-UC110 PD20W Charger
# HAVIT CHARGE UC117 Three USB travel charger
# HAVIT CHARGE Hv-uc111 Pd20w+qc3.0 Wall Charger
# Ldnio Power Strip, 3 Sockets, 6 USB Ports 2500W, Grey - SC3604
# Power Strip Systemmax 4Port/2USB - SMPG-4P2U 2.1A
# Power Strip Systemmax 5 Port - SMPG-5P
# Power Strip SystemMax 4 Port - SMPG-4P
# INGCO Blower 600W AB6008
# INGCO 6 Pcs screwdriver set HKSD0628
# I-ROCK 4 BLACK EYE ELECTRICITY JOINT MADE IN TURKEY WITH A CAPACITY OF 10 AMPS AND 2500 WATTS
# Ingco HES13041VSB Power Strip - 3 Socket - 3M - 13A
# INGCO 8 Pcs screwdriver set HKSD0828
# INGCO 5pcs mini pliers set 4.5 mm
# INGCO AB4018 Aspirator Blower 400 Watt
#  HP 107w Laser Wireless Printer  .White
#  HP Laser Printer MFP 135A
# Error fetching https://www.sigma-computer.com/subcategory?id=18&cname=GAMING CONSOLES&id2=56&scname=Sony PlayStation&page=1: 524 Server Error:  for url: https://www.sigma-computer.com/subcategory?id=18&cname=GAMING%20CONSOLES&id2=56&scname=Sony%20PlayStation&page=1
# PLAYSTATION DualSense PS5 Controller - Cosmic Red
# PLAYSTATION DualSense PS5 Controller - Midnight Black.
# PLAYSTATION DualSense PS5 Controller - White.
# XBOX-Microsoft-X-BOX SERIES S 1TB
# Xbox Series X 1Tb     Diablo IV Bundle
#  Microsoft Xbox Series S Digital Edition Console  512GB  with Wireless Controller   3 Months of Game Pass Ultimate  White
# Microsoft Xbox Series S Digital Edition Console  512GB  with Fortnite  Fall Guys   Rocket League Bundle
# Xbox Wireless Controller Shock Blue
# Xbox Wireless Controller Carbon Black
# Samsung UA43T5300 - 43-inch Full HD Smart TV With Built-In Receiver
#  Samsung 32-inch HD Smart TV With Built-In Receiver LED HD 1366×768 - UA32T5300
#  Samsung UA32N5000 - 32-inch HD TV With Built-In Receiver 32N5000
# Huawei Matepad T10S LTE AGS3K-L09 4GB Ram,128GB - Deepsea Blue
# Huawei Matepad T8.0  LTE KOBE2k-L09 2GB Ram,32GB - Deepsea Blue
# Huawei Matepad T10S LTE AGS3K-L09 4GB Ram,64GB - Deepsea Blue
# Lenovo Tab M7 Tablet, 7 Inch HD Display, 16 GB, 1 GB RAM, Android 9, 3G - Onyx Black
# Windows 10 Pro 64-bit Key
# KASPERSKY INTERNET SECURITY MULTI DEVICE 4 USER 1 YEAR
#  Awei H16 1.96 in HD Full Touch Screen Watch  BLUE
# Awei H16 1.96 in HD Full Touch Screen Watch  Black
# HUAWEI Band 6 Sakura Pink All-Day SpO2 Monitoring1   FullView Display   2-Week Battery Life
# HUAWEI Band 6 Amber Sunrise All-Day SpO2 Monitoring1   FullView Display   2-Week Battery Life
# HUAWEI Band 6 Forest Green WATCH All-Day SpO2 Monitoring1   FullView Display   2-Week Battery Life
# HUAWEI Band 6 dark gray WATCH All-Day SpO2 Monitoring1   FullView Display   2-Week Battery Life
# JSAUX  PB2002  Super Mini 22.5W Powerbank 10000mAh QC PD 3.0 Dual Port Portable Charger- Black
# Remax RPP-100 10000 mAh Repin Series Mini Power Bank with Display wireless- black
# WK DESIGN Power Bank Portable Charger Compact   Slim External Battery with High Capacity  Made for iPhone  iPad  Samsung Galaxy and More -Black
# Yk Design YKP-020 Power Bank 20000mah Dual Port- BLACK
# Proda Ultron Series PD-P32 Power Bank  10000 mah - WHITE
# Proda PD-P50 Gladiator Series 10000mAh Fast   Dual USB Port Power Bank - Black
# Proda PD-P39 Hujon Series Wired Power Bank  10000 mAh - White
# LDNIO PW1003 High Capacity Mobile phone charging station10000mAh Wireless charger power bank
# Remax RPP-140 Leader Series Wired Power Bank  20000 mAh  2 Ports - Black
# Power Bank REMAX JONSHON LCD RPP-153 10 000MAH White
# Remax RPP-141 Leader Series Wired Power Bank  30000 mAh  2 Ports - WHITE
# Remax RPP-159 Suchy Series Power Bank with 2 Charging Ports  10000 mAh - Black
#  Extra 20000mAh Power Bank - White
# Extra 10000mAh Power Bank - White
# i-LIFE PB 2600 Power Bank
# Power Bank - 15000 MAh - White- Team group
# TEAM WP1000 Power Bank  10000mAh  Black
# TEAM WP1000 Power Bank  10000mAh
# Rapoo P20 Power Bank - 5000 MAh
#  Rapoo Power Bank - 13000 MAh P370
# Rapoo P390 Polymer - 10000mAh Powerbank - Black
# Rapoo P200 - 10000 Mah Power Bank - Black
# RAPOO  P170 Power Bank - 10000mAh - Black
# Choetech Cable Display PORT To Displayport XDD01 2M 8K-4K
# CHOETECH AC0013 USB Type C Cable For HUAWEI  5A SuperCharge Fast Charging
# UGREEN USB Type-C Charging Cable 1.5M Black
# GLORIOUS G-SKATES MOUSE FEET premium
# General LED Bi-Color Light Video Led Light 20W With Cable
# GENERAL-LED-12W
# GENERAL LED55RGB LIGHT
# GENERAL LED 55WB1
# GENERAL-CONVERTAR-HDMI TO USB CAPTURE Portable For Live Streaming.
# GENERAL Microphone Mount Stand, Durable and Adjustable, Black NB-39.
# General VG-20 Vlogging Kit for Mobile with LED Light, K10 Wireless Microphone for iphone.
# General VG-20 Vlogging Kit for Mobile with LED Light, K10 Wireless Microphone type c.
# General K10 Wireless Microphone Camera – 1 mic
# GENERAL TL-5 soft box with 5 lamp holder
# ZHIYUN SMOOTH Q3 Smartphones Gimbal 3-Axis Flexible Phone Handheld Stabilizer with Fill Light for Android / IOS and And Every Smartphone
# General - 25cm base - for 360 degree product photography
# General T30RGB Tube Video Led Light Wand 10W 30Cm
# GENERAL K2 iPhone K10 Wireless Microphone
# General K10 k2 Microphone for Smartphone, Wireless Mini Microphone Plug & Play USB C Lavalier Microphone Wireless
# General K10 K1 Microphone for Smartphone, Wireless Mini Microphone Plug & Play USB C Lavalier Microphone Wireless
# BOYA MIC Omnidirectional Lavalier Microphone - BY-M1
# GENERAL Microphone Mic Wireless K1 iPhone K10
# General GH-W1 Headset Wireless Microphone
# Zhiyun Smooth-X GERY COLOR
# LENSGO LYM-DM1D Dual Mini Lavalier Microphone
# LENSGO LYM-DM1 Microphone
# TL-4 kit, 2 soft box with 4 lamp holder .
# WEIFENG WT-3560 Tripod for SLR Camera DV Professional Photographic Kit Camera Stand
# Weifeng wt -3520 Tripod For Digital SLR Camera
# General R1s Bluetooth Selfie Sticks with Remote and Selfie Light, 3-in-1 Multifunctional Selfie Stick Tripod Stand Compatible with iPhone/OnePlus/Samsung/Realme & All Smartphones/Go Pro (Black)
# Adjustable Microphone Stand with Holder,360 Degree Rotating
# معدات تصوير-GENERAL-كلامب موبايل بقفل -W-005
# General Gorilla Holder Stand Mobile &Camera
# General Mini Ring Light 30
# General Mini Ring Light 25
# Ring light R-380 38W
# GENERAL-CONVERTER-AV TO HDMI
# HDMI Video Capture Adapter

# %%
# %pip install psycopg2
# %pip install requests
# %pip install beautifulsoup4
# Out:
# Collecting psycopg2Note: you may need to restart the kernel to use updated packages.
#
#   Downloading psycopg2-2.9.10-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Downloading psycopg2-2.9.10-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.2 MB 326.8 kB/s eta 0:00:04
#    --- ------------------------------------ 0.1/1.2 MB 585.1 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.2 MB 821.4 kB/s eta 0:00:02
#    ------- -------------------------------- 0.2/1.2 MB 919.0 kB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.2 MB 983.0 kB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.2 MB 1.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.4/1.2 MB 1.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.2 MB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.2 MB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 0.9/1.2 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.0/1.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 1.1/1.2 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
#    ---------------------------------------- 0.0/164.9 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/164.9 kB 960.0 kB/s eta 0:00:01
#    ----------------------- -------------- 102.4/164.9 kB 980.4 kB/s eta 0:00:01
#    ----------------------------- ---------- 122.9/164.9 kB 1.0 MB/s eta 0:00:01
#    -------------------------------------  163.8/164.9 kB 893.0 kB/s eta 0:00:01
#    -------------------------------------- 164.9/164.9 kB 822.8 kB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    --------------- ----------------------- 41.0/102.4 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 102.4/102.4 kB 1.2 MB/s eta 0:00:00
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.4 kB ? eta -:--:--
#    ------------------- -------------------- 61.4/128.4 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 122.9/128.4 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 128.4/128.4 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.12.14 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 urllib3-2.3.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Mohamed\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/147.9 kB 435.7 kB/s eta 0:00:01
#    ------------------ -------------------- 71.7/147.9 kB 563.7 kB/s eta 0:00:01
#    ------------------------------------ - 143.4/147.9 kB 853.3 kB/s eta 0:00:01
#    -------------------------------------- 147.9/147.9 kB 882.6 kB/s eta 0:00:00
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3 soupsieve-2.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
