# %%
import psycopg2
from psycopg2 import sql
from concurrent.futures import ThreadPoolExecutor
import requests
from bs4 import BeautifulSoup
import re

# Database connection
conn = psycopg2.connect(
    dbname="PcBuild",
    user="postgres",
    password="123",
    host="localhost",
    port="5432"
)
cursor = conn.cursor()

standardized_categories = {
    "Processors": ["CPU", "Processors"],
    "Motherboards": ["Motherboard"],
    "Graphics Cards": ["VGA Cards", "Graphic Card"],
    "RAM": ["Ram", "RAM"],
    "Internal Storage": ["SSD Disk", "HDD Disk", "Internal Hard", "SSD", "M.2"],
    "External Storage": ["External Hard", "External SSD", "Flash Disk", "Memory Card"],
    "Computer Cases": ["Computer Case"],
    "Power Supplies": ["Power Supply"],
    "Cooling Solutions": ["Cooling", "PC Cooling", "Fans", "Thermal Paste"],
    "Monitors": ["Monitors"],
    "Networking Equipment": ["Router", "Switch", "Access Point", "Wireless USB Adapter", "Cards"],
    "Laptops": ["Laptop", "Notebook"],
    "Laptop Accessories": ["Laptop Bags", "Laptop Fans", "Laptop Chargers & Adapters"],
    "Keyboards": ["Keyboard", "Keyboards", "Keyboard & Mouse COMBO"],
    "Mice": ["Mouse", "Mouse Pad"],
    "Headsets": ["Headsets", "Headphones"],
    "Gaming Chairs": ["Gaming Chair"],
    "Speakers": ["Speaker"],
    "Microphones": ["Microphones"],
    "Webcams": ["Webcam"],
    "Capture Devices": ["Capture box"],
    "Gaming Gear": ["PC Game Controllers", "Gaming Desk"],
    "PC Bundles": ["Bundles", "AMD Bundles", "INTEL Bundles"],
    "Printers": ["Printer", "Cashier Printer", "Barcode Printer"],
    "Scanners": ["Scanner", "Barcode Scanner"],
    "T.V.": ["T.V"],
    "Projectors": ["Projector"],
    "Media Equipment": ["Media Equipment"],
    "Miscellaneous": ["Accessories", "Electricity Connections", "Other Products"],
    "Brands": ["Apple", "HP", "Asus", "Lenovo", "MSI", "Acer", "Dell"]
}

def map_category(category_name):
    category_name = category_name.lower()
    for standardized, variations in standardized_categories.items():
        if category_name in [v.lower() for v in variations]:
            return standardized
    return category_name

# Function to upsert store
def upsert_store(cursor, store_name):
    cursor.execute('SELECT "Id" FROM "Stores" WHERE "Name" = %s', (store_name,))
    store_id = cursor.fetchone()
    if store_id:
        return store_id[0]
    cursor.execute(
        'INSERT INTO "Stores" ("Name") VALUES (%s) RETURNING "Id";',
        (store_name,)
    )
    return cursor.fetchone()[0]

# Function to upsert category
def upsert_category(cursor, category_name):
    category_name = map_category(category_name)
    cursor.execute('SELECT "Id" FROM "Categories" WHERE "Name" = %s', (category_name,))
    category_id = cursor.fetchone()
    if category_id:
        return category_id[0]
    cursor.execute(
        'INSERT INTO "Categories" ("Name") VALUES (%s) RETURNING "Id";',
        (category_name,)
    )
    return cursor.fetchone()[0]

# Function to fetch page content
def fetch_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return BeautifulSoup(response.content, 'html.parser')
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

# Function to scrape and store products
def upsert_product(store_name, product_data):
    try:
        # Get store ID
        cursor.execute('SELECT "Id" FROM "Stores" WHERE "Name" = %s;', (store_name,))
        store_id = cursor.fetchone()
        if not store_id:
            print(f"Error: Store {store_name} not found.")
            return
        store_id = store_id[0]

        # Get or insert category ID
        category_id = upsert_category(cursor, product_data['category'])

        # Check for existing product
        cursor.execute(
            """
            SELECT "Id", "CurrentPrice" FROM "Products"
            WHERE "ProductUrl" = %s AND "StoreId" = %s;
            """,
            (product_data['link'], store_id)
        )
        product = cursor.fetchone()

        if product:
            product_id, current_price = product
            if abs(float(current_price) - float(product_data['price'])) > 0.01:
                cursor.execute(
                    """
                    UPDATE "Products"
                    SET "CurrentPrice" = %s
                    WHERE "Id" = %s;
                    """,
                    (product_data['price'], product_id)
                )
                cursor.execute(
                    """
                    INSERT INTO "Prices" ("Value", "ProductId", "Date")
                    VALUES (%s, %s, NOW());
                    """,
                    (product_data['price'], product_id)
                )
        else:
            cursor.execute(
                """
                INSERT INTO "Products" ("Name", "CurrentPrice", "StoreId", "ImageUrl", "ProductUrl", "CategoryId")
                VALUES (%s, %s, %s, %s, %s, %s)
                RETURNING "Id";
                """,
                (
                    product_data['title'],
                    product_data['price'],
                    store_id,
                    product_data['image_url'],
                    product_data['link'],
                    category_id
                )
            )
            product_id = cursor.fetchone()[0]
            cursor.execute(
                """
                INSERT INTO "Prices" ("Value", "ProductId", "Date")
                VALUES (%s, %s, NOW());
                """,
                (product_data['price'], product_id)
            )
        conn.commit()
    except Exception as e:
        print(f"Error upserting product: {e}")
        conn.rollback()

# Function to scrape Sigma website
def scrape_sigma():
    base_url = "https://www.sigma-computer.com"
    main_page_url = f"{base_url}/home"
    main_soup = fetch_page(main_page_url)
    if not main_soup:
        return

    category_links = main_soup.select('div.sub-menu a.main-menu')
    for category_link in category_links:
        category_name = category_link.text.strip().lower()
        upsert_category(cursor, category_name)

        category_url = base_url + "/" + category_link['href']
        
        current_page_url = category_url + "&page=1"

        while True:
            soup = fetch_page(current_page_url)
            if not soup:
                break

            containers = soup.find_all('div', class_='product-item-container')
            for container in containers:
                anchor = container.find('a', href=True, title=True)
                title = anchor['title'] if anchor else "No title found"
                link = base_url + "/" + anchor['href'] if anchor else "No link found"
                price_span = container.find('span', class_='price-new')
                image_tag = container.find('img')
                image_url = base_url + "/" + image_tag['src'] if image_tag else "No image found"
                price = re.sub(r'[^\d.]', '', price_span.text.strip()) if price_span else None
                store_name = "Sigma Computer"

                if price:
                     add_to_cart_button = container.find('button', class_='addToCart')
                     if add_to_cart_button:
                        span_text = add_to_cart_button.find('span').text.strip().lower()
                        if "out of stock" not in span_text:
                            product_data = {
                                "title": title,
                                "price": price,
                                "link": link,
                                "image_url": image_url,
                                "category": category_name
                            }
                            upsert_product(store_name, product_data)
                        else:
                            print(title)

            pagination = soup.find('ul', class_='pagination')
            next_page = pagination.find('a', rel='next') if pagination else None
            if next_page:
                current_page_url = next_page['href']
            else:
                break

def scrape_elnour():
    base_url = "https://elnour-tech.com/en/"
    main_soup = fetch_page(base_url)
    if not main_soup:
        return

    category_links = main_soup.select('.menu-item.menu-item-type-taxonomy.menu-item-object-product_cat')
    for category_link in category_links:
        category_name = category_link.text.strip().lower()
        upsert_category(cursor, category_name)
        category_url = category_link.select_one('a').get('href') if category_link.select_one('a') else None
        if not category_url:
            continue

        page_num = 1
        while True:
            page_url = f"{category_url}/page/{page_num}"
            soup = fetch_page(page_url)
            if not soup:
                break

            products = soup.select('.wd-product.product-grid-item')
            for product in products:
                add_to_cart_btn = product.select_one('.add_to_cart_button')
                if add_to_cart_btn:
                    title = product.select_one('.wd-entities-title').text.strip() if product.select_one('.wd-entities-title') else None
                    price_text = product.select_one('bdi').text.strip() if product.select_one('bdi') else None
                    price = re.sub(r'[^\d.]', '', price_text) if price_text else None
                    link = product.select_one('.wd-entities-title a').get('href') if product.select_one('.wd-entities-title a') else None
                    img_url = product.select_one('.product-wrapper img').get('src') if product.select_one('.product-wrapper img') else None
                    store_name = "Elnour Tech"

                    if price:
                        product_data = {
                            "title": title,
                            "price": price,
                            "link": link,
                            "image_url": img_url,
                            "category": category_name
                        }
                        upsert_product(store_name, product_data)

            next_page = soup.select_one('a.page-numbers.next')
            if next_page:
                page_num += 1
            else:
                break

def scrape_and_store(store_names):
    with conn:
        with conn.cursor() as cursor:
            print("Upserting stores...")
            store_ids = {name: upsert_store(cursor, name) for name in store_names}
            conn.commit()

def main():
    websites = {
        "sigma": scrape_sigma,
        "elnour": scrape_elnour
    }
    stores = ["Sigma Computer", "Elnour Tech"]
    scrape_and_store(stores)
    with ThreadPoolExecutor() as executor:
        future_to_website = {executor.submit(scraper): name for name, scraper in websites.items()}
        for future in future_to_website:
            website = future_to_website[future]
            try:
                future.result()
            except Exception as e:
                print(f"Error scraping {website}: {e}")

if __name__ == "__main__":
    main()

conn.close()
# Out:
# Upserting stores...
# MSI MAG X870 Tomahawk WiFi Gaming Motherboard  AMD Ryzen 9000 8000 7000 Series Processors  AM5  DDR5  PCIe 5.0  M.2 Gen5  SATA 6Gb s  USB 40Gbps  HDMI DP  Wi-Fi 7  Bluetooth 5.4  5Gbps LAN  ATX
# MSI PRO X870-P WIFI Motherboard  ATX - Supports AMD Ryzen 9000   8000   7000 Processors  AM5 - 60A SPS VRM  DDR5 Memory Boost 8200 MT s  OC   PCIe 5.0 x16   4.0 x16  M.2 Gen5  Wi-Fi 7  5G LAN
# ASUS ProArt X870E-CREATOR WiFi AMD AM5 X870E ATX Motherboard PCIe   5.0 x16 Slots with Full Support for Next-gen GPUs  16 2 2 Power Stages  DDR5  Dual USB4    10 Gb   2.5 Gb LAN  WiFi 7  Four M.2 Slots
# ASUS PRIME B650M-A II-CSM Micro-ATX motherboard with DDR5  PCIe 5.0 M.2  2.5Gb Ethernet  DisplayPort  HDMI    VGA  rear USB 3.2 Gen 2  front USB 3.2 Gen 1 Type-C    BIOS FlashBack     Aura Sync
# ASUS ROG Strix B650-A Gaming WiFi 6E AM5  LGA1718  Ryzen 7000 Motherboard 12 2 Power Stages DDR5 3xM.2 Slots PCIe   4.0  2.5G LAN WiFi 6E USB 3.2 Gen 2x2 Type-C   Port
# ASUS TUF GAMING B760M-E D4 Intel B760 LGA 1700 mATX Gaming Motherboard  DDR4  PCIe 4.0  2x M.2  10 1 DrMOS  2.5Gb Ethernet  M.2 for Wi-Fi Ready  DisplayPort  HDMI  USB 3.2 Gen 2  Arua Sync RGB
# ASUS PRIME H610M-A D4-CSM H610  LGA 1700  mic-ATX motherboard with DDR4  PCIe 4.0  dual M.2 slots  Intel 1 Gb Ethernet  DisplayPort  HDMI  D-Sub  USB 3.2 Gen 2 ports  SATA 6 Gbps  Addressable Gen 2 headers  and Aura Sync
# ASUS TUF GAMING X870-PLUS WIFI AMD Socket AM5  4 DDR5 memory slots  up to 192GB   PCIe 5.0 support  Wi-Fi 7  and high-definition 7.1 audio
# ASUS ROG STRIX X870E-E GAMING WIFI AMD AM5 socket  supports up to 192GB DDR5 memory  5 M.2 slots  Wi-Fi 7  high-quality ROG SupremeFX 7.1 audio
# ASUS ROG CROSSHAIR X870E HERO   AMD AM5 socket  supports up to 192GB DDR5 RAM  dual PCIe 5.0 x16 slots  5 M.2 slots  with Wi-Fi 7   Bluetooth 5.4
# ASUS ProArt X670E-CREATOR WiFi AMD X670 AM5 Ryzen    Desktop 9000 8000   7000 ATX Motherboard  16 2 Power Stages  PCIe   5.0 Ready  DDR5 Support  USB4    10 Gb   2.5 Gb LAN  WiFi 6E  Four M.2 Slots
# GIGABYTE Z790 Eagle AX LGA 1700 Intel Z790 ATX Motherboard with DDR5  M.2  PCIe 5.0  USB 3.2 Gen2X2 Type-C  Intel Wi-Fi 6E  2.5GbE LAN  Q-Flash Plus  EZ-Latch
# Asus PRIME B550M-K ARGB
# Asus TUF GAMING B760M-PLUS WIFI II
# Gigabyte Z790 AERO G
# Gigabyte B650M S2H
# Gigabyte B650 EAGLE AX
# Gigabyte B650 AORUS ELITE AX ICE
#  GIGABYTE Z790 D AC LGA 1700 Intel Z790 ATX Motherboard DDR5
# GIGABYTE Z790 AORUS ELITE AX LGA 1700 DDR5
# ASUS TUF GAMING B650M-E WIFI
# GIGABYTE B650 UD AC  rev. 1.0  AM5 LGA 1718 AMD B650 ATX Motherboard DDR5  PCIe 4.0 M.2  PCIe 4.0  USB 3.2 Gen2x2 Type-C  GbE LAN
# ASUS PRIME B760M-A D4  LGA 1700  mATX motherboard  PCIe 4.0  two M.2 slots  Realtek 2.5Gb Ethernet  DisplayPort  Dual HDMI    SATA 6 Gbps  rear USB 3.2 Gen 2  front USB 3.2 Gen 1 Type-C    Aura Sync
# MSI AMD B550 MAG TOMAHAWK MAX WIFI
# ASUS PRIME B650-PLUS
# ASUS PRIME X670-P-CSM
# ASUS PRIME B650M-A
# ASUS PRIME H510M-K R2.0
# GIGABYTE B450M-S2H
# Gigabyte X670 GAMING X AX
# Gigabyte Z790M AORUS ELITE.
# GIGABAYT-AMD-B650 AORUS PRO AX
# GIGABYTE X670E AORUS MASTER AM5 LGA 1718 AMD X670E EATX Motherboard DDR5  Quad M.2  PCIe 5.0  USB 3.2 Gen2X2 Type-C  Intel WiFi 6E  Intel 2.5GbE LAN  Q-Flash Plus  EZ-Latch Plus
# GIGABYTE Z790 AORUS ELITE X AX
# GIGABYTE Z790 AORUS MASTER X LGA 1700 DDR5 Motherboard     5 M.2  PCIe 5.0  USB 3.2 Type-C  Wi-Fi 7  10GbE LAN  Q-Flash Plus  EZ-Latch Plus
# GIGABYTE Z790 AORUS MASTER X LGA 1700 DDR5 Motherboard     5 M.2  PCIe 5.0  USB 3.2 Type-C  Wi-Fi 7  10GbE LAN  Q-Flash Plus  EZ-Latch Plus
# GIGABAYT-INTEL-Z790 GAMING X AX
# GIGABYTE B760 DS3H DDR4 LGA 1700 Intel B760 ATX Motherboard
#  MSI AMD MAG B650 TOMAHAWK WIFI Supports AMD Ryzen    8000  7000 Motherboard
# ASUS INTEL-PRIME Z790-P WIFI  LGA1700 Z790 USB3.2 G
# ASUS AMD TUF GAMING X670E-PLUS DDR5
# ASUS INTEL ROG STRIX Z790-A GAMING WIFI
# ASUS Prime B760-PLUS D4  an Intel   B760 LGA 1700 ATX motherboard with PCIe 5.0  three PCIe 4.0 M.2 slots  DDR4  Realtek 2.5Gb Ethernet  DisplayPort  VGA  HDMI    SATA 6 Gbps  USB 3.2 Gen 2x2 Type-C    front USB 3.2 Gen 1 Type-C    Thunderbolt
# ASUS INTEL ROG STRIX Z790-H Gaming  WiFi 6E LGA 1700 motherboard DDR5 .
# COLORFUL INTEL-H510M-K M.2 V20
# GIGABAYT Motherboard AMD-B650M H
# GIGABAYT Motherboard  AMD X670E AORUS MASTER
# GIGABYTE Motherboard INTEL B760M GAMING X DDR4
# ASUS TUF GAMING B760-PLUS WIFI DDR5.
# MSI MOTHERBOARD INTEL B660M-P-PRO DDR4
# ASUS PRIME A620M-K micro-ATX motherboard  DDR5  PCIe 4.0 Graphics card and PCIe 4.0 M.2 support  HDMI     VGA  USB 3.2 Gen 1 Type-A  SATA 6 Gbps  Two-Way AI Noise Cancelation  Aura Sync
# ASUS INTEL H610M PRIME-K DDR5
# ASROCK INTEL B660M PRO RS-DDR4
# ASROCK INTEL B660M HDV-DDR4
# ASROCK AMD B450M PRO4 DDR4
# ASROCK AMD A520M DDR4 HVD
# ASROCK INTEL H610M-HDV M.2
# ASUS Motherboard AMD-PRIME A520M-A II
# ASUS Motherboard AMD X670 PRIME P-WIFI-AM5-DDR5
# ASUS ROG Strix B760-A Gaming WiFi D4 Intel B760  13th and 12th Gen  LGA1700 white ATXmotherboard
# ASUS ROG Strix X670E-A Gaming WiFi 6E Socket AM5  LGA 1718  Ryzen 7000 Gaming Motherboard
# ASUS TUF GAMING B650M-E Socket AM5  LGA 1718  Ryzen 7000 mATX gaming motherboard
# ASUS TUF Gaming B650-PLUS WiFi Socket AM5  LGA 1718  Ryzen 7000 ATX Gaming Motherboard
# ASUS TUF Gaming X670E-PLUS WiFi 6E Socket AM5  LGA 1718  Ryzen 7000 ATX Gaming Motherboard 16 Power Stages  PCIe   5.0  DDR5 Memory  Four M.2 Slots 2.5 Gb LAN USB 4  Aura RGB Lighting
# MSI MOTHERBOARD INTEL PRO H610M-E DDR4
#  GIGABYTE Motherboard Gaming H410M S2 V3
# GIGABYTE Motherboard H610M S2 DDR4
# ASUS TUF GAMING B660M-PLUS D4 motherboard
# ASUS TUF GAMING B660M-PLUS D4 motherboard WIFI
# ASUS motherboard ProArt B660-CREATOR D4
# Gigabyte Intel B660M GAMING AC DDR4 Motherboard
#  GIGABYTE Motherboard B660M GAMING X DDR4
# GIGABYTE    Motherboard Intel   B560M H
# MB GIGABYTE    Intel H610M S2H DDR4
# MB GIGABYTE    AMD A320M-S2H
# Gigabyte Intel B660M DS3H AX DDR4 Motherboard
# COLORFUL BATTLE-AX B660M-HD DELUXE V20  LGA 1700   M.2 SLOTX1   GAMING AUDIO
# Colorful H610M-D M.2 V20 Motherboard
# MSI MAG B660M BAZOOKA DDR4 LGA 1700 Intel B660 SATA 6Gb s Micro ATX Intel Motherboard
# Intel   LGA 1700 socket  Ready for 12th Gen Intel   processors Ultrafast connectivity   PCIe 4.0  Intel   1 Gb Ethernet  rear USB 3.2 Gen 2 Type-A and front USB 3.2 Gen 1 Type-A and Type-C   ASUS OptiMem II  Careful routing of traces and vias
# ASUS H610M PRIME K DDR4 Socket LGA 1700
# GIGABYTE Intel   Z690 Creator Motherboard with unique VisionLINK I O design  Next Gen Memory DDR5  WIFI6 802.11ax and Intel   2.5GbE LAN  PCIe 5.0 x16 slot  4 x NVMe PCIe 4.0 x4 M.2 Connectors  USB 3.2 Gen 2x2 Type-C
# GIGABYTE B660M D2H DDR4  rev. 1.0
# GIGABYTE AMD B550 AORUS Motherboard with Twin 12 2 Phases Digital VRM  Enlarged Surface Heatsinks  PCIe 4.0 x16 Slot  Dual PCIe 4.0 3.0 x4 M.2 with One Thermal Guard  2.5GbE LAN  RGB FUSION 2.0  Q-Flash Plus
# GIGABYTE AMD B450 AORUS Motherboard with Hybrid Digital PWM  M.2 with Thermal Guard  GIGABYTE Gaming LAN with 25KV ESD Protection  Anti-sulfur Design  CEC 2019 ready  RGB FUSION 2.0
# GIGABYTE Intel   B660 AORUS Motherboard with 12  1 1 Twin Hybrid Phases Digital VRM Design   DDR5 MEMORY Design  Fully Covered Thermal Design   2 x PCIe 4.0 M.2 with Thermal Guard  Intel   2.5GbE LAN  WIFI 6 802.11ax  Rear USB 3.2 Gen 2x2 Typ
# GIGABYTE Intel   B660 AORUS Motherboard with 12  1 1 Twin Hybrid Phases Digital VRM Design  Fully Covered Thermal Design   2 x PCIe 4.0 M.2 with Thermal Guard  Intel   2.5GbE LAN  Rear USB 3.2 Gen 2x2 Type-C    RGB FUSION 2.0  Q-Flash Plus
# GIGABYTE Intel   H510M DS2V Ultra Durable Motherboard with 6 2 Phases Digital VRM  PCIe 4.0  Design  Realtek 8118 Gaming LAN  Anti-Sulfur Resistor  Smart Fan 6
# Gigabyte Z690 AORUS ELITE AX  rev. 1.x  Socket 1700 DDR5 Motherboard
# GIGABYTE Intel   Z690 Creator Motherboard with unique VisionLINK I O design  WIFI6 802.11ax and Intel   2.5GbE LAN  PCIe 5.0 x16 slot  4 x NVMe PCIe 4.0 x4 M.2 Connectors  USB 3.2 Gen 2x2 Type-C
#  Intel   B660 Motherboard with 6 2 1 Phases Hybrid Digital VRM with MOS Heatsink     2 x PCIe 4.0 M.2 with Thermal Guard  2.5GbE LAN  WIFI 6 802.11ax      Rear USB 3.2 Gen 2 Type-C    RGB FUSION 2.0  Q-Flash Plus
# MSI PRO B660M-E DDR4   LGA 1700 Intel B660 SATA 6Gb s Micro ATX Intel Motherboard
# MSI PRO B660-A DDR4 LGA 1700 Intel B660 SATA 6Gb s Micro ATX Intel Motherboard
# MSI MAG B660M Mortar DDR4 Gaming Motherboard  mATX  12th Gen Intel Core  LGA 1700 Socket  DDR4  PCIe 4  2.5G LAN  M.2 Slots
# ASUS Intel   Z690  LGA 1700  ATX motherboard with PCIe   5.0  three M.2 slots  14 1 DrMOS  DDR4  HDMI    DisplayPort     Intel   WiFi 6  2.5 Gb Ethernet  USB 3.2 Gen 2x2 Type-C    front USB 3.2 Gen 1 Type-C    Thunderbolt    4 header and Aura Sync RG
# ASUS Intel   B660  LGA 1700  ATX motherboard with 8 power stages  PCIe 4.0 slots  three M.2 slots  Realtek 2.5Gb Ethernet  DisplayPort  HDMI    D-Sub  rear USB 3.2 Gen 2x2 Type-C    front USB 3.2 Gen 1 Type-C    Aura Sync
# GIGABYTE Intel   H410M Ultra Durable Motherboard with GIGABYTE Gaming GbE LAN  PCIe Gen3 x4 M.2  HDMI   DVI-D  D-Sub Ports for Multiple Display  Anti-Sulfur Resistor  Smart Fan 5
# GIGABYTE Intel   H510M Ultra Durable Motherboard with 6 2 Phases Digital VRM  PCIe 4.0  Design  Realtek 8118 Gaming LAN  3 Display Interfaces Support   Anti-Sulfur Resistor   Smart Fan 6
# GIGABYTE Intel   Z690 UD AX DDR4  rev. 1.x  Motherboard
# GIGABYTE Intel   Z690 GAMING X DDR4  rev. 1.0  Motherboard
# GIGABYTE Intel   Z690M DS3H DDR4  rev. 1.0  Motherboard
# GIGABAYT Intel   B660 AORUS MASTER  rev. 1.x  Motherboard
# ASUS PRIME A520M-K  AMD A520  Ryzen AM4  micro ATX motherboard with M.2 support  1 Gb Ethernet  HDMI D-Sub  SATA 6 Gbps  USB 3.2 Gen 1 Type-A
# ASUS AMD B550M-K  Ryzen AM4  micro ATX motherboard with dual M.2  PCIe 4.0  1 Gb Ethernet  HDMI D-Sub DVI  SATA 6 Gbps  USB 3.2 Gen 2 Type-A
# Asus Prime A520M-E - AMD A520  Ryzen AM4  micro ATX motherboard with M.2 support  1 Gb Ethernet  HDMI DVI D-Sub  SATA 6 Gbps  USB 3.2 Gen 2 Type-A
# ASUS TUF GAMING B660M-E D4  LGA 1700  mATX motherboard
# ASUS PRIME B660M-K D4  LGA 1700  mATX motherboard
# AMD B550 AORUS Motherboard with True 12 2 Phases Digital VRM  Fins-Array Heatsink  Direct-Touch Heatpipe  Dual PCIe 4.0 3.0 x4 M.2 with Thermal Guards  2.5GbE LAN  RGB FUSION 2.0  Q-Flash Plus
# GIGABYTE A520M DS3H AC
# ASUS ROG Strix Z690-F Gaming WiFi 6E LGA1700 Intel 12th Gen  ATX Gaming Motherboard PCIe 5.0 DDR5 16 1 Power Stages 2.5Gb LAN BT v5.2 Thunderbolt 4 4xM.2 Front Panel USB 3.2 Gen 2x2 Type-C Connector
# ASUS ROG Strix Z690-G Gaming WiFi 6E LGA 1700 Intel 12th Gen Micro ATX Gaming Motherboard- PCIe 5.0  DDR5  14 1 Power Stages  2.5 Gb LAN  Bluetooth v5.2  Thunderbolt 4  3xM.2 NVMe SSD
# ASUS TUF Gaming Z690-Plus WiFi D4 LGA1700 Intel 12th Gen  ATX gaming motherboard PCIe 5.0  DDR4 4xM.2 NVMe SSD 14 2 power stages WiFi 6 2.5Gb LAN front USB 3.2 Gen 2 Type-C
# ASUS TUF Gaming Z690-PLUS WiFi D4 LGA 1700 ATX Motherboard  15 DrMOS  PCIe 5.0  DDR4 RAM  Four M.2 Slots  Intel WiFi 6  Front USB 3.2 Gen 2 Type-C
# ASUS Prime Z690-A LGA 1700 Intel 12th  ATX Motherboard  16 1 DrMOS PCIe 5.0 DDR5 4X M.2  Intel 2.5 Gb LAN USB 3.2 Gen 2 Front Panel Type-C
# ASUS Prime Z690M-Plus D4 LGA 1700 Intel 12th Gen  microATX motherboard  PCIe 5.0 DDR4 10 1 Power Stages 3x M.2 1Gb LAN USB 3.2 Gen 2x2 Type-C front USB 3.2 Gen 1 Type-C
# ASUS ROG Strix B550-F Gaming  WiFi 6  AMD AM4 Zen 3 Ryzen 5000   3rd Gen Ryzen ATX Gaming Motherboard  PCIe 4.0  2.5Gb LAN  BIOS Flashback  HDMI 2.1  Addressable Gen 2 RGB Header and Aura Sync
# AMD B550  Ryzen AM4  micro ATX gaming motherboard with PCIe 4.0  dual M.2  10 DrMOS power stages  Intel   WiFi 6  2.5 Gb Ethernet  HDMI  DisplayPort  SATA 6 Gbps
# AMD B550  Ryzen AM4  micro ATX gaming motherboard with PCIe 4.0  dual M.2  10 DrMOS power stages  2.5 Gb Ethernet  HDMI  DisplayPort  SATA 6 Gbps  USB 3.2 Gen 2 Type-A and Type-C  and Aura Sync RGB lighting support
# AMD B550  Ryzen AM4  micro ATX motherboard with dual M.2  PCIe 4.0  1 Gb Ethernet  HDMI D-Sub DVI  SATA 6 Gbps  USB 3.2 Gen 2 Type-A
# AORUS Z690 ELITE DDR4  rev. 1.0  LGA1700 Support for 12th Generation Intel   Core
# AORUS B550 ELITE AX V2  rev. 1.0  rev. 1.1 with 12 2 Phases Digital Twin Power Design
# AORUS Z690 MASTER  rev. 1.x  LGA1700  Intel Z690  ATX  DDR5  Quad M.2  PCIe 5.0  USB 3.2 Gen2X2 Type-C Intel WiFi 6E  AQUANTIA 10GbE LAN Intel Thunderbolt 4  Gaming Motherboard
# GIGABYTE Z690 GAMING X DDR4  rev. 1.0  PCIe 5.0 Design  Fully Covered Thermal Design  4 x PCIe 4.0 M.2
# GIGABYTE X570S UD  rev. 1.0  Motherboard with Twin 12 2 Phases Digital VRM Solution with 50A DrMOS
# GIGABYTE X570S AORUS PRO AX  rev. 1.0  AMD Socket AM4  support for AMD Ryzen MOTHERBOARD
# GIGABYTE X570S AORUS ELITE AX  rev. 1.1  AMD Socket AM4  support for AMD Ryzen
# GIGABYTE Aero G AMD X570S AM4 ATX DDR4-SDRAM Motherboard
#  GIGABYTE B560M H  rev. 1.x
# MSI B550M PRO-VDH Dual AMD Socket AM4 MOTHERBOARD
# MSI PRO Z690-A DDR5 ProSeries Motherboard ATX 12th Gen Intel Core LGA 1700 Socket PCIe 4 CFX M.2 Slots Wi-Fi 6E
# MSI PRO Z690-A DDR4
# MSI B560M PRO-E LGA 1200 Intel B560 SATA 6Gb s Micro ATX Intel Motherboard
# MSI H510M-A PRO Mirco-ATX Gen 4 Supports 10th Gen Intel   Core     11th Gen Intel   Core     Pentium   Gold and Celeron   processors for LGA 1200 socket
# MSI AMD A520M-A PRO Supports DDR4 Memory  up to 4600 OC  MHz MOTHERBOARD
# MSI H510M INTEL PRO Supports DDR4 Memory  up to 3200 Max  MHz MOTHERBOARD
# MSI H510M INTEL BOMBER MOTHERBOARD LGA1200
# GIGABYTE MOTHERBOARD Z590 AORUS ELITE  rev. 1.0 LGA 1200 Intel Z590 ATX Triple M.2 PCIe 4.0 USB 3.2 Gen2X2 Type-C 2.5GbE LAN
# GIGABYTE MOTHERBOARD Z590 VISION D  rev. 1.0
# GIGABYTE MOTHERBOARD A520M H  rev. 1.x  Ultra Durable PCIe 3.0 x4 M.2  RGB FUSION 2.0  Smart Fan 5  Q-Flash Plus
# GIGABYTE MOTHERBOARD A520M DS3H  rev. 1.x  PCIe 3.0 x4 M.2  RGB FUSION 2.0  Smart Fan 5  Q-Flash Plus
# ASUS ROG MAXIMUS XIII HERO Intel  Z590 ATX GAMING MOTHERBOARD
# ASUS ROG Maximus XIII Extreme Intel   Z590 EATX WiFi 6E  802.11ax  and Aura Sync RGB lighting
# ASUS TUF GAMING B550M-E WIFI MICRO ATX Aura Sync RGB lighting support
# ASUS TUF GAMING B550M  WI-FI  ZAKU EDITION MICRO ATX
# ASUS ROG Strix X570-I Gaming AMD Aura Sync RGB mini-ITX
# ASUS ROG STRIX B560-E GAMING WIFI
# Asrock Intel B560M Pro4 DDR4 OC MotherBoard
# Asrock Intel B560 Pro4 DDR4 OC MotherBoard  LGA1200
# Asrock Intel B560M Steel Legend DDR4 OC MotherBoard
# Asrock Intel B560 Steel Legend DDR4 OC MotherBoard
# Asrock Intel Z590M Phantom Gaming 4 DDR4 OC
# Asrock Intel Z590 Phantom Gaming 4 DDR4 OC MotherBoard
# Asrock Z590 Steel Legend Intel DDR4 OC Motherboard
# Asrock Z590 Taichi intel DDR4 MotherBoard
# Asrock B550M Phantom Gaming 4 AMD AM4 Socket Ryzen DDR4 OC
# Asrock B550 Phantom Gaming 4 AMD AM4 Socket Ryzen DDR4 OC
# GIGABYTE Intel   H410M S2  rev. 1.x Ultra Durable Motherboard
# Intel   B560  LGA 1200  mATX motherboard with PCIe   4.0  two M.2 slots  8 power stages  Intel   1 Gb Ethernet  HDMI  D-Sub  rear USB 3.2 Gen 1  TPM header RGB header
# ASUS TUF GAMING INTEL B560M-E mATX
# ASUS PRIME INTEL micro ATX H570M-PLUS
# ASUS TUF GAMING INTEL mATX B560M-PLUS
# ASUS TUF INTEL mATX GAMING B560M-PLUS WIFI
# ASUS ROG STRIX INTEL ATX B560-A GAMING WIFI
# ASUS ROG STRIX INTEL micro ATX B560-G GAMING WIFI
# ASUS ROG STRIX INTEL B560-F  ATX GAMING WIFI
# ASUS TUF GAMING INTEL ATX H570-PRO WIFI
# ASUS TUF INTEL ATX GAMING Z590-PLUS WIFI
# ASUS ROG STRIX INTEL Z590-E GAMING WIFI
# ASUS INTEL PRIME H510M-K micro ATX MOTHERBOARD
# ASUS INTEL PRIME H510M-E micro ATX MOTHERBOARD
# ASUS Intel PRIME H510M-D micro ATX MOTHERBOARD
# GIGABYTE MOTHERBOARD INTEL H410M H  rev. 1.x
# GIGABYTE Intel   Ultra B460M DS3H V2  rev. 1.0  Durable Motherboard with Intel   GbE with cFosSpeed  PCIe Gen3 x4 M.2   HDMI   DVI-D  D-Sub Ports for Multiple Display  Anti-Sulfur Resistor  Smart Fan 5  RGB FUSION 2.0
# GIGABYTE MOTHERBOARD INTEL  Z590 AORUS XTREME  rev. 1.0
# GIGABYTE MOTHERBOARD INTEL B560M AORUS PRO  rev. 1.0
# GIGABYTE MOTHERBOARD B560M DS3H AC  rev. 1.0
# MSI MOTHERBOARD MEG X570 ACE RGB
# MSI MOTHERBOARD AMD MPG X570 GAMING EDGE WIFI RGB
# MSI MOTHERBOARD AMD A320M PRO-VH
# MSI MOTHERBOARD INTEL Z590-A PRO
# MSI MOTHERBOARD INTEL H510I PRO WIFI
# MSI MOTHERBOARD MAG B560M MORTAR WIFI
# MSI MOTHERBOARD MAG B560M BAZOOKA
# MSI MOTHERBOARD MAG B560 TORPEDO
# MSI MOTHERBOARD MAG B560 TOMAHAWK WIFI
# MSI INTEL B560M PRO motherboard
# MSI B560M-A PRO MATX motherboard
# MSI MOTHERBOARD B560M PRO-VDH WIFI
# GIGABYTE A520 AMD AORUS ELITE  rev. 1.0
# GIGABYTE Z590 AORUS MASTER  rev. 1.0
# GIGABYTE Z590 VISION G  rev. 1.0
# GIGABYTE Z590 AORUS ULTRA  rev. 1.0
# GIGABYTE Z590 AORUS ELITE AX  rev. 1.0
# GIGABYTE B560M AORUS ELITE  rev. 1.0
# Intel   H510M S2H Ultra Durable Motherboard with 6 2 Phases Digital VRM  PCIe 4.0  Design  Realtek 8118 Gaming LAN  4 Display Interfaces Support   Anti-Sulfur Resistor   Smart Fan 6
# GIGABYTE Z590 AORUS PRO AX  rev. 1.0
# GIGABYTE Z590 GAMING X  rev. 1.0  GAMING X
# ASUS ROG Strix GeForce RTX 4070 Ti SUPER 16GB GDDR6X OC Edition
# ASUS ROG Strix GeForce RTX 4080 SUPER 16GB GDDR6X OC Edition
# ASUS TUF Gaming GeForce RTX 4080 SUPER 16GB GDDR6X OC Edition
# ASUS TUF Gaming GeForce RTX 4070 Super OC Edition 12GB
# GeForce RTX    4070 SUPER WINDFORCE OC 12G GDDR6
# ZOTAC GeForce RTX 3050 6GB GDDR6 Solo
# GALAX GeForce RTX    4060 Ti 8GB EX 1-Click OC
# MSI GeForce RTX    4060 VENTUS 2X BLACK 8G OC
# ASUS Dual GeForce RTX    4070 SUPER OC Edition 12GB GDDR6X  PCIe 4.0  12GB GDDR6X  DLSS 3  HDMI 2.1a  DisplayPort 1.4a  2.5-slot design  Axial-tech fan design  0dB technology
# Gigabyte GeForce RTX    3050 EAGLE OC 6G.
# Gigabyte GeForce RTX    4080 SUPER GAMING OC 16G.
# Gigabyte GeForce RTX    4080 SUPER AERO OC 16G
# INNO3D-GEFORCE RTX 2060 SUPER TWIN X2 OC
#  Gigabyte-RTX4090 WINDFORCE OC 24GB DDR6X  TRIPLE FAN
# Gigabyte GeForce RTX    4060 WINDFORCE OC 8G DDR6  DUAL FAN
# AORUS GeForce RTX    4080 SUPER MASTER 16G
# Gigabyte-RTX4060TI AERO OC 8GB DDR6  Triple Fan -White
#  ASUS Dual GeForce RTX    4070 SUPER 12GB GDDR6X with two powerful Axial-tech fans and a 2.56-slot design for broad compatibility
#  ZOTAC GAMING GeForce GTX 1650 AMP Core GDDR6 ZT-T16520J-10L
# GALAX GeForce GT 730 4GB DDR3 4GB DDR3 128-Bit HDMI - DVI - VGA
# GALAX GeForce RTX    4060 1-Click OC 2X 8GB GDDR6 128-bit DP 3 HDMI 2.1 DLSS 3
# GIGABYTE RTX4070TI AORUS ELITE 12GB DDR6X  Triple Fan  GV-N407TAORUS E-12GD
# INNO3D RTX 4070 TWIN X2 OC  2505MHz 21Gbps  12GB GDDR6X 192-bit DP DP DP HDMI VA52N
# INNO3D- RTX 2060 TWIN X2  1680Mhz  14.0Gbps 6GB GDDR6  192-bit DPx3 HDMI VA15L
# COLORFUL iGame GeForce RTX 3080 Ultra W OC 12G LHR-V
# GIGABAYT NVIDIA GeForce RTX    3060 12GB GDDR6
#  GIGABAYT NVIDIA-GV-N3060EAGLE OC-12GD  rev. 2.0
# Gigabyte AORUS GeForce RTX 4070 MASTER 12GB Graphics Card - 12GB DDRX6 21Gbps 192bit Triple Fan
# ZOTAC GAMING GeForce GTX 1650 AMP Core 4GB GDDR6
# ASUS- ProArt GeForce RTX    4060 Ti 16GB OC Edition GDDR6 Graphics Card  PCIe 4.0  16GB GDDR6  DLSS 3  HDMI 2.1a  DisplayPort 1.4a
# ASUS ProArt GeForce RTX    4070Ti OC edition 12GB GDDR6X
# ASUS ProArt GeForce RTX    4080 16GB OC Edition GDDR6X Graphics Card  PCIe 4.0  16GB GDDR6X  DLSS 3  HDMI 2.1a  DisplayPort 1.4a
# DELL Inspiron 3505 RYZEN 5 3450U RAM 8GB 256 SSD 15FHD TOUCH INTEGRATED AMD REDEON VEGA 8 GRAPHICS WIN 10
# Lenovo Legion 5 15ARH05H Ryzen 5 4600H RAM 16GB 256GB SSD 1TB HDD 15.6 FHD IPS 120Hz GTX 1660 Ti 6GB WIN 10
# Asus TUF FX505DT-HN536 Gaming Laptop AMD Ryzen    7 3750H 8GB DDR4 512GB ssd 15.6 Full HD NVIDIA GeForce GTX 1650 4GB
# HP OMEN Laptop - 15-dh1020ne Core    i7-10750H RAM 16 GB 256 SSD 1TB HDD 15.6 FHD 144 Hz IPS GTX 1660 Ti
# LENOVO IdeaPad 3 15IML05 Core i3-10110U RAM 4GB 1TB HDD 15.6 FHD TN GeForce MX130 2GB GDDR5
# NOTEBOOK-LENOVO-CI7-LEGION 5- 82JH003VAX  I7-11800H  8C 16T -RAM 16G  2 8 -SSD 1T Gen4-RTX3060 130w-15.6-FHD-IPS-165Hz-100  sRGB- 60Wh - 230W -RGB Backlit-Arabic
# LENOVO IdeaPad 5 15ITL05 Core i5-1135G7 RAM 8GB 256GB SSD 1TB HDD 15.6 FHD TN Intel Iris Xe Graphics
# LENOVO IdeaPad Gaming 3 15ARH05 Ryzen 7 4800H RAM 16GB 512GB SSD 1TB HDD 15.6 FHD IPS 120Hz GTX 1650 Ti 4GB WIN 10
# LENOVO IdeaPad 5 15ITL05 Core i5-1135G7 RAM 8GB 256GB SSD 1TB HDD 15.6 FHD TN Intel Iris Xe Graphics
# LENOVO ideapad L340-15API Ryzen 5 3500U RAM 8GB 1TB HDD 15.6 HD TN AMD Radeon Vega 8 Graphics
# LENOVO ideapad L3 15IML05 Core i7-10510U RAM 8GB 256GB SSD 1TB HDD 15.6 FHD TN GeForce MX330 2GB GDDR5
# Lenovo Legion 5 15IMH05 Core i7-10750H RAM 8GB 512GB SSD 15.6 FHD IPS 120Hz GTX 1650 Ti 4GB WIN 10
# MSI BRAVO 17 Ryzen 7 4800H RAM 16 256 SSD 1TB HDD 17.3 FHD 144Hz IPS RX 5500M 4GB win10
# LENOVO IdeaPad Gaming 3 15IMH05 Core i7-10750H RAM 16GB 256GB SSD 1TB HDD 15.6 FHD IPS 120Hz GTX 1650 Ti 4GB
# LENOVO IdeaPad 3 15ADA05 AMD 3020e RAM 4GB 1TB HDD 15.6 HD TN AMD SoC Platform GRAY
# LENOVO IdeaPad 5 15ITL05 Core i5-1135G7 RAM 8GB 512GB SSD 15.6 IPS Integrated Intel Iris Xe Graphics WIN 10
# DELL Vostro 3500 Core i3-1115G4 RAM 4GB 1TB HDD 15.6-inch HD 1366 x 768
# LENOVO IdeaPad 5 15ITL05 Core i7-1165G7 RAM 8GB 256GB SSD 1TB HDD 15.6 FHD IPS Integrated Intel Iris Xe Graphics
# LENOVO IdeaPad 5 15ITL05 Core i7-1165G7 RAM 8GB 256GB SSD 1TB HDD 15.6 FHD IPS Integrated Intel Iris Xe Graphics
# Lenovo Legion 5 15ARH05 Ryzen 7 4800H RAM 16GB 512GB SSD 1TB HDD 15.6 FHD IPS 120Hz GTX 1650 4GB WIN 10
# L avvento BG-56-B Laptop Backpack fits up to 15.6  - Black
# L avvento BG-57-B Laptop Backpack fits up to 15.6
# E-train  BG02B  Backpack Bag Fit Up to 15.6  - Black
# L   avvento Backpack Bag Discovery Laptop Anti-Theft     Up to 15.6        Black
# HP Pavilion Gaming Backpack 400 15.6         Black
# L avvento Discovery Backpack  BG74B  fit with Laptops up to 15.6   - Black
# L avvento Discovery Backpack fit laptops up to 15.6  with Padded Laptop compartment and two Zipper on the Front  Nylon  PU - Black
# HP OMEN Gaming Laptop Backpack  17.3 Inch  Black - K5Q03AA
# CAT BIG BACKPACK-BIG-BLACK
# Targus 15.6-inch Element Backpack  Black
# Lenovo 15.6    Laptop Everyday Backpack B510
# Lenovo 15.6 inch laptop Backpack B210 Grey
# Lenovo 15.6-inch Commuter Backpack Water-repellant   durable
# Lenovo 15.6    Urban Backpack B810  Black
# Lenovo 15.6    Urban Backpack B810  Blue
#  Lenovo Laptop Backpack B210 15.6 - Black
# Lenovo 15.6 Laptop Casual Backpack B210 BLUE
#  Lenovo Laptop Casual Backpack B210 15.6 - GX40Q17228 - Green-Row
# Lenovo Laptop Everyday Backpack B515 15.6 - Grey
# Lenovo Laptop Everyday Backpack B515 15.6 - Black - GX40Q75215
# HP - Value BackPack Bag - 15.6 K0B39AA ABB
# HP - Odyssey Backpack -15.6 Y5Y50AA - Black Blue
# HP - Odyssey Backpack - 15.6 X0R83AA Red-Black
# HP - Backpack Bag - 15.6 BH-60-9 Blue-Red
# HP - Backpack Bag - 15.6 BH-60-9 Blue-Yellow
# HP Commuter Backpack Bag - 15.6
# HP Pavilion Gaming Backpack 400 15.6
# HP Commuter Backpack Bag - 15.6
# LENOVO Laptop Shoulder Bag T210  15.6-Inch Laptop grey
# LENOVO Laptop Shoulder Bag T210  15.6-Inch Laptop black
# LENOVO Legion Recon 15.6 inch Gaming Backpack
# Seagate BarraCuda 2TB Internal Hard Drive HDD 2.5 Inch SATA 6 Gb s 5400 RPM 128MB Cache for Laptop ST2000LM015
# TOSHIBA L200 2.5 1TB 5400 RPM For Laptop Hard Disk SATA
# Seagate BarraCuda 1TB Internal Hard Drive HDD     2.5 Inch SATA 6 Gb s 5400 RPM 128MB Cache for  Laptop  ST1000LM048
# Western Digital Blue 2TB Hard Disk Drive - 5400 RPM SATA 6 Gb s 128MB Cache 2.5 Inch LAPTOP
# Western Digital 1TB Hard Disk Drive - 5400 RPM SATA 6 Gb s 128MB Cache 2.5 Inch  LAPTOP - WD10SPZX - Blue
# MSI GF63 Thin 10UC-Intel Core i5-10500H-nividia RTX3050 4GB GDDR6-8GB ddr4 3200-256GB NVMe PCIe-1TB  SATA  5400rpm-15.6
# MSI Modern 14 B5M-AMD Ryzen 5 5500U-AMD Radeon    Graphics-8GB ddr4 3200-256GB NVMe-14
# MSI GF63 THIN LAPTOP Core i7-11800H-GeForce   RTX3050 4GB-16GB DDR4 3200MHz-1TB HDD   256 SSD-15.6
#  MSI Modern 14 B11M-803XEG i5 1155G7 RAM8G HD512 SSD VGA INTEL 9S7-14D224-803
# MSI Modern 14 B5M AMD Ryzen 7 5700U-AMD Radeon    Graphics-DDR IV 8GB 3200-512GB NVMe-14
# MSI Modern 14 B11MOU Intel Core i3-1115G4 - UHD Graphics -4GB ddr4 3200MHz - 256GB NVMe - 14 FHD  1920 1080
# MSI Katana GF66 12UGS CORE i7 12700H Ram16GB DDR4 1TB SSD  RTX 3070 Ti 8GB 15.6inch FHD 240Hz Win 11
# MSI Pulse GL66 12UGK Intel Core i7-12700H - RTX3070  GDDR6 8GB - 16GB DDR4 3200MHZ - 1TB NVMe PCIe SSD - 15.6
# MSI Modern 14-B11MOL CORE i7-1165G7 RAM 8GB 512GB SSD 14.0
# MSI Modern 14 B11MOL Laptop Core i5- 1135G7 RAM 8GB 512GB SSD 14 Inches FHD IPS Intel Iris Xe Graphics
# MSI GS66 Stealth 10SF Core I7-10875H RAM 16GB 1TB SSD 15.6FHD IPS 240Hz RTX 2070 8GB Win10
# MSI MODERN 14 B10RBSW CORE I5 10210U RAM 8GB 512 SSD 14 INCH fhd MX350 2GB
# MSI Modern 14 B10MW 14D114 Core i5 10210U RAM 8GB 512GB SSD 14 inches FHD Intel UHD Graphics
# MSI Modern 14 B4MW 298 Ryzen 5 4500U RAM 8GB 256GB SSD 14inch FHD AMD Radeon Graphics
# MSI GF65 Thin 10UE-243 CORE i7-10750H RAM 16GB 1TB SSD 15.6 FHD 144Hz IPS RTX3060 6GB WIN10
# MSI GF65 Thin 10UE-244 CORE i5-10500H RAM 8GB 512GB SSD 15.6 FHD 144Hz IPS RTX3060 6GB WIN 10
# MSI GF63 10SCXR CORE i7-10750H RAM 8GB 256GB SSD 1TB HDD 15.6 FHD IPS 60Hz GTX1650 4GB
# MSI GF63 Thin 10UD-228 CORE i7-10750H RAM 16GB 256GB SSD 1TB HDD 15.6 FHD IPS 144Hz RTX3050 Ti 4GB WIN 10
# MSI GF63 Thin 10UD-234 CORE i5-10500H RAM 8G 256GB SSD 1T HDD 15.6 FHD IPS 144Hz RTX3050 Ti 4GB
# MSI GF65 THIN 9SD INTEL CORE I7-9750H RAM 16GB DDR4 HARD 512 SSD NVME VGA GTX 1660 TI 6GB
# Dell G15 5510 CORE I7 10870H RAM 8GB 512G SSD 15.6FHD 120HZ RTX 3050 4GB WIN 10
# Dell G15 5510 CORE I5 10500H RAM 8GB 512G SSD 15.6FHD 120HZ RTX 3050 4GB WIN 10
# Dell G15 5510 CORE I7 10870H RAM 16 GB 512G SSD 15.6FHD 120HZ RTX 3050 4GB WIN 10
# Lenovo Legion 5 Pro 16ACH6H Ryzen 7 5800H RAM 16 GB 1TB SSD 16 IPS 165Hz sRGB RTX 3060 6GB WIN 10
# Asus GV301QE-K5139T RYZEN 9 5900H RAM 16 GB RAM 8GB 3.4 WQUXGA RTX 3050 Ti 4GB Win10 black
# Asus ROG Strix G513QM-HQ243T Ryzen9 5900HX RAM 16GB 1TB SSD 15.6 WQHD RTX 3060 6GB
# Asus TUF Gaming F15 FX506HM-HN002T Core i7 11800H RAM 16GB 1TB SSD 15.6 FHD 144HZ RTX3060 6GB WIN 10
# MSI GF65 Thin 10UE Core i5 10500H RAM 8GB 512 SSD 15.6 FHD 144Hz IPS RTX 3060 6GB WIN 10
# Lenovo Legion 5 15ACH6 Ryzen 7 5800H RAM 16GB 512GB SSD 15.6 FHD IPS 165Hz sRGB RTX 3050 Ti 4GB WIN 10
# ASUS ROG Strix  G513 G513QE-HN119T Ryzen    7 5800H RAM 16GB 1TSSD 15.6 FHD IPS 144Hz RTX    3050 Ti 4GB WIN 10
# HP Pavilion Gaming Laptop 15-dk2044nia Core i7-11370H RAM 16 GB 256 GB SSD 1 TB HDD 15.6 FHD 144Hz IPS RTX 3050 4GB
# HP Pavilion Gaming Laptop 15-dk2022nia Core i7-11370H RAM 16GB 512 SSD 1 TB HDD 15.6 FHD 144 HzRTX 3050 4GB
# Lenovo Legion 5 15ITH6 Core i7-11800H RAM 16GB 512GB SSD 15.6 FHD IPS 165Hz RTX 3050 Ti 4GB
# Dell G15 5510 Core i7- 10870H RAM 16GB 512GB SSD 15.6 FHD 120Hz RTX 3060 6GB WIN 10
# ASUS TUF A15-FA506QM-HN005T AMD R7-5800H RAM 16GB 1TB SSD RTX 3060 6GB 15.6 FHD 144Hz Win10 Eclipse grey
# ASUS ROG Strix G15 G513QM-HN027T AMD Ryzen 7 5800H RAM 16 GB 1T SSD RTX 3060 6GB 15.6 Full HD IPS WIN10 -GRAY
# Asus  ROG  Zephyrus  G14  GA401QM-HZ077T AMD Ryzen7 5800HS RAM 16GB 1TB SSD RTX 3060 6G FHD 144Hz Win10-Eclipse Grey
# ASUS TUF Gaming-A15 FA506IV-AL031T AMD R7-4800H- RAM 16GB-1TBSSD-RTX 2060 6GB-15.6 FHD 144Hz-Win10
# Dell G7 15 7500 i7-10750H RAM 16GB 1T SSD  RTX 2060 6 GB 1920 x 1080FHD WIN10
# Dell G3 15 3500 Core    i 7-10750H RAM 16GB 512GB SSD 15.6 inch FHD 120Hz RTX 2060 6GB
# Lenovo Legion 5 15IMH05H Core i7-10750H-RAM 16G-512GB SSD-15.6 FHD IPS 144Hz RTX 2060 6GB WIN 10
# Lenovo Legion 5 15ARH05H Ryzen 7 4800H-RAM 16-512GB SSD 1TB HDD-15.6 FHD IPS 144Hz  RTX 2060 6G WIN10
# MSI LAPTOP GL65 Leopard-Core    i7 10750H-RAM 16G-512SSD-15.6 FHD 144Hz IPS-RTX 2070 8G-WIN 10
# Dell G5 15 5500 Core i7-10750H-RAM 16GB-1TB SSD-15.6 inch FHD 144Hz- RTX 2060 6GB
# Lenovo 135W Slim Tip AC Adapter
# SanDisk 4TB Extreme PRO Portable SSD - Up to 2000MB s - USB-C  USB 3.2 Gen 2x2  IP65 Water and Dust Resistance  Updated Firmware - External Solid State Drive - SDSSDE81-4T00-G25
# SanDisk 1TB Extreme Portable SSD - Up to 1050MB s  USB-C  USB 3.2 Gen 2  IP65 Water and Dust Resistance  Updated Firmware - External Solid State Drive - SDSSDE61-1T00-G25
# WD SSD 2TB D30 Game WDBATL0020BBK-WESN Portable External Solid State Drive  Compatible with Playstation  Xbox    PC  Up to 900MB s
# WD My Passport SSD 1T WDBAGF0010BBL WESN-BLUE
# Crucial-external SSD-X6 External Portable SSD 2TB Speed 800 MBs USB 3.2 Type-C Drop Proof
# CORSAIR SSD EX100U 2TB Portable Solid State USB Type-C Storage Drive
# Lexar SL200 1TB Portable SSD External SSD Up to 550MB s Read 400MB s Write USB Type-C
# H D-ADATA-SSD-External-SE760-512G-USB 3.2 Gen2-Type-C-Up to 1000 MB s-BLACK 007008147000038
# SANDISK SSD 1T Portable SDSSDE30-G26
# HIKSEMI T300S 1TB Black USB 3.1 Up To 560MB Portable SSD BLACK
# Adata HD680 1TB USB 3.2 External HDD Hard Drive
# SILICON POWER ARMOR A60 1TB IPX4 WATER RESISTANT AND MIL-STD-810G SHOCK PROOF Black EXTERNAL HARD DriveThe Armor
# Silicon Power Hard Drive 1TB Armor A80 3.2 Antichoc Waterproof External - Black
# Silicon Power Hard Drive 1TB Armor A80 3.2 Antichoc Waterproof External - Blue
# HIKVISION Light 2TB HS-EHDD-T30 External Hard Disk Drive
# CRUCIAL -external SSD-X8 2TB Portable SSD     Up to 1050 MB s     USB 3.2     External Solid State Drive  USB-C  USB-A  Black
# Toshiba Canvio Ready 2TB Hard Drive - Black
# Toshiba Canvio Advance 2TB Black V10
# TOSHIBA 1TB Canvio Basics  USB 3.0 Portable Hard Drive-Black
# Seagate 5TB One Touch Portable Hard Drive USB 3.0 Black
# Seagate 4TB One Touch Portable Hard Drive USB 3.0 Black
# Seagate 1TB One Touch Portable Hard Drive USB 3.0 Black
# Seagate 2TB One Touch Portable Hard Drive USB 3.0 Black
# PNY Elite 960GB USB 3.1 Gen 1 Portable Solid State Drive  SSD
# A DATA HD710 Pro AHD710P-1TU31-CBL 4TB 2.5 External Hard Drive BLACK
#  A DATA HD710 Pro AHD710P-1TU31-CBL 5TB 2.5 External Hard Drive BLACK
# ADATA 2TB HD680 External USB 3.2 Hard Drive - BLACK
# A DATA HD710 Pro AHD710P-1TU31-CBL 2TB 2.5 External Hard Drive BLACK
# A DATA HD710 Pro AHD710P-1TU31-CBL 1TB 2.5 External Hard Drive BLACK
# ADATA HD770G External Hard Drive - Red - 2TB
# ADATA HD770G External Hard Drive - Red - 1TB
# 1TB Silicon Power Armor A60 Shockproof Portable Hard Drive - USB3.0 - green
# Silicon Power 1TB Rugged Portable External Hard Drive Armor A30  Shockproof USB 3.0  BLACK ORANGE
# Silicon Power 2TB Rugged Portable External Hard Drive Armor A30  Shockproof USB 3.0 f  BLACK ORANGE
# ADATA HD720 1TB USB 3.0 Waterproof Dustproof Shock-Resistant External Hard Drive  Green
# Silicon Power 2TB Rugged Portable External Hard Drive Armor A30  Shockproof USB 3.0   Black
# Silicon Power 1TB Rugged Armor A30 Military Grade Shockproof USB 3.0   Black
# Silicon Power SP010TBPHDA30S3W 1 TB Rugged Armor A30 Shockproof 2.5-Inch USB 3.0  White
# Silicon Power 2 TB External Portable Hard Drive Rugged Armor A30 Shockproof 2.5-Inch USB 3.0  White
# ADATA 2TB HD680 External USB 3.1 Hard Drive - Blue
# Transcend slim portable hard drive 4TB StoreJet 25M3
# ADATA HD650 2TB USB 3.1 Shock-Resistant External Hard Drive  Black
# ADATA HD650 1TB DURABLE Anti-Shock External Hard Drive  Black
# HIKVISION HS EHDD T20 MSR 1TB External Hard disk
# WD 2TB Elements Portable External Hard Drive USB 3.0 - Black
# WD Black 4TB P10 Game Drive  Portable External Hard Drive Compatible with Playstation  Xbox  PC    Mac
# WD Black 5TB P10 Game Drive  Portable External Hard Drive Compatible with Playstation  Xbox  PC    Mac
# WD Black 2TB P10 Game Drive  Portable External Hard Drive Compatible with Playstation  Xbox  PC    Mac
# ADATA HD770G 1TB RGB USB 3.2 IP68 Waterproof Dropproof Dustproof External HDD Black
# ADATA HD770G 2TB RGB USB 3.2 IP68 Waterproof Dropproof Dustproof External HDD Black
# Error upserting product: no results to fetch
# Western Digital 4TB My Passport Portable Hard Drive USB 3.2 Model - WDBPKJ0040BBK-WESN
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Transcend 4TB StoreJet 25H3 2.5-inch USB3.0 Portable Hard Drive
# Transcend slim portable hard drive 2TB StoreJet 25M3
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# WD My Cloud 6TB Personal Cloud Storage
# Western Digital WDBCTL0020HWT - My Cloud - 2TB - Personal Cloud Storage - White
# WD 1TB Elements Portable Storage USB 3.0 Model WDBUZG0010BBK-WESN Black
# Transcend Storejet 2TB Portable USB 3.1 Hard Disk
# Transcend Storejet 1 TB Portable USB 3.1 Hard Disk
# SEAGATE 4TB Backup Plus Portable 2.5
# 2TB M3 USB 3.0 Portable Hard Drive
# 2TB Backup Plus Slim Portable USB 3.0 External HDD - Red
# Error upserting product: no results to fetch
# Error scraping sigma: no results to fetch

# %%
# %pip install psycopg2
# %pip install requests
# %pip install beautifulsoup4
# Out:
# Collecting psycopg2Note: you may need to restart the kernel to use updated packages.
#
#   Downloading psycopg2-2.9.10-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Downloading psycopg2-2.9.10-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.2 MB 326.8 kB/s eta 0:00:04
#    --- ------------------------------------ 0.1/1.2 MB 585.1 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.2 MB 821.4 kB/s eta 0:00:02
#    ------- -------------------------------- 0.2/1.2 MB 919.0 kB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.2 MB 983.0 kB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.2 MB 1.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.4/1.2 MB 1.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.2 MB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.2 MB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 0.9/1.2 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.0/1.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 1.1/1.2 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
#    ---------------------------------------- 0.0/164.9 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/164.9 kB 960.0 kB/s eta 0:00:01
#    ----------------------- -------------- 102.4/164.9 kB 980.4 kB/s eta 0:00:01
#    ----------------------------- ---------- 122.9/164.9 kB 1.0 MB/s eta 0:00:01
#    -------------------------------------  163.8/164.9 kB 893.0 kB/s eta 0:00:01
#    -------------------------------------- 164.9/164.9 kB 822.8 kB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    --------------- ----------------------- 41.0/102.4 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 102.4/102.4 kB 1.2 MB/s eta 0:00:00
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.4 kB ? eta -:--:--
#    ------------------- -------------------- 61.4/128.4 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 122.9/128.4 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 128.4/128.4 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.12.14 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 urllib3-2.3.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Mohamed\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/147.9 kB 435.7 kB/s eta 0:00:01
#    ------------------ -------------------- 71.7/147.9 kB 563.7 kB/s eta 0:00:01
#    ------------------------------------ - 143.4/147.9 kB 853.3 kB/s eta 0:00:01
#    -------------------------------------- 147.9/147.9 kB 882.6 kB/s eta 0:00:00
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3 soupsieve-2.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
