# %%
import psycopg2
from psycopg2 import sql
from concurrent.futures import ThreadPoolExecutor
import requests
from bs4 import BeautifulSoup
import re

conn = psycopg2.connect(
    dbname="PcBuild",
    user="postgres",
    password="123",
    host="localhost",
    port="5432"
)
cursor = conn.cursor()
def upsert_store(cursor, store_name):
    cursor.execute('SELECT "Id" FROM "Stores" WHERE "Name" = %s', (store_name,))
    store_id = cursor.fetchone()
    if store_id:
        return store_id[0]
    insert_query = """
        INSERT INTO "Stores" ("Name")
        VALUES (%s)
        RETURNING "Id";
    """
    cursor.execute(insert_query, (store_name,))
    store_id = cursor.fetchone()
    
    # Return the ID of the newly inserted store
    return store_id[0] if store_id else None


def fetch_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return BeautifulSoup(response.content, 'html.parser')
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

def upsert_product(store_name, product_data):
    try:
        query = """
            SELECT "Id" FROM "Stores" WHERE "Name" = %s;
        """
        cursor.execute(query, (store_name,))
        store_id = cursor.fetchone()
        
        if not store_id:
            print(f"Error: Store {store_name} not found.")
            return  
        store_id = store_id[0]
        cursor.execute(
            """
            SELECT "Id", "CurrentPrice" FROM "Products"
            WHERE "ProductUrl" = %s AND "StoreId" = %s;
            """,
            (product_data['link'], store_id)
        )
        product = cursor.fetchone()

        if product:
            product_id, current_price = product
            if abs(float(current_price) - float(product_data['price'])) > 0.01: 
                cursor.execute(
                    """
                    UPDATE "Products"
                    SET "CurrentPrice" = %s
                    WHERE "Id" = %s;
                    """,
                    (product_data['price'], product_id)
                )
                cursor.execute(
                    """
                    INSERT INTO "Prices" ("Value", "ProductId", "Date")
                    VALUES (%s, %s, NOW());
                    """,
                    (product_data['price'], product_id)
                )
        else:
            print(f"Inserting product: {product_data['title']} - {product_data['price']}")

            cursor.execute(
                """
                INSERT INTO "Products" ("Name", "CurrentPrice", "StoreId", "ImageUrl", "ProductUrl")
                VALUES (%s, %s, %s, %s, %s)
                RETURNING "Id";
                """,
                (
                    product_data['title'],
                    product_data['price'],
                    store_id,
                    product_data['image_url'],
                    product_data['link']
                )
            )
            product_id = cursor.fetchone()[0]
            cursor.execute(
                """
                INSERT INTO "Prices" ("Value", "ProductId", "Date")
                VALUES (%s, %s, NOW());
                """,
                (product_data['price'], product_id)
            )
        conn.commit()
    except Exception as e:
        print(f"Error upserting product: {e}")
        conn.rollback()


# Function to scrape Sigma website
def scrape_sigma():
    base_url = "https://www.sigma-computer.com"
    main_page_url = f"{base_url}/home"
    main_soup = fetch_page(main_page_url)
    if not main_soup:
        return

    category_links = main_soup.select('div.sub-menu a.main-menu')
    for category_link in category_links:
        category_name = category_link.text.strip().lower()
        category_url = base_url + "/" + category_link['href']
        current_page_url = category_url + "&page=1"

        while True:
            soup = fetch_page(current_page_url)
            if not soup:
                break

            containers = soup.find_all('div', class_='product-item-container')
            for container in containers:
                anchor = container.find('a', href=True, title=True)
                title = anchor['title'] if anchor else "No title found"
                link = base_url + "/" + anchor['href'] if anchor else "No link found"
                price_span = container.find('span', class_='price-new')
                image_tag = container.find('img')
                image_url = base_url + "/" + image_tag['src'] if image_tag else "No image found"
                price = re.sub(r'[^\d.]', '', price_span.text.strip()) if price_span else None
                store_name = "Sigma Computer"

                if price:
                    product_data = {
                        "title": title,
                        "price": price,
                        "link": link,
                        "image_url": image_url,
                        "category": category_name
                    }
                    upsert_product(store_name, product_data)

            pagination = soup.find('ul', class_='pagination')
            next_page = pagination.find('a', rel='next') if pagination else None
            if next_page:
                current_page_url = next_page['href']
            else:
                break

def scrape_elnour():
    base_url = "https://elnour-tech.com/en/"
    main_soup = fetch_page(base_url)
    if not main_soup:
        return

    category_links = main_soup.select('.menu-item.menu-item-type-taxonomy.menu-item-object-product_cat')
    for category_link in category_links:
        category_name = category_link.text.strip().lower()
        category_url = category_link.select_one('a').get('href') if category_link.select_one('a') else None
        if not category_url:
            continue

        page_num = 1
        while True:
            page_url = f"{category_url}/page/{page_num}"
            soup = fetch_page(page_url)
            if not soup:
                break

            products = soup.select('.wd-product.product-grid-item')
            for product in products:
                add_to_cart_btn = product.select_one('.add_to_cart_button')
                if add_to_cart_btn:
                    title = product.select_one('.wd-entities-title').text.strip() if product.select_one('.wd-entities-title') else None
                    price_text = product.select_one('bdi').text.strip() if product.select_one('bdi') else None
                    price = re.sub(r'[^\d.]', '', price_text) if price_text else None
                    link = product.select_one('.wd-entities-title a').get('href') if product.select_one('.wd-entities-title a') else None
                    img_url = product.select_one('.product-wrapper img').get('src') if product.select_one('.product-wrapper img') else None
                    store_name = "Elnour Tech"

                    if price:
                        product_data = {
                            "title": title,
                            "price": price,
                            "link": link,
                            "image_url": img_url,
                            "category": category_name
                        }
                        upsert_product(store_name, product_data)

            next_page = soup.select_one('a.page-numbers.next')
            if next_page:
                page_num += 1
            else:
                break
def scrape_and_store(store_names):
    with conn:
        with conn.cursor() as cursor:
            print("Upserting stores...")
            store_ids = {name: upsert_store(cursor, name) for name in store_names}
            conn.commit()

def main():
    websites = {
        "sigma": scrape_sigma,
        "elnour": scrape_elnour
    }
    stores = ["Sigma Computer", "Elnour Tech"]
    scrape_and_store(stores)
    with ThreadPoolExecutor() as executor:
        future_to_website = {executor.submit(scraper): name for name, scraper in websites.items()}
        for future in future_to_website:
            website = future_to_website[future]
            try:
                future.result()
            except Exception as e:
                print(f"Error scraping {website}: {e}")

if __name__ == "__main__":
    main()

conn.close()
# Out:
# Upserting stores...
# Inserting product: ASUS PRIME H610M-A DDR5  LGA 1700 mATX motherboard with DDR5 PCIe 4.0 dual M.2 slots  Intel 1Gb Ethernet  WIFI 5  DisplayPort HDMI  VGA  USB 3.2 Gen 2 ports  Addressable Gen 2 headers - 4849
# Inserting product: ASUS PRIME H610M-D DDR5  LGA 1700 micro-ATX motherboard   PCIe 4.0  M.2 slot  Realtek 1 Gb Ethernet  HDMI     VGA  USB 3.2 Gen 1  SATA 6 Gbps  COM port  RGB header - 4350
# Inserting product: MSI MAG X870 Tomahawk WiFi Gaming Motherboard  AMD Ryzen 9000 8000 7000 Series Processors  AM5  DDR5  PCIe 5.0  M.2 Gen5  SATA 6Gb s  USB 40Gbps  HDMI DP  Wi-Fi 7  Bluetooth 5.4  5Gbps LAN  ATX  - 19499
# Inserting product: MSI PRO X870-P WIFI Motherboard  ATX - Supports AMD Ryzen 9000   8000   7000 Processors  AM5 - 60A SPS VRM  DDR5 Memory Boost 8200 MT s  OC   PCIe 5.0 x16   4.0 x16  M.2 Gen5  Wi-Fi 7  5G LAN - 15499
# Inserting product: MSI MAG Z890 Tomahawk WiFi Gaming Motherboard  Supports Core Ultra Series 2 Intel Processors  LGA 1851  DDR5  PCIe 5.0  M.2  SATA  5Gbps LAN  USB Type-C  Wi-Fi 7  Bluetooth 5.4  Thunderbolt 4  ATX  - 20499
# Inserting product: MSI PRO Z890-A WiFi ProSeries Motherboard  Supports Core Ultra Series 2 Intel Processors  LGA 1851  DDR5  PCIe 5.0  M.2  SATA  5Gbps LAN  USB Type-C  Wi-Fi 7  Bluetooth 5.4  Thunderbolt 4  ATX  - 17000
# Inserting product: MSI PRO Z890-P WiFi ProSeries Motherboard  Supports Core Ultra Series 2 Intel Processors  LGA 1851  DDR5  PCIe 5.0  M.2  SATA  5Gbps LAN  USB Type-C  Wi-Fi 7  Bluetooth 5.4  Thunderbolt 4  ATX  - 15500
# Inserting product: ASUS ProArt X870E-CREATOR WiFi AMD AM5 X870E ATX Motherboard PCIe   5.0 x16 Slots with Full Support for Next-gen GPUs  16 2 2 Power Stages  DDR5  Dual USB4    10 Gb   2.5 Gb LAN  WiFi 7  Four M.2 Slots - 27999
# Inserting product: GIGABYTE B650E AORUS STEALTH ICE Motherboard - Supports AMD Ryzen 9000 CPUs- 12 2 2 phases VRM- up to 8000MHz DDR5  OC - 1xPCIe 5.0 M2   3xPCIe 4.0 M.2- Wi-Fi 7-2.5GbE LAN- USB 3.2 Gen 2x2 - 14899
# Inserting product: GIGABYTE B760 DS3H AX DDR4  LGA 1700  Intel  B760  ATX  DDR4  M.2  PCIe 4.0  USB 3.2 Gen 2 Type-C WiFi 6E Realtek GbE LAN Q-Flash Plus PCIe EZ-Latch Motherboard  - 8200
# Inserting product: GIGABYTE B760M AORUS ELITE DDR4 Intel LGA 1700 m-ATX Motherboard  4x DDR4  128GB  2x PCI-E x16  2x M.2  4x SATA  4x USB 3.2  1x USB-C  4x USB 2.0 - 7600
# Inserting product: GIGABYTE B760M DS3H AX DDR4  LGA 1700  Intel  B760  M-ATX  DDR4  2  M.2  PCIe 4.0  USB 3.2 Gen 2 Type-C WiFi 6E  2.5GbE LAN Q-Flash Plus PCIe EZ-Latch Gaming Motherboard  - 7299
# Inserting product: MSI MAG Z690 TOMAHAWK Gaming Motherboard ATX  Supports Intel Processors 12th Generation  LGA 1700  16 Duet Rail VRM 70A  DDR5 Memory Boost 6400 MHz OC  1 x PCIe 5.0 x16  3 x M.2 Gen4  Wi-Fi 6E - 11999
# Inserting product: MSI PRO H610M-E Motherboard  Micro-ATX - Supports 14th 13th 12th Gen Intel Core Processors  LGA 1700 - DDR5 Memory Boost 5600MHz MAX  PCIe 4.0 x16 Slot  M.2 Gen3 Slot - 4000
# Inserting product: MSI PRO Z790-P WiFi ProSeries Motherboard  Supports 12th 13th 14th Gen Intel Processors  LGA 1700  DDR5  PCIe 5.0  M.2  2.5Gbps LAN  USB 3.2 Gen2  HDMI DP  Wi-Fi 6E  Bluetooth 5.3  ATX  - 11249
# Inserting product: MSI PRO B760M-P DDR4 ProSeries Motherboard  Supports 12th 13th Gen Intel Processors  LGA 1700  DDR4  PCIe 4.0  M.2  Gbps LAN  USB 3.2 Gen2  mATX  - 5249
# Inserting product: MSI PRO B760M-E DDR4 Intel LGA 1700 2x DDR4 slots  max 64GB  up to 4800MHz  HDMI and VGA outputs  and offers multiple expansion slots  RAID support  and Realtek Gigabit LAN - 4699
# Inserting product: MSI MAG Z790 Tomahawk MAX WiFi Gaming Motherboard  Supports 12th 13th 14th Gen Intel Processors  LGA 1700  DDR5  PCIe 5.0  M.2  SATA 6G  2.5Gbps LAN  USB 3.2 Gen2  Wi-Fi 7  Bluetooth 5.4  ATX  - 15500
# Inserting product: MSI Z790 Project Zero Gaming Motherboard  Support 14th 13th 12th Gen Intel Processors  LGA 1700  DDR5  PCIe 5.0  M.2 Slots  2.5Gbps LAN  USB 3.2 Gen2  HDMI DP  Wi-Fi 7  Bluetooth 5.4  ATX  - 13000
# Inserting product: ASUS PRIME B650M-A II-CSM Micro-ATX motherboard with DDR5  PCIe 5.0 M.2  2.5Gb Ethernet  DisplayPort  HDMI    VGA  rear USB 3.2 Gen 2  front USB 3.2 Gen 1 Type-C    BIOS FlashBack     Aura Sync - 7999
# Inserting product: ASUS ROG Strix B650-A Gaming WiFi 6E AM5  LGA1718  Ryzen 7000 Motherboard 12 2 Power Stages DDR5 3xM.2 Slots PCIe   4.0  2.5G LAN WiFi 6E USB 3.2 Gen 2x2 Type-C   Port  - 12999
# Inserting product: ASUS PRIME B650M-R Micro-ATX motherboard  DDR5  PCIe 4.0 support  Realtek 2.5Gb Ethernet  HDMI  SATA 6 Gbps  front USB 5Gbps Type-C  BIOS FlashBack  Two-Way AI Noise Cancelation  Aura Sync - 5499
# Inserting product: ASUS TUF GAMING B760M-E D4 Intel B760 LGA 1700 mATX Gaming Motherboard  DDR4  PCIe 4.0  2x M.2  10 1 DrMOS  2.5Gb Ethernet  M.2 for Wi-Fi Ready  DisplayPort  HDMI  USB 3.2 Gen 2  Arua Sync RGB  - 7500
# Inserting product: ASUS H610  LGA 1700  mic-ATX motherboard with DDR4  PCIe 4.0  dual M.2 slots  Intel   1 Gb Ethernet  WIFI 5  DisplayPort  HDMI    D-Sub  USB 3.2 Gen 2 ports  SATA 6 Gbps  Addressable Gen 2 headers  and Arua Sync - 4699
# Inserting product: ASUS ROG STRIX Z790-E GAMING WiFi Slash the 6GHz barrier in style with the Strix Z790-E. Translucent shrouds outline its RGB ignition panel - 25500
# Inserting product: ASUS TUF Gaming Z790-PRO WiFi 6E LGA 1700 Intel 14th  13th 12th Gen  ATX Gaming Motherboard DDR5 PCIe 5.0X 16 Front Panel USB 20Gbps Type-C Thunderbolt 4  Q-Antenna  2.5Gb LAN AI OVERCLOCKING - 14500
# Inserting product: ASUS PRIME B760M-PLUS Intel   B760  LGA 1700  micro-ATX motherboard with PCIe 4.0  DDR5  two M.2 slots  Realtek 2.5Gb Ethernet  DisplayPort  HDMI     SATA 6 Gbps  rear USB 10Gbps  front USB 5Gbps Type-C    Aura Sync - 7500
# Inserting product: ASUS PRIME B450M-A II AMD B450  Ryzen AM4  micro ATX motherboard with M.2 support  HDMI DVI-D D-Sub  SATA 6 Gbps  1 Gb Ethernet  USB 3.2 Gen 2 Type-A  BIOS FlashBack     and Aura Sync RGB lighting support - 3750
# Inserting product: ASUS PRIME H610M-A D4-CSM H610  LGA 1700  mic-ATX motherboard with DDR4  PCIe 4.0  dual M.2 slots  Intel 1 Gb Ethernet  DisplayPort  HDMI  D-Sub  USB 3.2 Gen 2 ports  SATA 6 Gbps  Addressable Gen 2 headers  and Aura Sync - 4400
# Inserting product: ASUS TUF GAMING X870-PLUS WIFI AMD Socket AM5  4 DDR5 memory slots  up to 192GB   PCIe 5.0 support  Wi-Fi 7  and high-definition 7.1 audio - 18499
# Inserting product: ASUS ROG STRIX X870E-E GAMING WIFI AMD AM5 socket  supports up to 192GB DDR5 memory  5 M.2 slots  Wi-Fi 7  high-quality ROG SupremeFX 7.1 audio - 29999
# Inserting product: ASUS ROG CROSSHAIR X870E HERO   AMD AM5 socket  supports up to 192GB DDR5 RAM  dual PCIe 5.0 x16 slots  5 M.2 slots  with Wi-Fi 7   Bluetooth 5.4 - 34999
# Inserting product: ASUS ProArt X670E-CREATOR WiFi AMD X670 AM5 Ryzen    Desktop 9000 8000   7000 ATX Motherboard  16 2 Power Stages  PCIe   5.0 Ready  DDR5 Support  USB4    10 Gb   2.5 Gb LAN  WiFi 6E  Four M.2 Slots - 18000
# Inserting product: GIGABYTE Z790 Eagle AX LGA 1700 Intel Z790 ATX Motherboard with DDR5  M.2  PCIe 5.0  USB 3.2 Gen2X2 Type-C  Intel Wi-Fi 6E  2.5GbE LAN  Q-Flash Plus  EZ-Latch - 11300
# Inserting product: ASUS Prime B550M-A WiFi II AMD Micro ATX Motherboard with PCIe 4.0  WiFi 6  ECC Memory  HDMI 2.1  RGB Header - 6649
# Inserting product: TUF Gaming Z790-BTF WiFi 7 Intel   Z790  LGA 1700  ATX Motherboard Hidden-Connector Design  PCIe 5.0  4xM.2 Slots  16 1 1 Power Stages  DDR5 2.5Gb Ethernet USB Type-C  Front USB Type-C  Thunderbolt    4 - 14999
# Inserting product: GIGABYTE B650 UD AC  rev. 1.0  AM5 LGA 1718 AMD B650 ATX Motherboard DDR5  PCIe 4.0 M.2  PCIe 4.0  USB 3.2 Gen2x2 Type-C  GbE LAN - 8999
# Inserting product: ASUS PRIME B760M-R D4  an Intel   B760 LGA 1700 micro-ATX motherboard with PCIe 4.0  two PCIe 4.0 M.2 slots  DDR4  Realtek 2.5Gb Ethernet  HDMI     SATA 6 Gbps  front USB 5Gbps ports  Aura Sync - 5100
# Inserting product: ASUS PRIME B760M-A D4  LGA 1700  mATX motherboard  PCIe 4.0  two M.2 slots  Realtek 2.5Gb Ethernet  DisplayPort  Dual HDMI    SATA 6 Gbps  rear USB 3.2 Gen 2  front USB 3.2 Gen 1 Type-C    Aura Sync - 6100
# Inserting product: MSI PRO B760M-A WiFi Gaming ProSeries Motherboard  DDR5 Supports Intel Processors  LGA 1700  Micro-ATX  Wi-Fi 6E - Black - 9499
# Inserting product:  ASUS ROG Strix Z790-A Gaming WiFi II - WiFI 7 LGA 1700 Intel 14th 13th   12th Gen  ATX gaming motherboard - 19500
# Inserting product: ASUS ROG Strix Z790-F Gaming WiFi II LGA 1700 Intel 14th  13th   12th Gen ATX gaming motherboard DDR5 2.5 Gb LAN 5XM.2 slots with heatsinks PCIe 5.0 x16 SafeSlot with Q-Release WiFi 7 USB 20Gbps rear I O port and front-panel connector.v - 22500
# Inserting product: ASUS TUF Gaming B650-E WIFI AMD B650 AM5 DDR5 8000 DP HDMI 3x M2 USB3.2 WiFi 6E   BT AURA RGB 2.5Gbit LAN ATX ASUS TUF PROTECTION  ASUS Q-Design  Armoury Crate  Motherboard - 10499
# Inserting product: “Acer Nitro V ANV15-41-R8FH’ AMD Ryzen 5-7535HS 8GB RAM,512GB SSD,NVIDIA GeForce RTX 2050 4GB Graphics, 15.6″  Screen Size, Windows 11” - 30.00000
# Inserting product: ACER Predator Helios Neo 16 PHN16-72-99PA Gaming Core™’ i9 14900HX RAM 16 GB DDR5 1TB NVMe RTX”™ 4060 NVIDIA° 8 GB GDDR6 16INCH 165 Hz100% sRGB Windows 11 Home - 70.00000
# Inserting product: ASUS TUF F15 2024 FX507VV-LP156W INTEL CORE  i7-13620H – Nvidia  RTX 4060 8GB – 16GB DDR5 – 1TB SSD – 15.6 FHD 144HZ 100%SRGB – Win 11 - 58.00000
# Inserting product: ASUS TUF Gaming A15 FA506NCR-HN007W Laptop – AMD Ryzen™ 7-7435HS – 8GB – 512GB SSD – NVIDIA® GeForce® RTX™ 3050 4GB – 15.6” FHD – Win11 - 37.80000
# Inserting product: ASUS TUF Gaming A15 FA506NFR-HN007W Laptop – AMD Ryzen™ 7-7435HS – 8GB DDR5 – 512GB SSD – NVIDIA® GeForce® RTX™ 2050 4GB – 15.6” FHD – Win11 - 32.60000
# Inserting product: ASUS TUF Gaming A15 FA507NUR-LP007W Laptop – AMD Ryzen 7 7435HS – 16GB – 512GB SSD – NVIDIA® GeForce® RTX 4050 6GB – 15.6” FHD 144HZ – Win11 - 48.00000
# Inserting product: Dell Vostro 3520 – intel Core i5-1235U – Intel UHD Graphics – RAM 8GB DDR4 – 512GB SSD – 15.6-inch FHD 120Hz - 23.00000
# Inserting product: Dell Vostro 3520 Laptop – 12th Intel Core i3-1215U 6-Cores, 8GB RAM, 512GB SSD, Intel UHD Graphics, 15.6″ FHD (1920 x 1080) 120Hz 250 nits Anti-Glare, Ubuntu – Carbon Black - 18.00000
# Inserting product: DELL Vostro 3520 Laptop – 12th Intel core i7-1255U –  8GB RAM – 512 GB SSD –  Intel Iris Xe Graphics – 15.6″ FHD 120HZ - 30.00000
# Inserting product: HP 15-DW1380NIA LAPTOP – Intel Core i5-10210U – Intel UHD Graphics – 1TB HDD + 256GB SSD – 8GB RAM – 15.6” HD – Windows 11 – Black - 19.00000
# Inserting product: Hp Victus 15-fa1041ne Gaming Intel i5 13500H – 8GB RAM DDR4 – 512GB SSD NVME –  NVIDIA GeForce RTX 3050 6GB GDDR6 Graphics 15.6 INCH FHD 144Hz IPS – Performance Blue - 40.00000
# Inserting product: HP Victus 15-FB2063DX Gaming Laptop –  AMD Ryzen 5 7535HS – AMD Radeon RX 6550M 4GB Graphics – 8GB RAM DDR5 – 512GB SSD – 15.6″ FHD IPS 144Hz Display – WIndows 11 - 29.40000
# Inserting product: HP Victus 16-S1023DX Gaming Laptop – AMD Ryzen 7 8845HS – GeForce RTX 4070 8GB Laptop Graphics – 16GB RAM DDR5 5600Mhz – 512GB SSD –  16.1″ FHD IPS 144Hz Display – Windows 11 - 65.00000
# Inserting product: Lenovo LOQ 15ARP9 Gaming Laptop 2024 –  AMD Ryzen 7 7435HS 8-Core – NVIDIA GeForce RTX 4060 8GB GDDR6 – 16GB RAM DDR5 – 512GB SSD – 15.6″ FHD IPS 144Hz 100% sRGB – Win11 - 50.00000
# Inserting product: Lenovo LOQ 15ARP9 Gaming Ryzen 5 7235HS – AI Chip: LA1 – 12GB DDR5 RAM –  512GB SSD NVME – NVIDIA GeForce RTX 3050 6GB GDDR6 Graphics – 15.6 INCH FHD IPS 100% sRGB 144Hz G-SYNC, Win 11 - 35.00000
# Inserting product: LENOVO LOQ 15IAX9 GAMING LAPTOP INTEL CORE I5-12450HX – NVIDIA RTX 2050 4G – RAM 16G DDR5 – SSD 512G – 15.6 FHD 144HZ G-SYNC SRGB 100% - 33.90000
# Inserting product: LENOVO LOQ 15IAX9 GAMING LAPTOP INTEL CORE I5-12450HX – NVIDIA RTX 2050 4G – RAM 8G DDR5 – SSD 512G – 15.6 FHD 144HZ G-SYNC SRGB 100% – LOQ GAMING MOUSE – 2Y Warranty - 32.50000
# Inserting product: Lenovo LOQ 15IRX9 Core™ i7-14700HX  – RAM 16G DDR5 – 1TB SSD NVMe – NVIDIA® GeForce RTX™ 4060 8GB GDDR6 – 15.6INCH FHD IPS 100% SRGB  144Hz  G-SYNC®- 2 Year Warranty + Lenovo Mouse - 60.00000
# Inserting product: Lenovo LOQ 15IRX9 Gaming – i7-13650HX 14 Cores – AI Chip: LA1 –  16GB  DDR5 RAM – 512GB SSD M.2 NVME – NVIDIA GeForce RTX 4050 6GB GDDR6 Graphics – 15.6″ FHD  IPS SRGB%100 144Hz – - 49.50000
# Inserting product: Lenovo LOQ 15IRX9 Gaming – i7-13650HX 14 Cores – AI Chip: LA1 –  16GB  DDR5 RAM – 512GB SSD M.2 NVME – NVIDIA GeForce RTX 4060 8GB GDDR6 Graphics – 15.6″ FHD  IPS SRGB%100 144Hz - 56.80000
# Inserting product: MSI Thin 15 B13VE Laptop – Intel® Core™ i7-13620H – RAM 16GB – 512GB SSD – NVIDIA® GeForce RTX™ 4050 6GB – 15.6″ FHD 144HZ - 47.00000
# Inserting product: MSI THIN GF63 12UCX GAMING LAPTOP – INTEL CORE I5-12450H RAM 8GB DDR4 SSD 512GB NVIDIA RTX 2050 4GB 144HZ - 32.00000
# Inserting product: GIGABYTE X670E AORUS MASTER AM5 LGA 1718 AMD X670E EATX Motherboard DDR5  Quad M.2  PCIe 5.0  USB 3.2 Gen2X2 Type-C  Intel WiFi 6E  Intel 2.5GbE LAN  Q-Flash Plus  EZ-Latch Plus - 25400
# Inserting product:  GIGABYTE Z790 AORUS PRO X LGA 1700 ATX DDR5 Motherboard     5  M.2  PCIe 5.0  USB 3.2 Type-C  Wi-Fi 7  5GbE LAN  Q-Flash Plus  EZ-Latch Plus - 21300
# Inserting product: GIGABYTE Z790 AORUS MASTER X LGA 1700 DDR5 Motherboard     5 M.2  PCIe 5.0  USB 3.2 Type-C  Wi-Fi 7  10GbE LAN  Q-Flash Plus  EZ-Latch Plus - 29900
# Inserting product: GIGABYTE Z790 AORUS MASTER X LGA 1700 DDR5 Motherboard     5 M.2  PCIe 5.0  USB 3.2 Type-C  Wi-Fi 7  10GbE LAN  Q-Flash Plus  EZ-Latch Plus - 29999
# Inserting product:  MSI Intel PRO-H510M-B Supports 10th Gen Intel   Core     Pentium   Gold and Celeron   processors for LGA 1200 socket Motherboard - 3499
# Inserting product: ASUS Prime B760-PLUS D4  an Intel   B760 LGA 1700 ATX motherboard with PCIe 5.0  three PCIe 4.0 M.2 slots  DDR4  Realtek 2.5Gb Ethernet  DisplayPort  VGA  HDMI    SATA 6 Gbps  USB 3.2 Gen 2x2 Type-C    front USB 3.2 Gen 1 Type-C    Thunderbolt    - 9250
# Inserting product: MSI A520M-A PRO Gaming Motherboard  AMD Ryzen 5000  AM4  DDR4  PCIe 3.0  SATA 6Gb s  M.2  USB 3.2 Gen 1  DVI HDMI  Micro-ATX  - 2850
# Inserting product: ASUS PRIME A620M-K micro-ATX motherboard  DDR5  PCIe 4.0 Graphics card and PCIe 4.0 M.2 support  HDMI     VGA  USB 3.2 Gen 1 Type-A  SATA 6 Gbps  Two-Way AI Noise Cancelation  Aura Sync - 4899
# Inserting product:  MSI PRO A620M-E ProSeries Motherboard  AMD AM5  DDR5  PCIe 4.0  SATA 6Gb s  M.2  USB 3.2 Gen 1  Gbps LAN  DVI HDMI  mATX  - 4849
# Inserting product: ASUS TUF GAMING B760M-PLUS D4 Intel   Socket LGA1700 for 13th Gen Intel   Core      12th Gen motherboard. - 8000
# Inserting product: ASUS TUF Gaming X670E-PLUS WiFi 6E Socket AM5  LGA 1718  Ryzen 7000 ATX Gaming Motherboard 16 Power Stages  PCIe   5.0  DDR5 Memory  Four M.2 Slots 2.5 Gb LAN USB 4  Aura RGB Lighting  - 15500
# Inserting product: ASUS TUF GAMING Z790-PLUS D4 Supports Intel LGA1700 DDR4 RAM  up to 5333MHz OC   PCIe 5.0  4 M.2 slots  2.5Gb - 10999
# Inserting product: ASUS Prime X670-P Socket AM5  LGA 1718  Ryzen 7000 ATX Motherboard DDR5  3xM.2 Slots  USB 3.2 Gen 2x2 Type-C    USB4   Header  and 2.5Gb Ethernet  - 12999
# Inserting product: Intel   LGA 1700 socket  Ready for 12th Gen Intel   processors Ultrafast connectivity   PCIe 4.0  Intel   1 Gb Ethernet  rear USB 3.2 Gen 2 Type-A and front USB 3.2 Gen 1 Type-A and Type-C   ASUS OptiMem II  Careful routing of traces and vias   - 3450
# Inserting product: GIGABYTE Intel   Z690 Creator Motherboard with unique VisionLINK I O design  Next Gen Memory DDR5  WIFI6 802.11ax and Intel   2.5GbE LAN  PCIe 5.0 x16 slot  4 x NVMe PCIe 4.0 x4 M.2 Connectors  USB 3.2 Gen 2x2 Type-C   - 8200
# Inserting product: GIGABYTE Intel   H610 Motherboard with 6 1 1 Hybrid Phases Digital VRM Design  PCIe 4.0  Design  Gen3 x4 M.2  GIGABYTE Intel   GbE with cFosSpeed   Anti-Sulfur Resistor   Smart Fan 6 - 4199
# Inserting product: GIGABYTE AMD B550 AORUS Motherboard with Twin 12 2 Phases Digital VRM  Enlarged Surface Heatsinks  PCIe 4.0 x16 Slot  Dual PCIe 4.0 3.0 x4 M.2 with One Thermal Guard  2.5GbE LAN  RGB FUSION 2.0  Q-Flash Plus - 7499
# Inserting product: GIGABYTE AMD B450 AORUS Motherboard with Hybrid Digital PWM  M.2 with Thermal Guard  GIGABYTE Gaming LAN with 25KV ESD Protection  Anti-sulfur Design  CEC 2019 ready  RGB FUSION 2.0 - 2695
# Inserting product: GIGABYTE Intel   B660 AORUS Motherboard with 12  1 1 Twin Hybrid Phases Digital VRM Design   DDR5 MEMORY Design  Fully Covered Thermal Design   2 x PCIe 4.0 M.2 with Thermal Guard  Intel   2.5GbE LAN  WIFI 6 802.11ax  Rear USB 3.2 Gen 2x2 Typ - 5300
# Inserting product: GIGABYTE Intel   B660 AORUS Motherboard with 12  1 1 Twin Hybrid Phases Digital VRM Design  Fully Covered Thermal Design   2 x PCIe 4.0 M.2 with Thermal Guard  Intel   2.5GbE LAN  Rear USB 3.2 Gen 2x2 Type-C    RGB FUSION 2.0  Q-Flash Plus - 4650
# Inserting product: GIGABYTE Intel   H510M DS2V Ultra Durable Motherboard with 6 2 Phases Digital VRM  PCIe 4.0  Design  Realtek 8118 Gaming LAN  Anti-Sulfur Resistor  Smart Fan 6 - 2750
# Inserting product: GIGABYTE Intel   Z690 Creator Motherboard with unique VisionLINK I O design  WIFI6 802.11ax and Intel   2.5GbE LAN  PCIe 5.0 x16 slot  4 x NVMe PCIe 4.0 x4 M.2 Connectors  USB 3.2 Gen 2x2 Type-C   - 8199
# Inserting product:  Intel   B660 Motherboard with 6 2 1 Phases Hybrid Digital VRM with MOS Heatsink     2 x PCIe 4.0 M.2 with Thermal Guard  2.5GbE LAN  WIFI 6 802.11ax      Rear USB 3.2 Gen 2 Type-C    RGB FUSION 2.0  Q-Flash Plus          - 3650
# Inserting product: MSI MAG B660M Mortar DDR4 Gaming Motherboard  mATX  12th Gen Intel Core  LGA 1700 Socket  DDR4  PCIe 4  2.5G LAN  M.2 Slots  - 4599
# Inserting product: ASUS Intel   Z690  LGA 1700  ATX motherboard with PCIe   5.0  three M.2 slots  14 1 DrMOS  DDR4  HDMI    DisplayPort     Intel   WiFi 6  2.5 Gb Ethernet  USB 3.2 Gen 2x2 Type-C    front USB 3.2 Gen 1 Type-C    Thunderbolt    4 header and Aura Sync RG - 8350
# Inserting product: ASUS Intel   B660  LGA 1700  ATX motherboard with 8 power stages  PCIe 4.0 slots  three M.2 slots  Realtek 2.5Gb Ethernet  DisplayPort  HDMI    D-Sub  rear USB 3.2 Gen 2x2 Type-C    front USB 3.2 Gen 1 Type-C    Aura Sync - 3499
# Inserting product: GIGABYTE Intel   H410M Ultra Durable Motherboard with GIGABYTE Gaming GbE LAN  PCIe Gen3 x4 M.2  HDMI   DVI-D  D-Sub Ports for Multiple Display  Anti-Sulfur Resistor  Smart Fan 5 - 1675
# Inserting product: GIGABYTE Intel   H510M Ultra Durable Motherboard with 6 2 Phases Digital VRM  PCIe 4.0  Design  Realtek 8118 Gaming LAN  3 Display Interfaces Support   Anti-Sulfur Resistor   Smart Fan 6 - 1950
# Inserting product: ASUS PRIME A520M-K  AMD A520  Ryzen AM4  micro ATX motherboard with M.2 support  1 Gb Ethernet  HDMI D-Sub  SATA 6 Gbps  USB 3.2 Gen 1 Type-A - 1700
# Inserting product: ASUS AMD B550M-K  Ryzen AM4  micro ATX motherboard with dual M.2  PCIe 4.0  1 Gb Ethernet  HDMI D-Sub DVI  SATA 6 Gbps  USB 3.2 Gen 2 Type-A - 4899
# Inserting product: Asus Prime A520M-E - AMD A520  Ryzen AM4  micro ATX motherboard with M.2 support  1 Gb Ethernet  HDMI DVI D-Sub  SATA 6 Gbps  USB 3.2 Gen 2 Type-A - 4000
# Inserting product: AMD B550 AORUS Motherboard with True 12 2 Phases Digital VRM  Fins-Array Heatsink  Direct-Touch Heatpipe  Dual PCIe 4.0 3.0 x4 M.2 with Thermal Guards  2.5GbE LAN  RGB FUSION 2.0  Q-Flash Plus - 5499
# Inserting product: ASUS ROG Strix Z690-F Gaming WiFi 6E LGA1700 Intel 12th Gen  ATX Gaming Motherboard PCIe 5.0 DDR5 16 1 Power Stages 2.5Gb LAN BT v5.2 Thunderbolt 4 4xM.2 Front Panel USB 3.2 Gen 2x2 Type-C Connector  - 9099
# Inserting product: ASUS ROG Strix Z690-G Gaming WiFi 6E LGA 1700 Intel 12th Gen Micro ATX Gaming Motherboard- PCIe 5.0  DDR5  14 1 Power Stages  2.5 Gb LAN  Bluetooth v5.2  Thunderbolt 4  3xM.2 NVMe SSD - 6599
# Inserting product: ASUS TUF Gaming Z690-Plus WiFi D4 LGA1700 Intel 12th Gen  ATX gaming motherboard PCIe 5.0  DDR4 4xM.2 NVMe SSD 14 2 power stages WiFi 6 2.5Gb LAN front USB 3.2 Gen 2 Type-C - 6599
# Inserting product: ASUS TUF Gaming Z690-PLUS WiFi D4 LGA 1700 ATX Motherboard  15 DrMOS  PCIe 5.0  DDR4 RAM  Four M.2 Slots  Intel WiFi 6  Front USB 3.2 Gen 2 Type-C - 6299
# Inserting product: ASUS Prime Z690-A LGA 1700 Intel 12th  ATX Motherboard  16 1 DrMOS PCIe 5.0 DDR5 4X M.2  Intel 2.5 Gb LAN USB 3.2 Gen 2 Front Panel Type-C  - 5899
# Inserting product: ASUS Prime Z690M-Plus D4 LGA 1700 Intel 12th Gen  microATX motherboard  PCIe 5.0 DDR4 10 1 Power Stages 3x M.2 1Gb LAN USB 3.2 Gen 2x2 Type-C front USB 3.2 Gen 1 Type-C - 4199
# Inserting product: ASUS ROG Strix B550-F Gaming  WiFi 6  AMD AM4 Zen 3 Ryzen 5000   3rd Gen Ryzen ATX Gaming Motherboard  PCIe 4.0  2.5Gb LAN  BIOS Flashback  HDMI 2.1  Addressable Gen 2 RGB Header and Aura Sync  - 4099
# Inserting product: AMD B550  Ryzen AM4  micro ATX gaming motherboard with PCIe 4.0  dual M.2  10 DrMOS power stages  Intel   WiFi 6  2.5 Gb Ethernet  HDMI  DisplayPort  SATA 6 Gbps  - 5000
# Inserting product: AMD B550  Ryzen AM4  micro ATX gaming motherboard with PCIe 4.0  dual M.2  10 DrMOS power stages  2.5 Gb Ethernet  HDMI  DisplayPort  SATA 6 Gbps  USB 3.2 Gen 2 Type-A and Type-C  and Aura Sync RGB lighting support - 2999
# Inserting product: AMD B550  Ryzen AM4  micro ATX motherboard with dual M.2  PCIe 4.0  1 Gb Ethernet  HDMI D-Sub DVI  SATA 6 Gbps  USB 3.2 Gen 2 Type-A - 1999
# Inserting product: AORUS Z690 MASTER  rev. 1.x  LGA1700  Intel Z690  ATX  DDR5  Quad M.2  PCIe 5.0  USB 3.2 Gen2X2 Type-C Intel WiFi 6E  AQUANTIA 10GbE LAN Intel Thunderbolt 4  Gaming Motherboard  - 10400
# Inserting product: GIGABYTE Z690 GAMING X DDR4  rev. 1.0  PCIe 5.0 Design  Fully Covered Thermal Design  4 x PCIe 4.0 M.2 - 4900
# Inserting product: MSI PRO Z690-A DDR5 ProSeries Motherboard ATX 12th Gen Intel Core LGA 1700 Socket PCIe 4 CFX M.2 Slots Wi-Fi 6E - 5000
# Inserting product: MSI H510M-A PRO Mirco-ATX Gen 4 Supports 10th Gen Intel   Core     11th Gen Intel   Core     Pentium   Gold and Celeron   processors for LGA 1200 socket - 2475
# Inserting product: “|Intel Core i5-14600K 14 cores (6 P-cores & 8 E-cores), Integrated Graphics – Unlocked - 13.50000
# Inserting product: “Hikvision Memory 16GB C1 C10 “ - 17000
# Inserting product: “Redragon Fobos GW600 Webcam “ - 1.79900
# Inserting product: “Redragon PULSAR GM303 Condenser USB Microphone “ - 1.50000
# Inserting product: “T-DAGGER Webcam Gamer and Streamer T-Dagger Eagle HD 720p TGW620 “ - 1.30000
# Inserting product: 2B (CM663) Business Series FHD Webcam – 1280×1080 – With Microphone and light sensors – Black - 1.50000
# Inserting product: 2B (CR003) – USB 2.0 – Card Reader All in one 480 Mbps - 34000
# Inserting product: 2B (CV132) USB 3.0 – 4Port HUB Super - 48000
# Inserting product: 2B (CV143) Type C Male to VGA – HDMI - 65000
# Inserting product: 2B (CV145) Type C to Display Port Converter - 48000
# Inserting product: 2B (CV146) Type C Male to VGA – HDMI – DVI – USB3 - 90000
# Inserting product: 2B (CV224) Converter From Type C Male to VGA Female - 55000
# Inserting product: 2B (DC604) Display port to HDMI – 1.8 M – Black - 39000
# Inserting product: 2B (GP026) 5in1 Racing wheel For PS3/PS4/PC/XBOX ONE/Switch - 5.50000
# Inserting product: 2B (GP076) Wireless Single Gamepad Turbo Dual Vibration 3 in one (PC- PS3) – Black Shell - 1.30000
# Inserting product: 2B (MO887) Wireless Presenter with OFN Brilliant red leaser pointer – Black - 1.50000
# Inserting product: 2B GP193 Wireless Single Gamepad PC & PlayStation 4 – Black Shell - 1.60000
# Inserting product: 2B US318 USB 3.0 HUB 4 Ports + 4 Switches - 49000
# Inserting product: Acer ED322Q Pbmiipx 32 Inch FHD 165Hz 1Ms VRB VA Curved Gaming Monitor - 9.00000
# Inserting product: ADATA Premier 16GB (1x16GB) DDR5 4800MHz LAPTOP RAM - 2.90000
# Inserting product: AMD Ryzen 5 8600G 6-Core, 24-Thread Desktop Processor - 11.00000
# Inserting product: AMD Ryzen™ 3 4300G BOX - 5.00000
# Inserting product: AMD Ryzen™ 5 4500 Desktop Processors - 5.00000
# Inserting product: AMD Ryzen™ 5 5500 Desktop Processors - 5.50000
# Inserting product: GIGABYTE MOTHERBOARD Z590 AORUS ELITE  rev. 1.0 LGA 1200 Intel Z590 ATX Triple M.2 PCIe 4.0 USB 3.2 Gen2X2 Type-C 2.5GbE LAN - 5050
# Inserting product: GIGABYTE MOTHERBOARD A520M H  rev. 1.x  Ultra Durable PCIe 3.0 x4 M.2  RGB FUSION 2.0  Smart Fan 5  Q-Flash Plus - 1475
# Inserting product: GIGABYTE MOTHERBOARD A520M DS3H  rev. 1.x  PCIe 3.0 x4 M.2  RGB FUSION 2.0  Smart Fan 5  Q-Flash Plus - 1700
# Error upserting product: not enough values to unpack (expected 2, got 1)
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Error upserting product: no results to fetch
# Inserting product: Antec Performance 1 FT 4-FAN Full Tower E-ATX Gaming Case - 9.50000
# Inserting product: ASUS TUF GAMING INTEL ATX H570-PRO WIFI  - 4299
# Inserting product: ASUS TUF INTEL ATX GAMING Z590-PLUS WIFI - 4500
# Inserting product: ASUS ROG STRIX INTEL Z590-E GAMING WIFI - 7200
# Inserting product: ASUS INTEL PRIME H510M-K micro ATX MOTHERBOARD - 4400
# Inserting product: ASUS INTEL PRIME H510M-E micro ATX MOTHERBOARD - 1650
# Inserting product: ASUS Intel PRIME H510M-D micro ATX MOTHERBOARD   - 1650
# Inserting product: GIGABYTE MOTHERBOARD INTEL H410M H  rev. 1.x  - 1450
# Inserting product: GIGABYTE Intel   Ultra B460M DS3H V2  rev. 1.0  Durable Motherboard with Intel   GbE with cFosSpeed  PCIe Gen3 x4 M.2   HDMI   DVI-D  D-Sub Ports for Multiple Display  Anti-Sulfur Resistor  Smart Fan 5  RGB FUSION 2.0 - 1849
# Inserting product: GIGABYTE MOTHERBOARD INTEL  Z590 AORUS XTREME  rev. 1.0  - 9900
# Inserting product: GIGABYTE MOTHERBOARD INTEL B560M AORUS PRO  rev. 1.0  - 2900
# Inserting product: GIGABYTE MOTHERBOARD B560M DS3H AC  rev. 1.0  - 5149
# Inserting product: MSI MOTHERBOARD MEG X570 ACE RGB  - 8200
# Inserting product: MSI MOTHERBOARD AMD MPG X570 GAMING EDGE WIFI RGB - 4900
# Inserting product: MSI MOTHERBOARD AMD A320M PRO-VH - 1200
# Inserting product: MSI MOTHERBOARD INTEL Z590-A PRO  - 4070
# Inserting product: MSI MOTHERBOARD INTEL H510I PRO WIFI  - 2500
# Inserting product: MSI MOTHERBOARD MAG B560M MORTAR WIFI  - 2950
# Inserting product: MSI MOTHERBOARD MAG B560M BAZOOKA - 2750
# Inserting product: MSI MOTHERBOARD MAG B560 TORPEDO - 3200
# Inserting product: MSI MOTHERBOARD MAG B560 TOMAHAWK WIFI - 3650
# Inserting product: MSI INTEL B560M PRO motherboard  - 2000
# Inserting product: MSI B560M-A PRO MATX motherboard  - 2000
# Inserting product: MSI MOTHERBOARD B560M PRO-VDH WIFI  - 2600
# Inserting product: GIGABYTE A520 AMD AORUS ELITE  rev. 1.0   - 1850
# Inserting product: GIGABYTE Z590 AORUS MASTER  rev. 1.0   - 7499
# Inserting product: GIGABYTE Z590 VISION G  rev. 1.0   - 5300
# Inserting product: GIGABYTE Z590 AORUS ULTRA  rev. 1.0   - 6900
# Inserting product: GIGABYTE Z590 AORUS ELITE AX  rev. 1.0   - 4249
# Inserting product: GIGABYTE B560M AORUS ELITE  rev. 1.0   - 3850
# Inserting product: Intel   H510M S2H Ultra Durable Motherboard with 6 2 Phases Digital VRM  PCIe 4.0  Design  Realtek 8118 Gaming LAN  4 Display Interfaces Support   Anti-Sulfur Resistor   Smart Fan 6 - 1950
# Inserting product: Antec Performance 1 FT Case 4 Fan Full Tower White - 8.30000
# Inserting product: Antec Symphony 240MM ARGB Newly Designed All-in-One Liquid Cooler Liquid CPU cooler - 5.50000
# Inserting product: ANTEC SYMPHONY 360MM ARGB Newly Designed All-in-One Liquid Cooler - 5.30000
# Inserting product: Antec Vortex 240MM ARGB CPU Liquid Cooler - 4.50000
# Inserting product: Antec Vortex 360 All-In-One ARGB CPU Liquid Cooler - 5.49900
# Inserting product: AOC 24G4E 23.8-Inch Fast IPS Gaming Monitor, 1920 × 1080 (FHD), 180Hz, 0.5ms, HDR10, Adaptive Sync, Engineered for Peak Gaming Performance - 8.00000
# Inserting product: AOC 27G4E Gaming Monitor 27-Inch (IPS Panel) , 1920 x 1080 (FHD), 180Hz Refresh Rate, 0.5ms Response Time, Adaptive Sync, HDMI 2.0 x 1, DisplayPort 1.4 × 1 - 9.50000
# Inserting product: AOC AGON PRO AG276QZD 27″ OLED Tournament Gaming Monitor 2560×1440 – 240Hz – 0.03MS – G-SYNC Compatible - 45.00000
# Inserting product: AOC C27G2Z2 27″ 250HZ 0.5MS CURVED VA PANEL FHD HDMI 2.0 - 12.00000
# Inserting product: AOC C27G4ZE 27″ 280Hz Curved Ultra-Fast Gaming Monitor 1920×1080 (FHD) – 0.3ms – Fast VA, 1500R – Adaptive Sync – Three-sided frameless design - 11.30000
# Inserting product: AOC Q27G4 – 2560 × 1440 (QHD) – IPS – 180HZ – 127%- SRGB, DCI P3 99% – HDR 400A - 14.00000
# Inserting product: AOC Q27G4F 27″ Frameless Ultra-Fast IPS Gaming Monitor – QHD 2560 X 1440 – 180Hz – 0.5ms – MBR Sync - 13.25000
# Inserting product: AOC U27U3CV – Graphic Pro Series – LED monitor – 4K – 27″ – HDR - 28.00000
# Inserting product: ASUS PRIME A620M-K  AMD A620  DDR5 – PCIe 4.0 – Graphics card and PCIe 4.0 M.2 support - 7.20000
# Inserting product: ASUS PRIME B450M-A II - 6.20000
# Inserting product: ASUS ROG Strix XG27ACS USB Type-C Gaming Monitor – 27-inch 2560×1440 – 180Hz – 1ms (GTG) – Fast IPS – Extreme Low Motion Blur Sync – USB Type-C – G-Sync compatible – DisplayWidget Center – tripod socket – HDR - 18.50000
# Inserting product: ASUS TUF GAMING B650M-PLUS AM5 DDR5 - 14.50000
# Inserting product: ASUS TUF Gaming VG27AQ3A Gaming Monitor – 27-inch, QHD(2560×1440), 180Hz, Fast IPS, ELMB Sync, 1ms (GTG), Freesync Premium™, G-Sync compatible, Variable Overdrive, 130% sRGB - 14.50000
# Inserting product: ASUS TUF Gaming VG27AQML1A Gaming Monitor – 27-inch, QHD(2560×1440) – Overclock to 260Hz (native 240Hz) – ELMB Sync – Freesync Premium™ – 1ms (GTG), Variable Overdrive -100% sRGB, DisplayHDR™ 400 - 25.00000
# Inserting product: ASUS VA27EHF Eye Care Gaming Monitor – 27-inch, IPS, Full HD, Frameless, 100Hz, Adaptive-Sync, 1ms MPRT, HDMI, Low Blue Light, Flicker Free, Wall Mountable - 6.80000
# Inserting product: ASUS VZ24EHF Eye Care Gaming Monitor – 24-inch (23.8-inch viewable), IPS -Full HD – Frameless – 100Hz –  Adaptive-Sync – 1ms MPRT – HDMI – Low Blue Light – Flicker Free – Wall Mountable - 6.00000
# Inserting product: Case Technozone C-500 With 3RGB FAN+ PSU 600W 80PLUS - 3.90000
# Inserting product: COOLER MASTER CMP 520 + Power ELITE NEX N600 600W  3FANS ARGB - 5.00000
# Inserting product: COOLER MASTER ELITE 301  3x 120mm ARGB fans + ELITE NEX PN700 700W PSU – USB Type-C Support - 4.50000
# Inserting product: Cooler Master Elite 301 3FAN ARGB +  ELITE NEX PN600W PSU - 4.50000
# Inserting product: COOLER MASTER G GOLD 750W V2 ATX 3.1 - 6.10000
# Inserting product: COOLER MASTER HYBER 212 SPECTRUM V3 - 2.00000
# Inserting product: COOLER MASTER HYPER 622 HALO BLACK ARGB  WHITE - 4.00000
# Inserting product: COOLER MASTER MASTERBOX TD500 MESH V2 -3FAN ARGB FANS INCLUDED USB 3.2 GEN 2 Type C Support - 5.00000
# Inserting product: Cooler Master MasterGel Regular High Performance Thermal GREASE - 35000
# Inserting product: COOLER MASTER PSU MWE 750W +80 PLUS BRONZE V3 230V ATX 3.1 - 4.00000
# Inserting product: COUGAR POWER SUPPLY VTE X2 ARGB – 650W +80 BRONZE - 2.35000
# Inserting product: Crucial 16GB DDR4-3200 NOTEBOOK - 2.20000
# Inserting product: Crucial 16GB DDR4-3200 UDIMM - 2.00000
# Inserting product: Crucial 16GB DDR5 4800 MHz UDIMM Memory Module (1 x 16GB) - 2.29900
# Inserting product: Crucial BX500 1TB 3D NAND SATA 2.5-Inch Internal SSD - 4.00000
# Inserting product: Crucial BX500 240GB 3D NAND SATA 2.5-Inch Internal SSD, up to 540MB/s - 1.30000
# Inserting product: Crucial BX500 2TB 3D NAND SATA 2.5 Inch - 7.50000
# Inserting product: Crucial BX500 500GB 2.5-inch SATA 3D NAND Internal SSD - 1.80000
# Inserting product: Crucial P3 1TB M.2 PCIe Gen3 NVMe Internal SSD – Up to 3500MB/s Sequential Read & 3000 MB/s Sequential Write – CT1000P3SSD8 - 3.50000
# Inserting product: Crucial P3 500GB PCIe 3.0 3D NAND NVMe M.2 SSD, up to 3500MB/s Sequential Read & 1900 MB/s Sequential Write – CT500P3SSD8 - 2.00000
# Inserting product: DAHUA 128GB C800AS128G 2.5 SATAIII  SSD DRIVE 550MB/S - 75000
# Inserting product: Dahua C800A 256GB 2.5 SATA III 6Gb s 3D TLC SSD DHI-SSD-C800AS256G - 85000
# Inserting product: Dahua SSD 256GB NVMe M.2 2280 PCIe Gen3x4 Solid State Drive R:2000 MB/s,W:1050 MB/s DHI-SSD-C900N256G - 1.00000
# Inserting product: Devia Watch Pro 5  1.36”inches With 2 Strap – Black - 2.90000
# Inserting product: E-train (DC891) HDMI to HDMI Round Cable 4K 1.5M Gold Plated – Gray - 15000
# Inserting product: E-train (GP054) – USB 2.0 Double Game pad – Colors - 58000
# Inserting product: FAN CASE LC -120 ARGB - 20000
# Inserting product: GAMDIAS AURA GL360 V2 ARGB Liquid CPU Cooler - 4.20000
# Inserting product: GAMDIAS BOREAS E2-410 CPU Air Cooler BLACK - 2.00000
# Inserting product: GAMDIAS BOREAS E2-410 CPU Air Cooler White - 2.10000
# Inserting product: GAMDIAS CHIONE M4-240 IPS LCD ARGB Liquid CPU Cooler - 4.00000
# Inserting product: GIGABYTE – M34WQ – 34 IPS Ultrawide Gaming Monitor – WQHD 3440×1440 – 144Hz – 1ms MPRT – AMD FreeSync Premium – Type C KVM – HDMI DP Type C – Height Adjustable - 22.19900
# Inserting product: Gigabyte A620M H Motherboard - 6.30000
# Inserting product: GIGABYTE AORUS C500 Glass – Black Mid Tower PC Gaming Case, Tempered Glass, USB Type-C, 4X ARBG Fans Included - 13.50000
# Inserting product: Gigabyte AORUS C700 Glass Full Size ATX Tempered Glass Gaming Computer Case, GB-AC700G - 30.00000
# Inserting product: GIGABYTE B450 AORUS ELITE V2 AM4 AMD B450 SATA 6GB/S ATX AMD MOTHERBOARD - 7.00000
# Inserting product: GIGABYTE B450M K Ultra Durable Motherboard with GbE LAN and Bandwidth Management - 4.00000
# Inserting product: GIGABYTE B550M DS3H AM4 AMD B550 MICRO-ATX MOTHERBOARD - 5.12000
# Inserting product: GIGABYTE B550M K MOTHERBOARD - 6.00000
# Inserting product: GIGABYTE B650 AORUS Elite AM5/AMD B650/DDR5/ PCIe 5.0/ USB 3.2 Gen2X2 Type-C - 12.50000
# Inserting product: Gigabyte Z790 D DDR5 ATX Motherboard - 10.00000
# Inserting product: GIGABYTE Z790 S DDR4 Motherboard - 10.00000
# Inserting product: GIGABYTE Z790 UD Intel LGA 1700 ATX Motherboard DDR5 - 11.29000
# Inserting product: Hiksemi Wave 128Gb Internal Soild State Drive - 72000
# Inserting product: HIKVISION E100 128GB SSD - 75000
# Inserting product: HikVision SSD E100 256GB Solid State Drive - 1.20000
# Inserting product: Intel Core i3-12100F 3.3 GHz Quad-Core LGA 1700 Processor - 3.49900
# Inserting product: Intel Core i3-14100F Desktop Processor - 5.90000
# Inserting product: Intel Core i5-14400 Desktop Processor - 10.49900
# Inserting product: Intel Core i5-14400F 2.5 GHz 10-Core LGA 1700 Processor, 10 Cores & 16 Threads, 20MB Cache, 5 GHz Maximum Turbo Boost - 7.69900
# Inserting product: Intel Core I7 13700KF Processor - 18.00000
# Inserting product: Intel Core i9-14900KF 14th Gen 24-Core (8P+16E) LGA 1700 - 30.00000
# Inserting product: INTEL LGA 1200 CPU COOLER - 49000
# Inserting product: Intel® Core™ i5-12400F Processor  6 Core 12 Thread Up To 4.4GHz LGA1700 - 6.50000
# Inserting product: Kingston A400 960 GB SSD Solid State Drive 2.5 Inch SATA 3 - 3.20000
# Inserting product: Kingston Fury Beast 8 GB 3200 MHz DDR4 CL16 Desktop Memory Single Stick - 1.20000
# Inserting product: Kingston NV2 1TB M.2 2280 NVMe Internal SSD PCIe 4.0 Gen 4×4 - 3.50000
# Inserting product: Kingston NV2 2TB NVMe PCIe 4.0 M.2 SSD - 6.50000
# Inserting product: Kingston NV2 500G M.2 2280 NVMe PCIe Internal SSD Up to 3500 MB/s - 2.00000
# Inserting product: KINGSTON NV3 PCIe 4.0 NVMe SSD 1TB UP TO 6000MB s  M.2 2280 3D NAND - 3.85000
# Inserting product: L’AVVENTO (DC136) – OTG Type-C Cable To USB Female – 20CM - 13000
# Inserting product: L’avvento (MO997) 2.4GHz Wireless Presenter - 1.50000
# Inserting product: L’AVVENTO (US518) Hub Type-C to 4 USB 3.0 Ports with Super Speed up to 5GB/S - 55500
# Inserting product: L’avvento CV567 5 in 1 Hub from USB/Type-C to 1* USB 3.0 2* USB 2.0, SD Card Reader Micro SD Card Reader - 45000
# Inserting product: Lexar NM620 1TB SSD, M.2 2280 PCIe Gen3x4 NVMe SSD, Up to 3500MB/s - 3.50000
# Inserting product: Lexar NM620 M.2 2280 NVMe SSD 512GB up to 3500MB/s Read, 2400MB/s Write - 2.00000
# Inserting product: Lexar RAM For Laptop 16GB DDR4 3200MHz - 1.90000
# Inserting product: Lexar Thor DDR4 RAM 16GB Kit (2x8GB) 3200MHz CL16 Desktop Memory, XMP 2.0 High Performance Computer Memory - 1.85000
# Inserting product: Logitech G29 Driving Force Racing Wheel - 17.00000
# Inserting product: Logitech Gamepad F310 USB - 1.40000
# Inserting product: LOGITECH R500s Bluetooth Presentation Remote - 2.00000
# Inserting product: Logitech Wireless Gamepad F710 - 2.20000
# Inserting product: MB GIGABYTE Z790 EAGLE AX DDR5 Wi-Fi 6E - 12.50000
# Inserting product: Meetion SP2011 2.0 Usb Wired Speaker - 39900
# Inserting product: GIGABYTE Z590 AORUS PRO AX  rev. 1.0   - 4899
# Inserting product: GIGABYTE Z590 GAMING X  rev. 1.0  GAMING X  - 3699
# Inserting product: GIGABYTE B560M DS3H  rev. 1.0   - 2100
# Inserting product: ASROCK MOTHERBOARD H61M-VS3 - 600
# Inserting product: ASRock B450 PRO4 ATX Motherboard  - 1350
# Inserting product: ASRock B450M PRO4 Micro ATX Motherboard  - 1300
# Inserting product: MSI B450M Pro M2 Max AMD B450 AM4 Motherboard  - 1400
# Inserting product: ASRock B550 PRO4 AMD AM4 SOCKET Ryzen Processors Motherboard - 2500
# Inserting product: ASRock B550M PRO4  AMD AM4 SOCKET Ryzen Processors Motherboard - 2200
# Inserting product: gigabyte H310M S2 Ultra Durable motherboard with GIGABYTE 8118 Gaming LAN  Anti-Sulfur Resistor  Smart Fan5  CEC 2019 ready - 780
# Inserting product: AORUS X570 AORUS ELITE WIFI  rev. 1.x  - 4300
# Inserting product:  GIGABYTE-MOTHERBOARD-AMD-B550M AORUS PRO-P - 4250
# Inserting product: GIGABYTE-MOTHERBOARD-AMD-X570-AORUS-PRO-WIFI  - 5300
# Inserting product:  GIGABAYT-AORUS-Motherboard B550 AORUS PRO AX - 6350
# Inserting product: GIGABYTE B560M AORUS PRO AX  rev. 1.0  - 3600
# Inserting product: GIGABYTE Intel   Z590 UD-AC Ultra Durable Motherboard - 4200
# Inserting product: ASUS TUF GAMING H470-PRO  WI-FI  - 3199
# Inserting product:  ASUS TUF GAMING Z490-PLUS  WI-FI  - 4200
# Inserting product: ASUS Z490 ROG MAXIMUS XII HERO  WI-FI  - 5000
# Inserting product: ASUS ROG STRIX X299-E GAMING - 5999
# Inserting product: ASUS Prime B450M-K II  AMD AM4 Socket for AMD Ryzen 5000 4000  3rd 2nd 1st Gen  Micro ATX Motherboard with M.2 Support HDMI DVI-D D-Sub SATA 6 Gbps 1 Gb Ethernet USB 3.2 Gen 1 Type-A  BIOS Flashback - 3150
# Inserting product: ASUS TUF GAMING B450M-PLUS II - 3249
# Inserting product: ASUS ROG Maximus XII Formula Z490  WiFi 6  LGA 1200  Intel 10th Gen  ATX Gaming Motherboard - 5200
# Inserting product: Asus Prime TRX40-PRO AMD 3rd Gen Ryzen Threadripper Strx4 ATX Motherboard - 8450
# Inserting product: ASUS ROG Strix TRX40-E Gaming motherboard - 9999
# Inserting product: Asrock B550M Steel Legend - 2799
# Inserting product: Asrock B550 Steel Legend - 3250
# Inserting product: Asrock B550 Taichi - 5499
# Inserting product: Asrock B460M Steel Legend - 1999
# Inserting product: ASROCK B460 Steel Legend - 2299
# Inserting product: Gigabyte A520M S2H  AMD Ryzen AM4 MicroATX 4 3 Phases Digital PWM Gigabyte Gaming - 1799
# Inserting product: MSI B450 GAMING PRO CARBON MAX WIFI AM4 AMD B450 SATA 6Gb s ATX AMD Motherboard - 2299
# Inserting product: MSI A520M PRO Gaming Motherboard  AMD AM4  DDR4  PCIe 4.0  SATA 6Gb s  Dual M.2  USB 3.2 Gen 1  HDMI DP  Micro-ATX   - 1450
# Inserting product: GIGABYTE Z490M Multi-Graphics  Intel GbE with cFosSpeed  USB 3.2 Gen2 Type-A  USB 3.2 Gen1 Type-C MOTHERBOARD - 3000
# Inserting product: GIGABYTE Z490 UD AC LGA 1200 Intel Z490 ATX Motherboard with Dual M.2  SATA 6Gb s  USB 3.2 Gen 2  Intel 802.11ac - 3400
# Inserting product: Gigabyte B460M D2V Motherboard 10th Gen PCIe Gen3 x4 M.2  Anti-Sulfur Resistor Ultra Durable Motherboard - 1700
# Inserting product: GIGABYTE B550M Gaming with Pure Digital VRM Solution  PCIe 4.0 3.0 x4 M.2  RGB Fusion 2.0 motherboard - 3555
# Inserting product: Gigabyte B550M S2H mATX Motherboard for AMD AM4 CPUs  - 2805
# Inserting product:  ASUS TUF GAMING B460M-PLUS MOTHERBOARD - 2499
# Inserting product:  ASUS ROG STRIX B460-F GAMING  Socket 1200 B460 DDR4 S-ATA 600 ATX   - 3399
# Inserting product: ASUS TUF Gaming B450M-PRO S AMD AM4  3rd Gen Ryzen Micro ATX Gaming Motherboard - 3999
# Inserting product: ASUS TUF Gaming B550M-PLUS  WiFi 6  AMD AM4  3rd Gen Ryzen microATX Gaming Motherboard - 3199
# Inserting product: ASRock G41M-VS3 R2.0 Core 2 Quad  Intel G41  DDR3  A V L  Micro ATX LGA 755 Motherboard  - 300
# Inserting product: MSI B450M PRO-VDH Max ProSeries AMD Ryzen AM4 M.2 USB 3 DDR4 D-Sub DVI HDMI Micro-ATX Motherboard - 3600
# Inserting product: MSI A320M-A PRO MAX AMD AM4 motherboard inspired from architectural design  with Core Boost  DDR4 Boost  Turbo M.2  USB 3.2 Gen1 - 1050
# Inserting product: MSI B460M-A PRO ProSeries Motherboard mATX  10th Gen Intel Core  LGA 1200 Socket  DDR4  M.2 Slot - 1700
# Inserting product: MSI B460M PRO Intel B460 Chipset LGA200 - 1550
# Inserting product: MSI MAG B460M Mortar WiFi Gaming Motherboard  mATX  10th Gen Intel Core  LGA 1200 Socket  DDR4  CFX  Dual M.2 Slots - 2250
# Inserting product: MSI MAG B460M Mortar Gaming Motherboard  mATX  10th Gen Intel Core  LGA 1200 Socket  DDR4  CFX - 2200
# Inserting product: MSI MAG B460M Bazooka Gaming Motherboard  mATX  10th Gen Intel Core  LGA 1200 Socket  DDR4  Dual M.2 Slots - 2050
# Inserting product: ASUS ProArt Z490-CREATOR 10G   Intel Z490 LGA 1200 ATX Content Creation Motherboard - 3500
# Inserting product: MSI B460M PRO-VDH WiFi ProSeries Motherboard  mATX  10th Gen Intel Core  LGA 1200 Socket  DDR4  Dual M.2 Slots  2.5G LAN  Wi-Fi  - 1949
# Inserting product: MSI MAG B460 Tomahawk Gaming Motherboard  ATX  10th Gen Intel Core  LGA 1200 Socket  DDR4  CFX  Dual M.2 Slots - 2700
# Inserting product: MSI MAG Z390 Tomahawk LGA1151  Intel 8th and 9th Gen  M.2 USB 3.1 Gen 2 DDR4 Gaming Motherboard  - 3300
# Inserting product: MSI MAG B550 TOMAHAWK Gaming Motherboard  AMD AM4  DDR4  PCIe 4.0 - 3450
# Inserting product: MSI MAG B550M Mortar WiFi Gaming Motherboard  AMD AM4  DDR4  PCIe 4.0  - 3300
# Inserting product: MSI B550M PRO-VDH WiFi ProSeries Motherboard  AMD AM4  DDR4  PCIe 4.0  SATA 6Gb s  M.2  - 5650
# Inserting product: MSI MAG B550M Mortar Gaming Motherboard  AMD AM4  DDR4  PCIe 4.0  SATA 6Gb s  M.2  USB 3.2 Gen 2  HDMI DP  Micro-ATX  AMD Ryzen 5000 Series Processors  - 4850
# Inserting product: MSI A320M Pro Max AMD AM4 Micro ATX DDR4-SDRAM Motherboard - 1050
# Inserting product: Mainboard G41 X-Power Motherboard intel core2duo - core duo - core celeron - pentium 4 - 350
# Inserting product:  MSI MAG B550M Bazooka Gaming Motherboard  AMD AM4  DDR4  PCIe 4.0  SATA 6Gb s  M.2  USB 3.2 Gen 1  HDMI DP  Micro-ATX   - 4850
# Inserting product: MSI MPG B550 Gaming Plus Gaming Motherboard  AMD AM4  DDR4  PCIe 4.0  - 2950
# Inserting product: MSI MPG X570 GAMING PLUS Motherboard  RGB and RAINBOW LED strip  AMD AM4  PCIe 4.0  DDR4  - 3700
# Inserting product: MSI MPG X570 GAMING PRO CARBON WIFI Motherboard Mystic Light RGB  AMD AM4  DDR4  PCIe 4.0  SATA 6Gb s  M.2  USB 3.2 Gen 2  AX Wi-Fi 6  HDMI  ATX   - 5150
# Inserting product:  MSI Meg X570 Unify Motherboard  AMD AM4  DDR4  PCIe 4.0  SATA 6GB s  M.2  USB 3.2 Gen 2  Ax Wi-Fi 6  Bluetooth 5  ATX   - 6900
# Inserting product: MSI MAG X570 Tomahawk WiFi Motherboard  AMD AM4  DDR4  PCIe 4.0  SATA 6Gb s  M.2  USB 3.2 Gen 2  AC Wi-Fi 6  HDMI  ATX   - 4550
# Inserting product: ECS G41T-M16 Motherboard supports core2 quad - core2 duo - 350
# Inserting product: GIGABYTE B460 HD3 Motherboard with Dual NVMe PCIe Gen3 M.2 Slots - 2100
# Inserting product: AORUS B460M PRO Motherboard with RGB Fusion 2.0 with Digital LEDs  Intel   GbE LAN with cFosSpeed - 2350
# Inserting product: GIGABYTE GAH81M-WW ULTRA DURABLE 4th Generation Intel   Core MOTHERBOARD  TRAY  - 900
# Inserting product: Gigabyte H470 HD3  LGA1200INTELH470ATXDual M.2SATA 6GbsUSB 3.2 Gen 1HDMI DDR4 Motherboard  - 2450
# Inserting product: ASUS ROG Strix B550-F Gaming  WiFi 6  AMD AM4  3rd Gen Ryzen ATX Gaming Motherboard - 6699
# Inserting product: ASUS ROG Strix B550-E Gaming AMD AM4  3rd Gen Ryzen ATX Gaming Motherboard - 5400
# Inserting product: Gigabyte H470M DS3H LGA1200 MOTHERBOARD - 2150
# Inserting product: GIGABYTE H410M S2H MOTHERBOARD - 1550
# Inserting product: GIGABYTE B550 VISION D motherboard - 7200
# Inserting product: AORUS B460 PRO AC Motherboard with Direct 8 2 Phase Digital VRM Design - 3150
# Inserting product: GIGABYTE B550 GAMING X Motherboard with Digital VRM Solution - 6499
# Inserting product: GIGABYTE Intel B460M DS3H AC Ultra Durable Motherboard - 2000
# Inserting product: GIGABYTE AORUS B450  ELITE AM4 AMD Motherboard with Hybrid Digital PWM - 5250
# Inserting product: GIGABYTE B550M DS3H Motherboard - 5300
# Inserting product: AORUS B550  ELITE Motherboard - 7499
# Inserting product: AORUS B550  PRO AC with True 12 2 Phases Digital VRM Motherboard - 4500
# Inserting product: GIGABYTE B550 AORUS MASTER - 9499
# Inserting product: ASUS TUF Gaming H470-PRO WiFi ATX Gaming Motherboard RGB Header and Aura Sync - 3199
# Inserting product: ASUS PRIME B550M-A WIFI RGB headers  Ryzen AM4  micro ATX motherboard - 6000
# Inserting product:  Asus ROG Strix B450-F Gaming RGB LED lighting Motherboard - 2200
# Inserting product:  Asus Prime B450M-K AMD AM4 mATX motherboard withwith LED lighting - 2325
# Inserting product: Asus Prime B450M-A AMD AM4 mATX motherboard with Aura Sync RGB header - 1550
# Inserting product:  ASUS TUF Gaming B550M-PLUS AMD AM4  3rd Gen Ryzen Micro ATX Gaming Motherboard - 5499
# Inserting product: Asus Prime X570-P AMD AM4 ATX motherboard with PCIe 4.0 Aura Sync RGB - 3450
# Inserting product: ASUS TUF Gaming B460-PRO WiFi 6 LGA1200  Intel 10th Gen  ATX gaming motherboard - 2500
# Inserting product: ASUS TUF GAMING B460M-PLUS  WI-FI  LGA1200  Intel 10th Gen  Micro ATX Gaming Motherboard - 2499
# Inserting product: ASUS TUF GAMING Z490-PLUS  WI-FI  - 4300
# Inserting product: MSI MAG Z490 Tomahawk Gaming Motherboard - 4250
# Inserting product: MSI MPG Z490 GAMING PLUS MOTHERBOARD - 3700
# Inserting product: MSI MPG Z490 Gaming Edge WiFi ATX Gaming Motherboard - 4500
# Inserting product: MSI MPG Z490 Gaming Carbon WiFi Gaming Motherboard - 5400
# Inserting product: GIGABYTE Z490 VISION G LGA 1200 Intel Z490 ATX Motherboard with Dual M.2  SATA 6Gb s  USB 3.2 Gen 2 - 4700
# Inserting product: AORUS Z490 PRO AX Motherboard Intel LGA1200-Z490-ATX-Intel 2.5G LAN-Direct 12 Phase Digital Power-Dual M.2-SATA 6Gb-s-USB 3.2 Gen 2-Intel WiFi 6 - 4000
# Inserting product: AORUS Z490 ULTRA MOTHERBOARD with Direct 12 1 Phases Digital VRM Design 10th Gen Intel - 3899
# ...
# Inserting product: NINJA R7 5700 3070TI-402- MSI B550 MAG TOMAHAWK MAX WIFI- AMD Ryzen 7 5700 - Vulcan Z 2X16GB 3200MHz- Colorful RTX 3070TI 8GB- KLEVV CRAS C710 512GB- Aerocool GEOFLOW ARGB MID TOWER CASE- Aerocool LUX 750W- Aerocool Cylon 4F ARGB CPU AIR CO - 48499
# Inserting product: NINJA R7 5700 6800XT-403- MSI B550 MAG TOMAHAWK MAX WIFI- AMD Ryzen 7 5700 - Vulcan Z 2X16GB 3200MHz- XFX RX6800XT 16GB- KLEVV CRAS C710 512GB- Aerocool GEOFLOW ARGB MID TOWER CASE- Aerocool LUX 750W- Aerocool Cylon 4F ARGB CPU AIR COOLER - 52999
# Inserting product: JINX I5 13400F 7600 8GB -012- Intel Core i5-13400F -ASUS PRIME B760M-A D4 - XFX RX7600 8GB GDDR6 - KLEVV CRAS XR RGB 16GB 8GB x 2 3600MHz - Klevv Cras C710 1TB - Aerocool Designer ARGB MID TOWER AND 650W PSU - 39199
# Inserting product:   JINX R5 7500F 2060-009-AMD Ryzen 5 7500F Tray-ASUS TUF GAMING B650M-E-COLORFUL RTX2060 SUPER NB 8GB-Patriot VIPER VENOM DDR5 RAM 16GB 2X8GB 5200MHz-Lexar NM620 M.2 2280 NVMe SSD 1TB-GAMDIAS CASE AURA GC1 Elite 4xFRGB Whit GAMDIAS HELIOS E - 36350
# Inserting product: Jinx 13100F 3050 -007-Intel Core i3100F-GIGABYTE B660M D2H DDR4-GeForce RTX 3050 EAGLE OC 8Gb-Team T-Force Delta RGB DDR4 8GB 3200MHz  2x8 -HP EX900 Plus M.2 PCIe 3.0 x4 NVMe 256 GB-BitFenix Saber Case-Gigabyte P550B 80 PLUS Bronze 550W PSU - 25999
# Inserting product: Jinx 13400F 2060 006- Intel Core i5-13400F-GIGABAYT B660M DS3H DDR4-GIGABAYT GeForce RTX 2060 WINDFORCE OC 12G-HP V6 DDR4 16GB 3200Mhz 2x8 -Lexar NM620 M.2 256GB-COUGAR Case DUOFACE 3 FAN RGB POWER VTE X2 650W - 27999
# Inserting product: JINX 12100F 1660S  004-Intel Core i3-12100F-ASUS PRIME H610M-K D4-GAINWARD GTX 1660 SUPER Ghost 6G-Crucial 8GB DDR4-3200-HIKVISION E100 128GB-2B PW017 Ecstasy Gaming Mid Tower-COOLER MASTER ELITE 600W TRAY    - 16799
# Error fetching https://www.sigma-computer.com/subcategory?id=7&cname=Bundles&id2=97&scname=Sigma Friday&page=1: 524 Server Error:  for url: https://www.sigma-computer.com/subcategory?id=7&cname=Bundles&id2=97&scname=Sigma%20Friday&page=1
# Error fetching https://www.sigma-computer.com/subcategory?id=8&cname=Other&id2=23&scname=Projector&page=1: 524 Server Error:  for url: https://www.sigma-computer.com/subcategory?id=8&cname=Other&id2=23&scname=Projector&page=1
# Inserting product: Hp 137fnw personal laser multifunction printer - 11299
# Inserting product: HP LaserJet Pro M404dn - 5750
# Inserting product: HP LaserJet Pro M15w Printer - 4990
# Inserting product: HP PRINTER - LASERJET-PRO M404n - 7999
# Inserting product: Canon Imageclass MF3010 Laser MFP ALL IN ONE - 3500
# Inserting product:  HP LaserJet Pro MFP M130a Multifunction Printer - 3300
# Inserting product: HP LaserJet Pro M404n Laser Printer with Built-in Ethernet   Security Features - 5750
# Inserting product: HP Laser MFP 135w Multifunction Printer  Print  copy  scan built-in Wi-Fi    White - 4ZB83A  - 8599
# Inserting product:  HP LaserJet Pro M15w Printer USB 2.0 Hi-Speed Wi-Fi-Cartridge 44A - 2250
# Inserting product: HP 135A  MFP Laser Multifunction Printer - 6100
# Inserting product: HP LaserJet Pro MFP M130fw - 2400
# Inserting product: HP LaserJet Pro M28W Printer - 3000
# Inserting product: HP LaserJet Pro MFP M28a - 3000
# Inserting product: HP LaserJet Pro M15a Printer - 1800
# Inserting product: HP DeskJet Ink 3788 All-in-One Printer Wireless - Red - 950
# Inserting product: Canon I-SENSYS LBP6030B Mono Laser Printer - 1700
# Inserting product: HP ScanJet Pro 2500 f1 Flatbed Scanner - L2747A - 3000
# Inserting product: Canon CanoScan LiDE 300 - 975
# Inserting product: LG GP65NB60 8X USB 2.0 Ultra Slim Portable DVD Writer Burner Drive - 700
# Inserting product: ASUS ZenDrive U8M  SDRW-08U8M-U  - 750
# Inserting product: DVD-R 16x Recordable 4.7GB   120 Mins - Pack of 50  - 200
# Inserting product: DRW-24D5MT - 24X DVD-RW DL Drive - 300
# Inserting product: TRANSCEND Transcend External DVD Writers - 450
# Inserting product: ASUS SDRW-08D2S-U LITE external 8X DVD writer  Mac Compatible  M-DISC support  Disc Encryption  NERO Backitup  E-Green  E-Media - 1299
# Inserting product: ASUS DRW-24D5MT - 24X DVD-RW DL Drive - 300
# Inserting product: HIKSEMI M.2 SSD COOLER HEATSINK MH1 - 550
# Inserting product: SIA GEN1 POWER STRIP 3USB-A & 4 power sockets - 225
# Inserting product: SIA Power Strip, 3 USB Port, 6 Power Socket, White - SI-PS003W. - 275
# Inserting product:  SIA Power Strip, 6 USB-A Ports, 3 Power Sockets, Black and White - SI-PS001G - 325
# Inserting product: Camelion Pen Light  - 99
# Inserting product: Remax RPP-139 LEADER Series 10000mAh Power Bank - white - 215
# Inserting product: YK DESIGN YKP-021 10000MAH POWERBANK DUAL USB OUTPUT - 160
# Inserting product: TOOLS-INGCO-Screwdriver set (9 Pcs) HKSD0928 - 249
# Inserting product: Ingco 6pcs mini plier set, jewelry pliers tools kit beading pliers set hmps06115 - 400
# Inserting product: HAVIT CHARGE HV-UC110 PD20W Charger - 225
# Inserting product: HAVIT CHARGE UC117 Three USB travel charger - 225
# Inserting product: HAVIT CHARGE Hv-uc111 Pd20w+qc3.0 Wall Charger - 299
# Inserting product: HAVIT CABLE  H693 USB-A USB-C 3.0 2A - 275
# Inserting product: HAVIT CHARGE UC30 Wall Charger 33W Dual Ports( PD 30W,USB-A 18W) Support (PPS/PD3.0),EU Black - 450
# Inserting product: HAVIT CHARGE UC30 Wall Charger 33W Dual Ports( PD 30W,USB-A 18W) Support (PPS/PD3.0),EU  - 500
# Inserting product: Ldnio Power Strip, 3 Sockets, 6 USB Ports 2500W, Grey - SC3604 - 275
# Inserting product: Power Strip Systemmax 4Port/2USB - SMPG-4P2U 2.1A - 500
# Inserting product: Power Strip Systemmax 5 Port - SMPG-5P - 450
# Inserting product: Power Strip SystemMax 4 Port - SMPG-4P - 249
# Inserting product: INGCO Blower 600W AB6008 - 899
# Inserting product: INGCO 6 Pcs screwdriver set HKSD0628 - 250
# Inserting product: I-ROCK 4 BLACK EYE ELECTRICITY JOINT MADE IN TURKEY WITH A CAPACITY OF 10 AMPS AND 2500 WATTS - 110
# Inserting product: Ingco HES13041VSB Power Strip - 3 Socket - 3M - 13A - 160
# Inserting product: INGCO 8 Pcs screwdriver set HKSD0828 - 250
# Inserting product: INGCO 5pcs mini pliers set 4.5 mm - 275
# Inserting product: INGCO AB4018 Aspirator Blower 400 Watt - 599
# Inserting product: HP 107A Laser Printer  White - 5399
# Inserting product:  HP 107w Laser Wireless Printer  .White - 6299
# Inserting product:  HP Laser Printer MFP 135A - 6100
# Inserting product: Sony Playstation 5 Disc Version Silm PS5 Console With Dual Sense Controller - White - 34999
# Inserting product: Sony PlayStation 5 Standard 825GB - 33999
# Inserting product: Gran Turismo 7 Standard Edition - PlayStation 5 - 499
# Inserting product: SONY Playstation 5 Standard Edition CFI-1116A  with game Gran Turismo 7 - 18999
# Inserting product: SONY Playstation 5 Standard Edition CFI-1116A - 15999
# Inserting product: Playstation Sony 4  500 GB Bundle 3 Games   3 Months PS Plus subscription  - 7600
# Inserting product: Sony PlayStation 4 Slim with 3 Games and PlayStation Plus 90 Days Subscription  500GB  Jet Black - 7700
# Inserting product: PLAYSTATION DualSense PS5 Controller - Cosmic Red - 4999
# Inserting product: PLAYSTATION DualSense PS5 Controller - Midnight Black. - 4999
# Inserting product: PLAYSTATION DualSense PS5 Controller - White. - 3999
# Inserting product: XBOX-Microsoft-X-BOX SERIES S 1TB - 22499
# Inserting product: Xbox Series X 1Tb     Diablo IV Bundle - 28999
# Inserting product:  Microsoft Xbox Series S Digital Edition Console  512GB  with Wireless Controller   3 Months of Game Pass Ultimate  White - 17999
# Inserting product: Microsoft Xbox Series S Digital Edition Console  512GB  with Fortnite  Fall Guys   Rocket League Bundle - 17999
# Inserting product: Xbox Wireless Controller Shock Blue - 3499
# Inserting product: Xbox Wireless Controller Carbon Black - 3499
# Inserting product: Samsung UA43T5300 - 43-inch Full HD Smart TV With Built-In Receiver - 5800
# Inserting product:  Samsung 32-inch HD Smart TV With Built-In Receiver LED HD 1366×768 - UA32T5300 - 3600
# Inserting product:  Samsung UA32N5000 - 32-inch HD TV With Built-In Receiver 32N5000 - 3100
# Inserting product: Huawei Matepad T10S LTE AGS3K-L09 4GB Ram,128GB - Deepsea Blue - 6499
# Inserting product: Huawei Matepad T8.0  LTE KOBE2k-L09 2GB Ram,32GB - Deepsea Blue - 3499
# Inserting product: Huawei Matepad T10S LTE AGS3K-L09 4GB Ram,64GB - Deepsea Blue - 5949
# Inserting product: Lenovo Tab M7 Tablet, 7 Inch HD Display, 16 GB, 1 GB RAM, Android 9, 3G - Onyx Black - 1250
# Inserting product: Windows 10 Pro 64-bit Key - 899
# Inserting product: KASPERSKY INTERNET SECURITY MULTI DEVICE 4 USER 1 YEAR - 600
# Inserting product:  Awei H16 1.96 in HD Full Touch Screen Watch  BLUE  - 1650
# Inserting product: Awei H16 1.96 in HD Full Touch Screen Watch  Black  - 1650
# Inserting product: HUAWEI Band 6 Sakura Pink All-Day SpO2 Monitoring1   FullView Display   2-Week Battery Life - 1075
# Inserting product: HUAWEI Band 6 Amber Sunrise All-Day SpO2 Monitoring1   FullView Display   2-Week Battery Life - 1075
# Inserting product: HUAWEI Band 6 Forest Green WATCH All-Day SpO2 Monitoring1   FullView Display   2-Week Battery Life - 1075
# Inserting product: HUAWEI Band 6 dark gray WATCH All-Day SpO2 Monitoring1   FullView Display   2-Week Battery Life - 1075
# Inserting product: JSAUX  PB2002  Super Mini 22.5W Powerbank 10000mAh QC PD 3.0 Dual Port Portable Charger- Black - 649
# Inserting product: Remax RPP-100 10000 mAh Repin Series Mini Power Bank with Display wireless- black - 300
# Inserting product: WK DESIGN Power Bank Portable Charger Compact   Slim External Battery with High Capacity  Made for iPhone  iPad  Samsung Galaxy and More -Black - 160
# Inserting product: Yk Design YKP-020 Power Bank 20000mah Dual Port- BLACK - 175
# Inserting product: Proda Ultron Series PD-P32 Power Bank  10000 mah - WHITE - 160
# Inserting product: Proda PD-P50 Gladiator Series 10000mAh Fast   Dual USB Port Power Bank - Black - 160
# Inserting product: Proda PD-P39 Hujon Series Wired Power Bank  10000 mAh - White - 160
# Inserting product: LDNIO PW1003 High Capacity Mobile phone charging station10000mAh Wireless charger power bank - 300
# Inserting product: Remax RPP-140 Leader Series Wired Power Bank  20000 mAh  2 Ports - Black - 150
# Inserting product: Power Bank REMAX JONSHON LCD RPP-153 10 000MAH White - 88
# Inserting product: Remax RPP-141 Leader Series Wired Power Bank  30000 mAh  2 Ports - WHITE - 350
# Inserting product: Remax RPP-159 Suchy Series Power Bank with 2 Charging Ports  10000 mAh - Black - 160
# Inserting product:  Extra 20000mAh Power Bank - White - 200
# Inserting product: Extra 10000mAh Power Bank - White - 99
# Inserting product: i-LIFE PB 2600 Power Bank - 35
# Inserting product: Power Bank - 15000 MAh - White- Team group - 250
# Inserting product: TEAM WP1000 Power Bank  10000mAh  Black - 150
# Inserting product: TEAM WP1000 Power Bank  10000mAh  - 150
# Inserting product: Rapoo P20 Power Bank - 5000 MAh - 100
# Inserting product:  Rapoo Power Bank - 13000 MAh P370 - 200
# Inserting product: Rapoo P390 Polymer - 10000mAh Powerbank - Black - 299
# Inserting product: Rapoo P200 - 10000 Mah Power Bank - Black - 220
# Inserting product: RAPOO  P170 Power Bank - 10000mAh - Black - 125
# Inserting product: JSAUX HB0501 USB-C 5 IN 1 MultiFunction USB C Adapter - 750
# Inserting product: GENERAL PLUG YS1204 CAR CHARGER - POWER ESSENTIAL USBA USBC. - 350
# Inserting product: GENERAL Travel Charger A24009 2 Usb USB-C PD20W   USB-A QC18W  - 350
# Inserting product: GENERAL USB-A CHARGER PLUG A24004 A5V 2A. - 200
# Inserting product: GENERAL CABLE USB TO TYPE C 1M - 125
# Inserting product: GENERAL CABLE USB TO IPHONE 1M - 125
# Inserting product: GENERAL CABLE TYPE C TO TYPE C 1M - 200
# Inserting product: GENERAL CABLE TYPE C TO IPHONE 1M - 200
# Inserting product: CHOETECH Charger USB Fast Charging 2 Port 2A EU Plug - C0030EU-WH - 200
# Inserting product: Choetech Cable Display PORT To Displayport XDD01 2M 8K-4K  - 110
# Inserting product: CHOETECH AC0013 USB Type C Cable For HUAWEI  5A SuperCharge Fast Charging  - 35
# Inserting product: CHOETECH Cable AB003 USB-A to Micro USB 1.2m V1 WHITE - 75
# Inserting product: CHOETECH CABLE AB003 USB-A to Micro USB 1.2m Cable BLACK - 75
# Inserting product: UGREEN USB Type-C Charging Cable 1.5M Black - 75
# Inserting product: UGREEN USB C to USB C Charging Cable Type C Fast Charger Power Cord 1Meter - 300
# Inserting product: GLORIOUS G-SKATES MOUSE FEET premium  - 200
# Inserting product: GLORIOUS MOUSE GRIP TAPE Lightweight anti-slip full body mouse grip tape BLACK GLO-ACC-GRP-O - 300
# Inserting product: General Plastic Led Light Clip For Camera - White - 75
# Inserting product: General LED Bi-Color Light Video Led Light 20W With Cable - 444
# Inserting product: GENERAL-LED-12W - 499
# Inserting product: GENERAL LED55RGB LIGHT - 2999
# Inserting product: GENERAL LED 55WB1 - 2799
# Inserting product: GENERAL-CONVERTAR-HDMI TO USB CAPTURE Portable For Live Streaming. - 349
# Inserting product: GENERAL Microphone Mount Stand, Durable and Adjustable, Black NB-39. - 350
# Inserting product: General VG-20 Vlogging Kit for Mobile with LED Light, K10 Wireless Microphone for iphone. - 749
# Inserting product: General VG-20 Vlogging Kit for Mobile with LED Light, K10 Wireless Microphone type c. - 1099
# Inserting product: GENERAL-STAND-TPA-1-فلاش - 599
# Inserting product: General K10 Wireless Microphone Camera – 1 mic - 349
# Inserting product: GENERAL CVM-V01SP(UC) Omnidirectional USB C Lavalier Microphone for Android Devices - 499
# Inserting product: GENERAL TL-5 soft box with 5 lamp holder - 2099
# Inserting product: ZHIYUN SMOOTH Q3 Smartphones Gimbal 3-Axis Flexible Phone Handheld Stabilizer with Fill Light for Android / IOS and And Every Smartphone  - 3999
# Inserting product: General - 25cm base - for 360 degree product photography - 999
# Inserting product: GENERAL MIC CVM-V01CP-6M FOR CAMERA OR UX - 499
# Inserting product: General T30RGB Tube Video Led Light Wand 10W 30Cm - 888
# Inserting product: GENERAL K2 iPhone K10 Wireless Microphone - 499
# Inserting product: General K10 k2 Microphone for Smartphone, Wireless Mini Microphone Plug & Play USB C Lavalier Microphone Wireless - 450
# Inserting product: General K10 K1 Microphone for Smartphone, Wireless Mini Microphone Plug & Play USB C Lavalier Microphone Wireless - 300
# Inserting product: BOYA MIC Omnidirectional Lavalier Microphone - BY-M1 - 400
# Inserting product: GENERAL Microphone Mic Wireless K1 iPhone K10 - 349
# Inserting product: General GH-W1 Headset Wireless Microphone - 999
# Inserting product: Zhiyun Smooth-X GERY COLOR  - 1750
# Inserting product: Zhiyun-Tech Smooth-X Smartphone Gimbal (White) - 1449
# Inserting product: LENSGO LYM-DM1D Dual Mini Lavalier Microphone - 325
# Inserting product: LENSGO LYM-DM1 Microphone - 375
# Inserting product: TL-4 kit, 2 soft box with 4 lamp holder . - 1199
# Inserting product: WEIFENG WT-3560 Tripod for SLR Camera DV Professional Photographic Kit Camera Stand - 899
# Inserting product: Weifeng WT-3540 Tripod Stand With Carry Case For DSLR Camera - 799
# Inserting product: Weifeng wt -3520 Tripod For Digital SLR Camera - 549
# Inserting product: General R1s Bluetooth Selfie Sticks with Remote and Selfie Light, 3-in-1 Multifunctional Selfie Stick Tripod Stand Compatible with iPhone/OnePlus/Samsung/Realme & All Smartphones/Go Pro (Black) - 195
# Inserting product: General Holder Clamp Local ML-01 - 99
# Inserting product: Adjustable Microphone Stand with Holder,360 Degree Rotating - 75
# Inserting product: معدات تصوير-GENERAL-كلامب موبايل بقفل -W-005 - 25
# Inserting product: General Gorilla Holder Stand Mobile &Camera - 199
# Inserting product: General Mini Ring Light 30 - 175
# Inserting product: General Mini Ring Light 25 - 99
# Inserting product: light stand WT-803 - 199
# Inserting product: General RING LIGHT LF-R420C 18 INCH - 1399
# Inserting product: Ring light R-380 38W - 749
# Inserting product: GENERAL-CONVERTER-AV TO HDMI - 499
# Inserting product: HDMI Video Capture Adapter - 249
# Error fetching https://www.sigma-computer.com/category?id=25&cname=Powered by ASUS&page=1: 524 Server Error:  for url: https://www.sigma-computer.com/category?id=25&cname=Powered%20by%20ASUS&page=1

# %%
# %pip install psycopg2
# %pip install requests
# %pip install beautifulsoup4
# Out:
# Collecting psycopg2Note: you may need to restart the kernel to use updated packages.
#
#   Downloading psycopg2-2.9.10-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Downloading psycopg2-2.9.10-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.2 MB 326.8 kB/s eta 0:00:04
#    --- ------------------------------------ 0.1/1.2 MB 585.1 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.2 MB 821.4 kB/s eta 0:00:02
#    ------- -------------------------------- 0.2/1.2 MB 919.0 kB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.2 MB 983.0 kB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.2 MB 1.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.4/1.2 MB 1.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.2 MB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.2 MB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 0.9/1.2 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.0/1.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 1.1/1.2 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
#    ---------------------------------------- 0.0/164.9 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/164.9 kB 960.0 kB/s eta 0:00:01
#    ----------------------- -------------- 102.4/164.9 kB 980.4 kB/s eta 0:00:01
#    ----------------------------- ---------- 122.9/164.9 kB 1.0 MB/s eta 0:00:01
#    -------------------------------------  163.8/164.9 kB 893.0 kB/s eta 0:00:01
#    -------------------------------------- 164.9/164.9 kB 822.8 kB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    --------------- ----------------------- 41.0/102.4 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 102.4/102.4 kB 1.2 MB/s eta 0:00:00
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.4 kB ? eta -:--:--
#    ------------------- -------------------- 61.4/128.4 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 122.9/128.4 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 128.4/128.4 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.12.14 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 urllib3-2.3.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Mohamed\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/147.9 kB 435.7 kB/s eta 0:00:01
#    ------------------ -------------------- 71.7/147.9 kB 563.7 kB/s eta 0:00:01
#    ------------------------------------ - 143.4/147.9 kB 853.3 kB/s eta 0:00:01
#    -------------------------------------- 147.9/147.9 kB 882.6 kB/s eta 0:00:00
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3 soupsieve-2.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
