# %%
import psycopg2
from psycopg2 import sql
from concurrent.futures import ThreadPoolExecutor
import requests
from bs4 import BeautifulSoup
import re

conn = psycopg2.connect(
    dbname="PcBuild",
    user="postgres",
    password="123",
    host="localhost",
    port="5432"
)
cursor = conn.cursor()
def upsert_store(cursor, store_name):
    cursor.execute('SELECT "Id" FROM "Stores" WHERE "Name" = %s', (store_name,))
    store_id = cursor.fetchone()
    if store_id:
        return store_id[0]
    insert_query = """
        INSERT INTO "Stores" ("Name")
        VALUES (%s)
        RETURNING "Id";
    """
    cursor.execute(insert_query, (store_name,))
    store_id = cursor.fetchone()
    
    # Return the ID of the newly inserted store
    return store_id[0] if store_id else None
def upsert_category(category_name):
    cursor.execute('SELECT "Id" FROM "Categories" WHERE "Name" = %s', (category_name,))
    category_id = cursor.fetchone()
    if category_id:
        return category_id[0]
    insert_query = """
        INSERT INTO "Categories" ("Name")
        VALUES (%s)
        RETURNING "Id";
    """
    cursor.execute(insert_query, (category_name,))
    category_id = cursor.fetchone()
    
    # Return the ID of the newly inserted store
    return category_id[0] if category_id else None

def fetch_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return BeautifulSoup(response.content, 'html.parser')
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

def upsert_product(store_name, product_data):
    try:
        query = """
            SELECT "Id" FROM "Stores" WHERE "Name" = %s;
        """
        cursor.execute(query, (store_name,))
        store_id = cursor.fetchone()
        
        if not store_id:
            print(f"Error: Store {store_name} not found.")
            return  
        store_id = store_id[0]
        cursor.execute(
            """
            SELECT "Id", "CurrentPrice" FROM "Products"
            WHERE "ProductUrl" = %s AND "StoreId" = %s;
            """,
            (product_data['link'], store_id)
        )
        query = """
            SELECT "Id" FROM "Categories" WHERE "Name" = %s;
        """
        cursor.execute(query,(product_data['category'],))
        category_id = cursor.fetchone()
        if not category_id:
            print(f"Error: Category {product_data['category']} not found.")
            return
        category_id = category_id[0]
        product = cursor.fetchone()

        if product:
            product_id, current_price = product
            if abs(float(current_price) - float(product_data['price'])) > 0.01: 
                cursor.execute(
                    """
                    UPDATE "Products"
                    SET "CurrentPrice" = %s
                    WHERE "Id" = %s;
                    """,
                    (product_data['price'], product_id)
                )
                cursor.execute(
                    """
                    INSERT INTO "Prices" ("Value", "ProductId", "Date")
                    VALUES (%s, %s, NOW());
                    """,
                    (product_data['price'], product_id)
                )
        else:
            print(f"Inserting product: {product_data['title']} - {product_data['price']}")

            cursor.execute(
                """
                INSERT INTO "Products" ("Name", "CurrentPrice", "StoreId", "ImageUrl", "ProductUrl","CategoryId")
                VALUES (%s, %s, %s, %s, %s,%s)
                RETURNING "Id";
                """,
                (
                    product_data['title'],
                    product_data['price'],
                    store_id,
                    product_data['image_url'],
                    product_data['link'],
                    category_id
                )
            )
            product_id = cursor.fetchone()[0]
            cursor.execute(
                """
                INSERT INTO "Prices" ("Value", "ProductId", "Date")
                VALUES (%s, %s, NOW());
                """,
                (product_data['price'], product_id)
            )
        conn.commit()
    except Exception as e:
        print(f"Error upserting product: {e}")
        conn.rollback()


# Function to scrape Sigma website
def scrape_sigma():
    base_url = "https://www.sigma-computer.com"
    main_page_url = f"{base_url}/home"
    main_soup = fetch_page(main_page_url)
    if not main_soup:
        return

    category_links = main_soup.select('div.sub-menu a.main-menu')
    for category_link in category_links:
        category_name = category_link.text.strip().lower()
        upsert_category(category_name)

        category_url = base_url + "/" + category_link['href']
        
        current_page_url = category_url + "&page=1"

        while True:
            soup = fetch_page(current_page_url)
            if not soup:
                break

            containers = soup.find_all('div', class_='product-item-container')
            for container in containers:
                anchor = container.find('a', href=True, title=True)
                title = anchor['title'] if anchor else "No title found"
                link = base_url + "/" + anchor['href'] if anchor else "No link found"
                price_span = container.find('span', class_='price-new')
                image_tag = container.find('img')
                image_url = base_url + "/" + image_tag['src'] if image_tag else "No image found"
                price = re.sub(r'[^\d.]', '', price_span.text.strip()) if price_span else None
                store_name = "Sigma Computer"

                if price:
                    product_data = {
                        "title": title,
                        "price": price,
                        "link": link,
                        "image_url": image_url,
                        "category": category_name
                    }
                    upsert_product(store_name, product_data)

            pagination = soup.find('ul', class_='pagination')
            next_page = pagination.find('a', rel='next') if pagination else None
            if next_page:
                current_page_url = next_page['href']
            else:
                break

def scrape_elnour():
    base_url = "https://elnour-tech.com/en/"
    main_soup = fetch_page(base_url)
    if not main_soup:
        return

    category_links = main_soup.select('.menu-item.menu-item-type-taxonomy.menu-item-object-product_cat')
    for category_link in category_links:
        category_name = category_link.text.strip().lower()
        upsert_category(category_name)
        category_url = category_link.select_one('a').get('href') if category_link.select_one('a') else None
        if not category_url:
            continue

        page_num = 1
        while True:
            page_url = f"{category_url}/page/{page_num}"
            soup = fetch_page(page_url)
            if not soup:
                break

            products = soup.select('.wd-product.product-grid-item')
            for product in products:
                add_to_cart_btn = product.select_one('.add_to_cart_button')
                if add_to_cart_btn:
                    title = product.select_one('.wd-entities-title').text.strip() if product.select_one('.wd-entities-title') else None
                    price_text = product.select_one('bdi').text.strip() if product.select_one('bdi') else None
                    price = re.sub(r'[^\d.]', '', price_text) if price_text else None
                    link = product.select_one('.wd-entities-title a').get('href') if product.select_one('.wd-entities-title a') else None
                    img_url = product.select_one('.product-wrapper img').get('src') if product.select_one('.product-wrapper img') else None
                    store_name = "Elnour Tech"

                    if price:
                        product_data = {
                            "title": title,
                            "price": price,
                            "link": link,
                            "image_url": img_url,
                            "category": category_name
                        }
                        upsert_product(store_name, product_data)

            next_page = soup.select_one('a.page-numbers.next')
            if next_page:
                page_num += 1
            else:
                break
def scrape_and_store(store_names):
    with conn:
        with conn.cursor() as cursor:
            print("Upserting stores...")
            store_ids = {name: upsert_store(cursor, name) for name in store_names}
            conn.commit()

def main():
    websites = {
        # "sigma": scrape_sigma,
        "elnour": scrape_elnour
    }
    stores = ["Sigma Computer", "Elnour Tech"]
    scrape_and_store(stores)
    with ThreadPoolExecutor() as executor:
        future_to_website = {executor.submit(scraper): name for name, scraper in websites.items()}
        for future in future_to_website:
            website = future_to_website[future]
            try:
                future.result()
            except Exception as e:
                print(f"Error scraping {website}: {e}")

if __name__ == "__main__":
    main()

conn.close()
# Out:
# Upserting stores...
# Inserting product: “Acer Nitro V ANV15-41-R8FH’ AMD Ryzen 5-7535HS 8GB RAM,512GB SSD,NVIDIA GeForce RTX 2050 4GB Graphics, 15.6″  Screen Size, Windows 11” - 30.00000
# Inserting product: ACER Predator Helios Neo 16 PHN16-72-99PA Gaming Core™’ i9 14900HX RAM 16 GB DDR5 1TB NVMe RTX”™ 4060 NVIDIA° 8 GB GDDR6 16INCH 165 Hz100% sRGB Windows 11 Home - 70.00000
# Inserting product: ASUS TUF F15 2024 FX507VV-LP156W INTEL CORE  i7-13620H – Nvidia  RTX 4060 8GB – 16GB DDR5 – 1TB SSD – 15.6 FHD 144HZ 100%SRGB – Win 11 - 58.00000
# Inserting product: ASUS TUF Gaming A15 FA506NCR-HN007W Laptop – AMD Ryzen™ 7-7435HS – 8GB – 512GB SSD – NVIDIA® GeForce® RTX™ 3050 4GB – 15.6” FHD – Win11 - 37.80000
# Inserting product: ASUS TUF Gaming A15 FA506NFR-HN007W Laptop – AMD Ryzen™ 7-7435HS – 8GB DDR5 – 512GB SSD – NVIDIA® GeForce® RTX™ 2050 4GB – 15.6” FHD – Win11 - 32.60000
# Inserting product: ASUS TUF Gaming A15 FA507NUR-LP007W Laptop – AMD Ryzen 7 7435HS – 16GB – 512GB SSD – NVIDIA® GeForce® RTX 4050 6GB – 15.6” FHD 144HZ – Win11 - 48.00000
# Inserting product: Dell Vostro 3520 – intel Core i5-1235U – Intel UHD Graphics – RAM 8GB DDR4 – 512GB SSD – 15.6-inch FHD 120Hz - 23.00000
# Inserting product: Dell Vostro 3520 Laptop – 12th Intel Core i3-1215U 6-Cores, 8GB RAM, 512GB SSD, Intel UHD Graphics, 15.6″ FHD (1920 x 1080) 120Hz 250 nits Anti-Glare, Ubuntu – Carbon Black - 18.00000
# Inserting product: DELL Vostro 3520 Laptop – 12th Intel core i7-1255U –  8GB RAM – 512 GB SSD –  Intel Iris Xe Graphics – 15.6″ FHD 120HZ - 30.00000
# Inserting product: HP 15-DW1380NIA LAPTOP – Intel Core i5-10210U – Intel UHD Graphics – 1TB HDD + 256GB SSD – 8GB RAM – 15.6” HD – Windows 11 – Black - 19.00000
# Inserting product: HP VICTUS 15-FA0033DX CORE  I5 12450H – RAM 8G –  SSD 512G –  RTX 3050 4G – 144HZ WIN11 - 32.50000
# Inserting product: Hp Victus 15-fa1041ne Gaming Intel i5 13500H – 8GB RAM DDR4 – 512GB SSD NVME –  NVIDIA GeForce RTX 3050 6GB GDDR6 Graphics 15.6 INCH FHD 144Hz IPS – Performance Blue - 40.00000
# Inserting product: HP Victus 15-FB2063DX Gaming Laptop –  AMD Ryzen 5 7535HS – AMD Radeon RX 6550M 4GB Graphics – 8GB RAM DDR5 – 512GB SSD – 15.6″ FHD IPS 144Hz Display – WIndows 11 - 29.40000
# Inserting product: HP Victus 16-S1023DX Gaming Laptop – AMD Ryzen 7 8845HS – GeForce RTX 4070 8GB Laptop Graphics – 16GB RAM DDR5 5600Mhz – 512GB SSD –  16.1″ FHD IPS 144Hz Display – Windows 11 - 65.00000
# Inserting product: Lenovo LOQ 15ARP9 Gaming Laptop 2024 –  AMD Ryzen 7 7435HS 8-Core – NVIDIA GeForce RTX 4060 8GB GDDR6 – 16GB RAM DDR5 – 512GB SSD – 15.6″ FHD IPS 144Hz 100% sRGB – Win11 - 50.00000
# Inserting product: Lenovo LOQ 15ARP9 Gaming Ryzen 5 7235HS – AI Chip: LA1 – 12GB DDR5 RAM –  512GB SSD NVME – NVIDIA GeForce RTX 3050 6GB GDDR6 Graphics – 15.6 INCH FHD IPS 100% sRGB 144Hz G-SYNC, Win 11 - 35.00000
# Inserting product: LENOVO LOQ 15IAX9 GAMING LAPTOP INTEL CORE I5-12450HX – NVIDIA RTX 2050 4G – RAM 16G DDR5 – SSD 512G – 15.6 FHD 144HZ G-SYNC SRGB 100% - 33.90000
# Inserting product: LENOVO LOQ 15IAX9 GAMING LAPTOP INTEL CORE I5-12450HX – NVIDIA RTX 2050 4G – RAM 8G DDR5 – SSD 512G – 15.6 FHD 144HZ G-SYNC SRGB 100% – LOQ GAMING MOUSE – 2Y Warranty - 32.50000
# Inserting product: Lenovo LOQ 15IRX9 Core™ i7-14700HX  – RAM 16G DDR5 – 1TB SSD NVMe – NVIDIA® GeForce RTX™ 4060 8GB GDDR6 – 15.6INCH FHD IPS 100% SRGB  144Hz  G-SYNC®- 2 Year Warranty + Lenovo Mouse - 60.00000
# Inserting product: Lenovo LOQ 15IRX9 Gaming – i7-13650HX 14 Cores – AI Chip: LA1 –  16GB  DDR5 RAM – 512GB SSD M.2 NVME – NVIDIA GeForce RTX 4050 6GB GDDR6 Graphics – 15.6″ FHD  IPS SRGB%100 144Hz – - 49.50000
# Inserting product: Lenovo LOQ 15IRX9 Gaming – i7-13650HX 14 Cores – AI Chip: LA1 –  16GB  DDR5 RAM – 512GB SSD M.2 NVME – NVIDIA GeForce RTX 4060 8GB GDDR6 Graphics – 15.6″ FHD  IPS SRGB%100 144Hz - 56.80000
# Inserting product: MSI Thin 15 B13VE Laptop – Intel® Core™ i7-13620H – RAM 16GB – 512GB SSD – NVIDIA® GeForce RTX™ 4050 6GB – 15.6″ FHD 144HZ - 47.00000
# Inserting product: MSI THIN GF63 12UCX GAMING LAPTOP – INTEL CORE I5-12450H RAM 8GB DDR4 SSD 512GB NVIDIA RTX 2050 4GB 144HZ - 32.00000
# Inserting product: HP 15-DW1380NIA LAPTOP – Intel Core i5-10210U – Intel UHD Graphics – 1TB HDD + 256GB SSD – 8GB RAM – 15.6” HD – Windows 11 – Black - 19.00000
# Inserting product: HP VICTUS 15-FA0033DX CORE  I5 12450H – RAM 8G –  SSD 512G –  RTX 3050 4G – 144HZ WIN11 - 32.50000
# Inserting product: Hp Victus 15-fa1041ne Gaming Intel i5 13500H – 8GB RAM DDR4 – 512GB SSD NVME –  NVIDIA GeForce RTX 3050 6GB GDDR6 Graphics 15.6 INCH FHD 144Hz IPS – Performance Blue - 40.00000
# Inserting product: HP Victus 15-FB2063DX Gaming Laptop –  AMD Ryzen 5 7535HS – AMD Radeon RX 6550M 4GB Graphics – 8GB RAM DDR5 – 512GB SSD – 15.6″ FHD IPS 144Hz Display – WIndows 11 - 29.40000
# Inserting product: HP Victus 16-S1023DX Gaming Laptop – AMD Ryzen 7 8845HS – GeForce RTX 4070 8GB Laptop Graphics – 16GB RAM DDR5 5600Mhz – 512GB SSD –  16.1″ FHD IPS 144Hz Display – Windows 11 - 65.00000
# Inserting product: ASUS TUF F15 2024 FX507VV-LP156W INTEL CORE  i7-13620H – Nvidia  RTX 4060 8GB – 16GB DDR5 – 1TB SSD – 15.6 FHD 144HZ 100%SRGB – Win 11 - 58.00000
# Inserting product: ASUS TUF Gaming A15 FA506NCR-HN007W Laptop – AMD Ryzen™ 7-7435HS – 8GB – 512GB SSD – NVIDIA® GeForce® RTX™ 3050 4GB – 15.6” FHD – Win11 - 37.80000
# Inserting product: ASUS TUF Gaming A15 FA506NFR-HN007W Laptop – AMD Ryzen™ 7-7435HS – 8GB DDR5 – 512GB SSD – NVIDIA® GeForce® RTX™ 2050 4GB – 15.6” FHD – Win11 - 32.60000
# Inserting product: ASUS TUF Gaming A15 FA507NUR-LP007W Laptop – AMD Ryzen 7 7435HS – 16GB – 512GB SSD – NVIDIA® GeForce® RTX 4050 6GB – 15.6” FHD 144HZ – Win11 - 48.00000
# Inserting product: Lenovo LOQ 15ARP9 Gaming Laptop 2024 –  AMD Ryzen 7 7435HS 8-Core – NVIDIA GeForce RTX 4060 8GB GDDR6 – 16GB RAM DDR5 – 512GB SSD – 15.6″ FHD IPS 144Hz 100% sRGB – Win11 - 50.00000
# Inserting product: Lenovo LOQ 15ARP9 Gaming Ryzen 5 7235HS – AI Chip: LA1 – 12GB DDR5 RAM –  512GB SSD NVME – NVIDIA GeForce RTX 3050 6GB GDDR6 Graphics – 15.6 INCH FHD IPS 100% sRGB 144Hz G-SYNC, Win 11 - 35.00000
# Inserting product: LENOVO LOQ 15IAX9 GAMING LAPTOP INTEL CORE I5-12450HX – NVIDIA RTX 2050 4G – RAM 16G DDR5 – SSD 512G – 15.6 FHD 144HZ G-SYNC SRGB 100% - 33.90000
# Inserting product: LENOVO LOQ 15IAX9 GAMING LAPTOP INTEL CORE I5-12450HX – NVIDIA RTX 2050 4G – RAM 8G DDR5 – SSD 512G – 15.6 FHD 144HZ G-SYNC SRGB 100% – LOQ GAMING MOUSE – 2Y Warranty - 32.50000
# Inserting product: Lenovo LOQ 15IRX9 Core™ i7-14700HX  – RAM 16G DDR5 – 1TB SSD NVMe – NVIDIA® GeForce RTX™ 4060 8GB GDDR6 – 15.6INCH FHD IPS 100% SRGB  144Hz  G-SYNC®- 2 Year Warranty + Lenovo Mouse - 60.00000
# Inserting product: Lenovo LOQ 15IRX9 Gaming – i7-13650HX 14 Cores – AI Chip: LA1 –  16GB  DDR5 RAM – 512GB SSD M.2 NVME – NVIDIA GeForce RTX 4050 6GB GDDR6 Graphics – 15.6″ FHD  IPS SRGB%100 144Hz – - 49.50000
# Inserting product: Lenovo LOQ 15IRX9 Gaming – i7-13650HX 14 Cores – AI Chip: LA1 –  16GB  DDR5 RAM – 512GB SSD M.2 NVME – NVIDIA GeForce RTX 4060 8GB GDDR6 Graphics – 15.6″ FHD  IPS SRGB%100 144Hz - 56.80000
# Inserting product: MSI Thin 15 B13VE Laptop – Intel® Core™ i7-13620H – RAM 16GB – 512GB SSD – NVIDIA® GeForce RTX™ 4050 6GB – 15.6″ FHD 144HZ - 47.00000
# Inserting product: MSI THIN GF63 12UCX GAMING LAPTOP – INTEL CORE I5-12450H RAM 8GB DDR4 SSD 512GB NVIDIA RTX 2050 4GB 144HZ - 32.00000
# Inserting product: “Acer Nitro V ANV15-41-R8FH’ AMD Ryzen 5-7535HS 8GB RAM,512GB SSD,NVIDIA GeForce RTX 2050 4GB Graphics, 15.6″  Screen Size, Windows 11” - 30.00000
# Inserting product: ACER Predator Helios Neo 16 PHN16-72-99PA Gaming Core™’ i9 14900HX RAM 16 GB DDR5 1TB NVMe RTX”™ 4060 NVIDIA° 8 GB GDDR6 16INCH 165 Hz100% sRGB Windows 11 Home - 70.00000
# Inserting product: Dell Vostro 3520 – intel Core i5-1235U – Intel UHD Graphics – RAM 8GB DDR4 – 512GB SSD – 15.6-inch FHD 120Hz - 23.00000
# Inserting product: Dell Vostro 3520 Laptop – 12th Intel Core i3-1215U 6-Cores, 8GB RAM, 512GB SSD, Intel UHD Graphics, 15.6″ FHD (1920 x 1080) 120Hz 250 nits Anti-Glare, Ubuntu – Carbon Black - 18.00000
# Inserting product: DELL Vostro 3520 Laptop – 12th Intel core i7-1255U –  8GB RAM – 512 GB SSD –  Intel Iris Xe Graphics – 15.6″ FHD 120HZ - 30.00000
# Inserting product: “|Intel Core i5-14600K 14 cores (6 P-cores & 8 E-cores), Integrated Graphics – Unlocked - 13.50000
# Inserting product: “Hikvision Memory 16GB C1 C10 “ - 17000
# Inserting product: “Redragon Fobos GW600 Webcam “ - 1.79900
# Inserting product: “Redragon PULSAR GM303 Condenser USB Microphone “ - 1.50000
# Inserting product: “T-DAGGER Webcam Gamer and Streamer T-Dagger Eagle HD 720p TGW620 “ - 1.30000
# Inserting product: 2B (CM663) Business Series FHD Webcam – 1280×1080 – With Microphone and light sensors – Black - 1.50000
# Inserting product: 2B (CR003) – USB 2.0 – Card Reader All in one 480 Mbps - 34000
# Inserting product: 2B (CV132) USB 3.0 – 4Port HUB Super - 48000
# Inserting product: 2B (CV143) Type C Male to VGA – HDMI - 65000
# Inserting product: 2B (CV145) Type C to Display Port Converter - 48000
# Inserting product: 2B (CV146) Type C Male to VGA – HDMI – DVI – USB3 - 90000
# Inserting product: 2B (CV224) Converter From Type C Male to VGA Female - 55000
# Inserting product: 2B (DC604) Display port to HDMI – 1.8 M – Black - 39000
# Inserting product: 2B (GP026) 5in1 Racing wheel For PS3/PS4/PC/XBOX ONE/Switch - 5.50000
# Inserting product: 2B (GP076) Wireless Single Gamepad Turbo Dual Vibration 3 in one (PC- PS3) – Black Shell - 1.30000
# Inserting product: 2B (MO887) Wireless Presenter with OFN Brilliant red leaser pointer – Black - 1.50000
# Inserting product: 2B GP193 Wireless Single Gamepad PC & PlayStation 4 – Black Shell - 1.60000
# Inserting product: 2B US318 USB 3.0 HUB 4 Ports + 4 Switches - 49000
# Inserting product: Acer ED322Q Pbmiipx 32 Inch FHD 165Hz 1Ms VRB VA Curved Gaming Monitor - 9.00000
# Inserting product: ADATA Premier 16GB (1x16GB) DDR5 4800MHz LAPTOP RAM - 2.90000
# Inserting product: AMD Ryzen 5 8600G 6-Core, 24-Thread Desktop Processor - 11.00000
# Inserting product: AMD Ryzen™ 3 4300G BOX - 5.00000
# Inserting product: AMD Ryzen™ 5 4500 Desktop Processors - 5.00000
# Inserting product: AMD Ryzen™ 5 5500 Desktop Processors - 5.50000
# Inserting product: AMD Ryzen™ 5 5600G MPK - 7.00000
# Inserting product: AMD Ryzen™ 5 8400F Desktop Processor - 9.50000
# Inserting product: AMD Ryzen™ 7 9700X 8-Core, 16-Thread Unlocked Desktop Processor - 20.00000
# Inserting product: Antec  Cooling Air A30 Neo - 1.00000
# Inserting product: Antec A400i Neon RGB CPU Cooler - 1.50000
# Inserting product: ANTEC AX90 4FAN ARGB + PSU ANTEC ATOM G750 80+ GOLD - 6.30000
# Inserting product: Antec Case C5 7 Fan ARGB - 6.40000
# Inserting product: Antec Case C8 ARGB 3FAN (2×160MM+1×140MM) - 8.40000
# Inserting product: Antec Case C8 WHITE ARGB 3FAN (2×160MM+1×140MM) - 8.40000
# Inserting product: Antec Case NX416 ARGB - 4.50000
# Inserting product: Antec Case NX416 ARGB White - 4.20000
# Inserting product: ANTEC CONNECT 3FAN*120 REVERSE ARGB - 1.29900
# Inserting product: Antec Connect C120 ARGB 120mm 4-pin PWM | LED: 3-pin Vibration Absorbing and Anti-Noise Pads Easy Assemble 3pack Case Fans - 1.29900
# Inserting product: ANTEC CX300 AB75 4FAN ARGB +ATOM B750 BRONZE - 5.40000
# Inserting product: ANTEC CX300 AV65 4FAN ARGB +ATOM 80+ V650EC PSU - 4.30000
# Inserting product: Antec Flux Wood Mesh, 5 x PWM Fans Included, High-Airflow Front Panel with Walnut Wood, Type-C, 420mm Radiator & Back Connect Motherboard Support - 5.29900
# Inserting product: Antec FrigusAir 400 ARGB CPU Air Cooler - 1.85000
# Inserting product: ANTEC I SHAPE PRISM GPU HOLDER - 29900
# Inserting product: ANTEC NeoECO NE1000G M ATX3.0 1000W Full Modular PCIE 5.0 80+ Gold Certified - 10.00000
# Inserting product: ANTEC NeoECO NE1300G M ATX3.0 1300W Full Modular PCIE 5.0 80+ Gold Certified - 10.50000
# Inserting product: Antec P101 Silent Performance Series Mid-Tower PC Computer Case with Sound Dampening Panels, 4 X 120/140mm Cooling Fans Pre-Installed - 6.00000
# Inserting product: Antec P20C Black Massive Metal Mesh Front Panel 3 x 120mm FANS - 5.50000
# Inserting product: Antec P20C White Massive Metal Mesh Front Panel 3 x 120mm FANS - 4.60000
# Inserting product: Antec Performance 1 FT 4-FAN Full Tower E-ATX Gaming Case - 9.50000
# Inserting product: Antec Performance 1 FT Case 4 Fan Full Tower White - 8.30000
# Inserting product: Antec Symphony 240MM ARGB Newly Designed All-in-One Liquid Cooler Liquid CPU cooler - 5.50000
# Inserting product: ANTEC SYMPHONY 360MM ARGB Newly Designed All-in-One Liquid Cooler - 5.30000
# Inserting product: Antec Vortex 240MM ARGB CPU Liquid Cooler - 4.50000
# Inserting product: Antec Vortex 360 All-In-One ARGB CPU Liquid Cooler - 5.49900
# Inserting product: AOC 24G4E 23.8-Inch Fast IPS Gaming Monitor, 1920 × 1080 (FHD), 180Hz, 0.5ms, HDR10, Adaptive Sync, Engineered for Peak Gaming Performance - 8.00000
# Inserting product: AOC 27G4E Gaming Monitor 27-Inch (IPS Panel) , 1920 x 1080 (FHD), 180Hz Refresh Rate, 0.5ms Response Time, Adaptive Sync, HDMI 2.0 x 1, DisplayPort 1.4 × 1 - 9.50000
# Inserting product: AOC AGON PRO AG276QZD 27″ OLED Tournament Gaming Monitor 2560×1440 – 240Hz – 0.03MS – G-SYNC Compatible - 45.00000
# Inserting product: AOC C27G2Z2 27″ 250HZ 0.5MS CURVED VA PANEL FHD HDMI 2.0 - 12.00000
# Inserting product: AOC C27G4ZE 27″ 280Hz Curved Ultra-Fast Gaming Monitor 1920×1080 (FHD) – 0.3ms – Fast VA, 1500R – Adaptive Sync – Three-sided frameless design - 11.30000
# Inserting product: AOC Q27G4 – 2560 × 1440 (QHD) – IPS – 180HZ – 127%- SRGB, DCI P3 99% – HDR 400A - 14.00000
# Inserting product: AOC Q27G4F 27″ Frameless Ultra-Fast IPS Gaming Monitor – QHD 2560 X 1440 – 180Hz – 0.5ms – MBR Sync - 13.25000
# Inserting product: AOC U27U3CV – Graphic Pro Series – LED monitor – 4K – 27″ – HDR - 28.00000
# Inserting product: ASUS PRIME A620M-K  AMD A620  DDR5 – PCIe 4.0 – Graphics card and PCIe 4.0 M.2 support - 7.20000
# Inserting product: ASUS PRIME B450M-A II - 6.20000
# Inserting product: ASUS ROG Strix XG27ACS USB Type-C Gaming Monitor – 27-inch 2560×1440 – 180Hz – 1ms (GTG) – Fast IPS – Extreme Low Motion Blur Sync – USB Type-C – G-Sync compatible – DisplayWidget Center – tripod socket – HDR - 18.50000
# Inserting product: ASUS TUF GAMING B650M-PLUS AM5 DDR5 - 14.50000
# Inserting product: ASUS TUF Gaming VG27AQ3A Gaming Monitor – 27-inch, QHD(2560×1440), 180Hz, Fast IPS, ELMB Sync, 1ms (GTG), Freesync Premium™, G-Sync compatible, Variable Overdrive, 130% sRGB - 14.50000
# Inserting product: ASUS TUF Gaming VG27AQML1A Gaming Monitor – 27-inch, QHD(2560×1440) – Overclock to 260Hz (native 240Hz) – ELMB Sync – Freesync Premium™ – 1ms (GTG), Variable Overdrive -100% sRGB, DisplayHDR™ 400 - 25.00000
# Inserting product: ASUS VA27EHF Eye Care Gaming Monitor – 27-inch, IPS, Full HD, Frameless, 100Hz, Adaptive-Sync, 1ms MPRT, HDMI, Low Blue Light, Flicker Free, Wall Mountable - 6.80000
# Inserting product: ASUS VZ24EHF Eye Care Gaming Monitor – 24-inch (23.8-inch viewable), IPS -Full HD – Frameless – 100Hz –  Adaptive-Sync – 1ms MPRT – HDMI – Low Blue Light – Flicker Free – Wall Mountable - 6.00000
# Inserting product: Case Technozone C-500 With 3RGB FAN+ PSU 600W 80PLUS - 3.90000
# Inserting product: COOLER MASTER CMP 520 + Power ELITE NEX N600 600W  3FANS ARGB - 5.00000
# Inserting product: COOLER MASTER ELITE 301  3x 120mm ARGB fans + ELITE NEX PN700 700W PSU – USB Type-C Support - 4.50000
# Inserting product: Cooler Master Elite 301 3FAN ARGB +  ELITE NEX PN600W PSU - 4.50000
# Inserting product: COOLER MASTER G GOLD 750W V2 ATX 3.1 - 6.10000
# Inserting product: COOLER MASTER HYBER 212 SPECTRUM V3 - 2.00000
# Inserting product: COOLER MASTER HYPER 622 HALO BLACK ARGB  WHITE - 4.00000
# Inserting product: COOLER MASTER MASTERBOX TD500 MESH V2 -3FAN ARGB FANS INCLUDED USB 3.2 GEN 2 Type C Support - 5.00000
# Inserting product: Cooler Master MasterGel Regular High Performance Thermal GREASE - 35000
# Inserting product: COOLER MASTER PSU MWE 750W +80 PLUS BRONZE V3 230V ATX 3.1 - 4.00000
# Inserting product: COUGAR POWER SUPPLY VTE X2 ARGB – 650W +80 BRONZE - 2.35000
# Inserting product: Crucial 16GB DDR4-3200 NOTEBOOK - 2.20000
# Inserting product: Crucial 16GB DDR4-3200 UDIMM - 2.00000
# Inserting product: Crucial 16GB DDR5 4800 MHz UDIMM Memory Module (1 x 16GB) - 2.29900
# Inserting product: Crucial BX500 1TB 3D NAND SATA 2.5-Inch Internal SSD - 4.00000
# Inserting product: Crucial BX500 240GB 3D NAND SATA 2.5-Inch Internal SSD, up to 540MB/s - 1.30000
# Inserting product: Crucial BX500 2TB 3D NAND SATA 2.5 Inch - 7.50000
# Inserting product: Crucial BX500 500GB 2.5-inch SATA 3D NAND Internal SSD - 1.80000
# Inserting product: Crucial P3 1TB M.2 PCIe Gen3 NVMe Internal SSD – Up to 3500MB/s Sequential Read & 3000 MB/s Sequential Write – CT1000P3SSD8 - 3.50000
# Inserting product: Crucial P3 500GB PCIe 3.0 3D NAND NVMe M.2 SSD, up to 3500MB/s Sequential Read & 1900 MB/s Sequential Write – CT500P3SSD8 - 2.00000
# Inserting product: DAHUA 128GB C800AS128G 2.5 SATAIII  SSD DRIVE 550MB/S - 75000
# Inserting product: Dahua C800A 256GB 2.5 SATA III 6Gb s 3D TLC SSD DHI-SSD-C800AS256G - 85000
# Inserting product: Dahua SSD 256GB NVMe M.2 2280 PCIe Gen3x4 Solid State Drive R:2000 MB/s,W:1050 MB/s DHI-SSD-C900N256G - 1.00000
# Inserting product: Devia Watch Pro 5  1.36”inches With 2 Strap – Black - 2.90000
# Inserting product: E-train (DC891) HDMI to HDMI Round Cable 4K 1.5M Gold Plated – Gray - 15000
# Inserting product: E-train (GP054) – USB 2.0 Double Game pad – Colors - 58000
# Inserting product: FAN CASE LC -120 ARGB - 20000
# Inserting product: GAMDIAS AURA GL360 V2 ARGB Liquid CPU Cooler - 4.20000
# Inserting product: GAMDIAS BOREAS E2-410 CPU Air Cooler BLACK - 2.00000
# Inserting product: GAMDIAS BOREAS E2-410 CPU Air Cooler White - 2.10000
# Inserting product: GAMDIAS CHIONE M4-240 IPS LCD ARGB Liquid CPU Cooler - 4.00000
# Inserting product: GIGABYTE – M34WQ – 34 IPS Ultrawide Gaming Monitor – WQHD 3440×1440 – 144Hz – 1ms MPRT – AMD FreeSync Premium – Type C KVM – HDMI DP Type C – Height Adjustable - 22.19900
# Inserting product: Gigabyte A620M H Motherboard - 6.30000
# Inserting product: GIGABYTE AORUS C500 Glass – Black Mid Tower PC Gaming Case, Tempered Glass, USB Type-C, 4X ARBG Fans Included - 13.50000
# Inserting product: Gigabyte AORUS C700 Glass Full Size ATX Tempered Glass Gaming Computer Case, GB-AC700G - 30.00000
# Inserting product: GIGABYTE B450 AORUS ELITE V2 AM4 AMD B450 SATA 6GB/S ATX AMD MOTHERBOARD - 7.00000
# Inserting product: GIGABYTE B450M K Ultra Durable Motherboard with GbE LAN and Bandwidth Management - 4.00000
# Inserting product: GIGABYTE B550M DS3H AM4 AMD B550 MICRO-ATX MOTHERBOARD - 5.12000
# Inserting product: GIGABYTE B550M K MOTHERBOARD - 6.00000
# Inserting product: GIGABYTE B650 AORUS Elite AM5/AMD B650/DDR5/ PCIe 5.0/ USB 3.2 Gen2X2 Type-C - 12.50000
# Inserting product: Gigabyte Z790 D DDR5 ATX Motherboard - 10.00000
# Inserting product: GIGABYTE Z790 S DDR4 Motherboard - 10.00000
# Inserting product: GIGABYTE Z790 UD Intel LGA 1700 ATX Motherboard DDR5 - 11.29000
# Inserting product: Hiksemi Wave 128Gb Internal Soild State Drive - 72000
# Inserting product: HIKVISION E100 128GB SSD - 75000
# Inserting product: HikVision SSD E100 256GB Solid State Drive - 1.20000
# Inserting product: Intel Core i3-12100F 3.3 GHz Quad-Core LGA 1700 Processor - 3.49900
# Inserting product: Intel Core i3-14100F Desktop Processor - 5.90000
# Inserting product: Intel Core i5-14400 Desktop Processor - 10.49900
# Inserting product: Intel Core i5-14400F 2.5 GHz 10-Core LGA 1700 Processor, 10 Cores & 16 Threads, 20MB Cache, 5 GHz Maximum Turbo Boost - 7.69900
# Inserting product: Intel Core I7 13700KF Processor - 18.00000
# Inserting product: Intel Core i9-14900KF 14th Gen 24-Core (8P+16E) LGA 1700 - 30.00000
# Inserting product: INTEL LGA 1200 CPU COOLER - 49000
# Inserting product: Intel® Core™ i5-12400F Processor  6 Core 12 Thread Up To 4.4GHz LGA1700 - 6.50000
# Inserting product: Kingston A400 960 GB SSD Solid State Drive 2.5 Inch SATA 3 - 3.20000
# Inserting product: Kingston Fury Beast 8 GB 3200 MHz DDR4 CL16 Desktop Memory Single Stick - 1.20000
# Inserting product: Kingston NV2 1TB M.2 2280 NVMe Internal SSD PCIe 4.0 Gen 4×4 - 3.50000
# Inserting product: Kingston NV2 2TB NVMe PCIe 4.0 M.2 SSD - 6.50000
# Inserting product: Kingston NV2 500G M.2 2280 NVMe PCIe Internal SSD Up to 3500 MB/s - 2.00000
# Inserting product: KINGSTON NV3 PCIe 4.0 NVMe SSD 1TB UP TO 6000MB s  M.2 2280 3D NAND - 3.85000
# Inserting product: L’AVVENTO (DC136) – OTG Type-C Cable To USB Female – 20CM - 13000
# Inserting product: L’avvento (MO997) 2.4GHz Wireless Presenter - 1.50000
# Inserting product: L’AVVENTO (US518) Hub Type-C to 4 USB 3.0 Ports with Super Speed up to 5GB/S - 55500
# Inserting product: L’avvento CV567 5 in 1 Hub from USB/Type-C to 1* USB 3.0 2* USB 2.0, SD Card Reader Micro SD Card Reader - 45000
# Inserting product: Lexar NM620 1TB SSD, M.2 2280 PCIe Gen3x4 NVMe SSD, Up to 3500MB/s - 3.50000
# Inserting product: Lexar NM620 M.2 2280 NVMe SSD 512GB up to 3500MB/s Read, 2400MB/s Write - 2.00000
# Inserting product: Lexar RAM For Laptop 16GB DDR4 3200MHz - 1.90000
# Inserting product: Lexar Thor DDR4 RAM 16GB Kit (2x8GB) 3200MHz CL16 Desktop Memory, XMP 2.0 High Performance Computer Memory - 1.85000
# Inserting product: Logitech G29 Driving Force Racing Wheel - 17.00000
# Inserting product: Logitech Gamepad F310 USB - 1.40000
# Inserting product: LOGITECH R500s Bluetooth Presentation Remote - 2.00000
# Inserting product: Logitech Wireless Gamepad F710 - 2.20000
# Inserting product: MB GIGABYTE Z790 EAGLE AX DDR5 Wi-Fi 6E - 12.50000
# Inserting product: Meetion SP2011 2.0 Usb Wired Speaker - 39900
# Inserting product: MICROSOFT Windows 11 Pro OEM – Sticker licence - 38000
# Inserting product: MSI B450M-A PRO MAX II ProSeries - 4.00000
# Inserting product: MSI G272QPF RAPID IPS E2 27-inch 2560 x 1440 (QHD) Computer Monitor – 180Hz, Adaptive-Synch – HDMI, DisplayPort – VESA Mountable – Tilt – Height Adjustable – Speaker – 1ms - 14.50000
# Inserting product: MSI G321Q 2K IPS Gaming Monitor – 31.5 Inch, 16:9 WQHD (2560 x 1440), IPS, 1ms, 170 Hz, HDR, G-Sync Compatible, DisplayPort, HDMI, Anti-Flicker, Less Blue light, Night Vision - 22.50000
# Inserting product: MSI G32C4X, 32″ Gaming Monitor, 1920 x 1080 (FHD) Curved Gaming Monitor, 1 ms, 250Hz, FreeSync, 1500R, HDMI, DisplayPort, Tilt Adjustable, Black - 15.00000
# Inserting product: MSI LIQUID MAG CORELIQUID M360 ARGB - 6.10000
# Inserting product: MSI MAG 274QRF QD E2 27 Inch WQHD Gaming Monitor – 2560 x 1440 Rapid IPS Quantum Dot Panel, 180 Hz / 1ms, 120% sRGB Colour Gamut, DisplayHDR 400 – DP 1.4a, HDMI 2.0b, USB Type-C - 21.50000
# Inserting product: MSI MAG CORELIQUID C240 ARGB - 5.00000
# Inserting product: MSI MAG401QR 40″ 2K UWQHD (3440 x 1440) 155Hz Gaming Monitor - 30.00000
# Inserting product: MSI MPG274URF QD 27-inch 3840 x 2160 (UHD) Computer Monitor, 160Hz, Adaptive-Synch, HDMI, DisplayPort, VESA Mountable, Tilt, Height Adjustable - 30.00000
# Inserting product: MSI NVIDIA GeForce RTX™ 3050 VENTUS 2X XS 8G OC - 13.00000
# Inserting product: MSI PRO B550M-P GEN3 Motherboard AM4 DDR4 - 7.20000
# Inserting product: MSI PRO B760M-E – DDR5  – PCIe 4.0 x16 Slot –  M.2 Gen4 Slot - 7.00000
# Inserting product: MSI PRO B760M-E Motherboard LGA 1700 DDR4 - 5.49900
# Inserting product: MSI PRO MP273QP E2 27-inch IPS 2560 x 1440 (QHD) Computer Monitor, 100Hz, HDR400, Free-Sync, HDMI, DP Port, VESA Mountable, Height Adjustable, Tilt, Speaker, 1ms - 12.30000
# Inserting product: MSI SSD 240GB SSD 2.5″ SATA III R:500MB/s,W:400MB/s -SPATIUM S270 S78-440N070-P83 - 1.00000
# Inserting product: MSI SSD 480GB SSD 2.5″ SATA III R:500MB/s,W:450MB/s -SPATIUM S270 S78-440E350-P83 - 2.10000
# Inserting product: MSI SSD 960GB SSD 2.5″ SATA III R:500MB/s,W:450MB/s -SPATIUM S270 - 2.69900
# Inserting product: MSI X670E GAMING PLUS WIFI - 19.00000
# Inserting product: PATRIOT P300 256 GB Solid State Gaming Drive - 1.20000
# Inserting product: Patriot Viper Elite 5 Gaming RGB DDR5 WHITE RAM 32GB (2X16GB) 6600MT/s CL34  UDIMM Desktop Gaming Memory Kit - 6.90000
# Inserting product: Patriot Viper Elite 5 Gaming RGB DDR5 WHITE RAM 48GB (2X24GB) 6600MT/s CL34  UDIMM Desktop Gaming Memory Kit - 9.30000
# Inserting product: Patriot Viper Steel 16GB DDR4 3200 MHz CL16 - 2.00000
# Inserting product: Patriot Viper Steel DDR4 8GB 3200MHz CL16 - 1.45000
# Inserting product: Patriot Viper Steel RGB DDR4 RAM 16GB (1X16GB) 3200MHz CL18 - 1.80000
# Inserting product: Patriot Viper Steel RGB DDR4 RAM 32GB (2X16GB) 3200MHz CL16 UDIMM Desktop Gaming Memory Kit - 4.00000
# Inserting product: Patriot Viper Steel RGB DDR4 Ram 8GB  3200MHz CL18 - 1.60000
# Inserting product: Patriot Viper Venom RGB DDR5 32GB (2 x 16GB) 6400MHz CL32 - 8.50000
# Inserting product: Patriot Viper Xtreme 5 DDR5 NON RGB RAM 32GB (2X16GB)  8000MTCL38 RGB SILVER - 10.00000
# Inserting product: Philips 27E1N5800E 27 Inch – 4K UHD – IPS Monitor With HDMI 2.0 – DisplayPort – IPS 60Hz – 4 ms GTG – NTSC ‏106,4‏%*، sRGB:‏ 125,7‏% - 18.50000
# Inserting product: Philips Evnia 27M2N3200S GAMING MONITOR – Fast IPS – FHD – 180HZ – 1MS (GTG) - 8.90000
# Inserting product: Philips Evnia 27M2N5500-27 Inch QHD (2560 x 1440) Gaming Monitor, 180Hz, 0.5Ms, FreeSync Prem, G-Sync Comp, HDR400 (HDMI, DisplayPort) - 14.50000
# Inserting product: PNY GeForce RTX™ 4060 8GB Verto™ Dual Fan Graphics Card - 16.50000
# Inserting product: PNY RTX 4070 SUPER VERTO OC 12G GDDR6X DUAL FAN Graphic Card - 33.00000
# Inserting product: PNY Verto RTX 3050 6Gb GDDR6 Graphic Card - 10.00000
# Inserting product: Redragon G808 HARROW WIRELESS GAMEPAD – PC / PS3 – Plug and Play - 1.50000
# Inserting product: Redragon G815 PLUTO Wireless Gamepad Controller - 1.80000
# Inserting product: Redragon IRONHIDE GC-801 GAMING CASE - 6.50000
# Inserting product: Redragon Steeljaw GC-608 GAMING CASE - 5.00000
# Inserting product: Redragon Tailgate GC-702 GAMING CASE - 6.00000
# Inserting product: SAMSUNG LF27T350FHM 27-Inch 75hz FHD IPS Monitor - 6.10000
# Inserting product: SAMSUNG LS27CG552EMXEG 27INCH Odyssey G5  VA Curved 165Hz QHD 2K 1MS - 8.00000
# Inserting product: SAMSUNG LS32CG552EMXEG 32 Odyssey G5  VA Curved 165Hz QHD 2K  1MS - 9.60000
# Inserting product: Sapphire Pulse AMD Radeon RX 7600 8GB GDDR6 OC , AMD RDNA 3 - 15.49900
# Inserting product: Sapphire Pulse AMD Radeon RX 7700 XT Gaming Graphics Card with 12GB GDDR6, AMD RDNA 3 - 23.50000
# Inserting product: SAPPHIRE PULSE AMD RADEON™ RX 6650 XT GAMING OC 8GB GDDR6 - 15.00000
# Inserting product: SILVERSTONE Air Blazer 120i Lite 3X1 ARGB FANS KIT - 2.00000
# Inserting product: T-Dagger Soundbar Matrix RGB TGS550 Gaming Speaker - 69000
# Inserting product: TEAMGROUP SSD TEAM MP33-256GB M.2 NVMe - 1.10000
# Inserting product: TeamGroup Vulcan RAM 32GB (2x16GB) 6000MHz DDR5 - 5.59900
# Inserting product: Technozone RGB Case Fan-3000 - 1.60000
# Inserting product: Thermaltake Fan Cooling Pure 12 LED Blue - 45000
# Inserting product: Thermaltake Fan Cooling Pure 12 LED Red - 45000
# Inserting product: Western Digital Green 240GB SATA 2.5 Inch Internal SSD - 1.00000
# Inserting product: Xander X-2 2G Thermal Grease - 30000
# Inserting product: Xigmatek AIR-KILLER S Fan – Black - 1.40000
# Inserting product: Xigmatek AK4 Digital LED Display ARGB Air Cpu Cooler - 1.85000
# Inserting product: XIGMATEK AQUA III ARGB 7 FAN MID TOWER CASE - 4.00000
# Inserting product: Xigmatek Connect 240 Argb 3.4 Smart LCD Aio Liquid Cpu Cooler - 6.00000
# Inserting product: Xigmatek Connect 360 Argb 3.4 Smart LCD Aio Liquid Cpu Cooler - 6.70000
# Inserting product: Xigmatek Cubi II  Type C 7 Fan Argb BTF  Mid Tower Case - 5.10000
# Inserting product: XIGMATEK ELYSIUM II Super EATX,Left/Right/Top TG,16PCS 140mm Square Ring ARGB Fan, 2PCS Galaxy II Fan Control Box & Remote Kits - 20.00000
# Inserting product: XIGMATEK Endorphin Air V2 4 Argb FAN Mid Tower Case - 4.80000
# Inserting product: XIGMATEK Endorphin Air V2 ARCTIC 4 Argb FAN Mid Tower Case - 4.85000
# Inserting product: XIGMATEK Endorphin Ultra 5 Argb FAN Super Tower Case With Type-C Port - 5.60000
# Inserting product: Xigmatek Endorphin WD Arctic Argb Super Tower Case - 6.00000
# Inserting product: XIGMATEK Endorphin WD Argb Super Tower Case - 5.90000
# Inserting product: Xigmatek Frozr-O II 360 Arctic Argb Aio Liquid Cpu Cooler – Digital LCD Pump Head – ARGB Controller - 7.60000
# Inserting product: Xigmatek Frozr-O II 360 Argb Aio Liquid Cpu Cooler – Digital LCD Pump Head – ARGB Controller - 7.50000
# Inserting product: XIGMATEK FURY GD 850W 80+ GOLD FULL MODULAR POWER Supply - 5.50000
# Inserting product: XIGMATEK Gaming Y Pro ARGB LED Strip EATX Gaming Case - 3.30000
# Inserting product: XIGMATEK HERO II AIR 4F ARGB + 600W +80 WHITE - 3.25000
# Inserting product: XIGMATEK HERO II AIR 4F ARGB + 700W +80 WHITE - 3.50000
# Inserting product: Xigmatek I Cover II MB 24P Argb Psu Cable Cover Kit - 1.00000
# Inserting product: Xigmatek I Cover II Pci E 6+2P 4+4p Argb Psu Cable Cover Kit - 1.00000
# Inserting product: XIGMATEK iCABLE MB 24PIN EXTENSION CABLE-RED - 50000
# Inserting product: Xigmatek Infinity G20A Arctic Argb 3 Fans With Controller Fan - 1.35000
# Inserting product: Xigmatek Infinity G20A Argb 3 Fans With Controller Fan - 1.30000
# Inserting product: XIGMATEK LIQUID FENIX 360 ARGB ARCTIC - 4.35000
# Inserting product: XIGMATEK LIQUID FENIX 360 ARGB BLACK - 4.30000
# Inserting product: XIGMATEK Liquid Killer X 240 ARGB AIO - 3.45000
# Inserting product: XIGMATEK Liquid Killer X 360 ARGB AIO - 4.35000
# Inserting product: Xigmatek LK 240 Digital Argb Aio Digital Segment LCD Liquid Cpu Cooler - 3.50000
# Inserting product: Xigmatek LK 360 Digital Arctic Argb Digital Segment LCD Aio Liquid Cpu Cooler - 5.00000
# Inserting product: Xigmatek LK 360 Digital Argb Aio Digital Segment LCD Liquid Cpu Cooler - 4.90000
# Inserting product: Xigmatek Meta Arctic Type C 4 Fan Argb BTF Super Tower Case - 5.20000
# Inserting product: XIGMATEK Phantom 4-FAN Argb Mid Tower Case - 3.60000
# Inserting product: XIGMATEK SKY II 4F RAINBOW RGB + 600W +80 WHITE - 2.70000
# Inserting product: XIGMATEK Starlink Black (3PCS Black Easy Clip On & Smart Link Fan,2PCS ARGB & PWM Cable,Mini ARGB Controller,Color Box) - 1.40000
# Inserting product: XIGMATEK Starz Arctic 3 ARGB FAN + CONTROL BOX - 1.20000
# Inserting product: XIGMATEK Starz Pro 3 ARGB FAN + CONTROL BOX - 1.35000
# Inserting product: Xigmatek Thermal-Killer S Thermal Grease 3G - 25000
# Inserting product: XIGMATEK VISION FULL TOWER CASE ARGB 7 FAN - 7.50000
# Inserting product: XIGMATEK VISION PRO FULL TOWER CASE ARGB 8 FAN - 8.50000
# Inserting product: Xigmatek Windpower WP964 RGB - 1.10000
# Inserting product: XIGMATEK Zoser Arctic 4 Argb FAN Super Tower Case - 4.85000
# Inserting product: XIGMATEK Zoser Type C –  4 Argb FAN Super Tower Case - 3.90000
# Inserting product: XIGMATEK/MASTER X II SUPER TOWER 4F ARGB + 600W +80 WHITE - 3.60000
# Inserting product: ZOTAC GAMING GeForce RTX 3060 Twin Edge 12GB DDR6 - 16.00000
# Inserting product: ZOTAC GAMING GeForce RTX 4060 8GB Twin Edge GDDR6 - 17.50000
# Inserting product: ZOTAC GAMING GeForce RTX 4060 Ti 16GB Twin Edge - 25.50000
# Inserting product: تليفون أرضى لاسلكى PHILIPS d1601b/63 - 2.50000
# Inserting product: “|Intel Core i5-14600K 14 cores (6 P-cores & 8 E-cores), Integrated Graphics – Unlocked - 13.50000
# Inserting product: AMD Ryzen 5 8600G 6-Core, 24-Thread Desktop Processor - 11.00000
# Inserting product: AMD Ryzen™ 3 4300G BOX - 5.00000
# Inserting product: AMD Ryzen™ 5 4500 Desktop Processors - 5.00000
# Inserting product: AMD Ryzen™ 5 5500 Desktop Processors - 5.50000
# Inserting product: AMD Ryzen™ 5 5600G MPK - 7.00000
# Inserting product: AMD Ryzen™ 5 8400F Desktop Processor - 9.50000
# Inserting product: AMD Ryzen™ 7 9700X 8-Core, 16-Thread Unlocked Desktop Processor - 20.00000
# Inserting product: Intel Core i3-12100F 3.3 GHz Quad-Core LGA 1700 Processor - 3.49900
# Inserting product: Intel Core i3-14100F Desktop Processor - 5.90000
# Inserting product: Intel Core i5-14400 Desktop Processor - 10.49900
# Inserting product: Intel Core i5-14400F 2.5 GHz 10-Core LGA 1700 Processor, 10 Cores & 16 Threads, 20MB Cache, 5 GHz Maximum Turbo Boost - 7.69900
# Inserting product: Intel Core I7 13700KF Processor - 18.00000
# Inserting product: Intel Core i9-14900KF 14th Gen 24-Core (8P+16E) LGA 1700 - 30.00000
# Inserting product: Intel® Core™ i5-12400F Processor  6 Core 12 Thread Up To 4.4GHz LGA1700 - 6.50000
# Inserting product: ASUS PRIME A620M-K  AMD A620  DDR5 – PCIe 4.0 – Graphics card and PCIe 4.0 M.2 support - 7.20000
# Inserting product: ASUS PRIME B450M-A II - 6.20000
# Inserting product: ASUS TUF GAMING B650M-PLUS AM5 DDR5 - 14.50000
# Inserting product: Gigabyte A620M H Motherboard - 6.30000
# Inserting product: GIGABYTE B450 AORUS ELITE V2 AM4 AMD B450 SATA 6GB/S ATX AMD MOTHERBOARD - 7.00000
# Inserting product: GIGABYTE B450M K Ultra Durable Motherboard with GbE LAN and Bandwidth Management - 4.00000
# Inserting product: GIGABYTE B550M DS3H AM4 AMD B550 MICRO-ATX MOTHERBOARD - 5.12000
# Inserting product: GIGABYTE B550M K MOTHERBOARD - 6.00000
# Inserting product: GIGABYTE B650 AORUS Elite AM5/AMD B650/DDR5/ PCIe 5.0/ USB 3.2 Gen2X2 Type-C - 12.50000
# Inserting product: Gigabyte Z790 D DDR5 ATX Motherboard - 10.00000
# Inserting product: GIGABYTE Z790 S DDR4 Motherboard - 10.00000
# Inserting product: GIGABYTE Z790 UD Intel LGA 1700 ATX Motherboard DDR5 - 11.29000
# Inserting product: MB GIGABYTE Z790 EAGLE AX DDR5 Wi-Fi 6E - 12.50000
# Inserting product: MSI B450M-A PRO MAX II ProSeries - 4.00000
# Inserting product: MSI PRO B550M-P GEN3 Motherboard AM4 DDR4 - 7.20000
# Inserting product: MSI PRO B760M-E – DDR5  – PCIe 4.0 x16 Slot –  M.2 Gen4 Slot - 7.00000
# Inserting product: MSI PRO B760M-E Motherboard LGA 1700 DDR4 - 5.49900
# Inserting product: MSI X670E GAMING PLUS WIFI - 19.00000
# Inserting product: MSI NVIDIA GeForce RTX™ 3050 VENTUS 2X XS 8G OC - 13.00000
# Inserting product: PNY GeForce RTX™ 4060 8GB Verto™ Dual Fan Graphics Card - 16.50000
# Inserting product: PNY RTX 4070 SUPER VERTO OC 12G GDDR6X DUAL FAN Graphic Card - 33.00000
# Inserting product: PNY Verto RTX 3050 6Gb GDDR6 Graphic Card - 10.00000
# Inserting product: Sapphire Pulse AMD Radeon RX 7600 8GB GDDR6 OC , AMD RDNA 3 - 15.49900
# Inserting product: Sapphire Pulse AMD Radeon RX 7700 XT Gaming Graphics Card with 12GB GDDR6, AMD RDNA 3 - 23.50000
# Inserting product: SAPPHIRE PULSE AMD RADEON™ RX 6650 XT GAMING OC 8GB GDDR6 - 15.00000
# Inserting product: ZOTAC GAMING GeForce RTX 3060 Twin Edge 12GB DDR6 - 16.00000
# Inserting product: ZOTAC GAMING GeForce RTX 4060 8GB Twin Edge GDDR6 - 17.50000
# Inserting product: ZOTAC GAMING GeForce RTX 4060 Ti 16GB Twin Edge - 25.50000
# Inserting product: Crucial BX500 1TB 3D NAND SATA 2.5-Inch Internal SSD - 4.00000
# Inserting product: Crucial BX500 240GB 3D NAND SATA 2.5-Inch Internal SSD, up to 540MB/s - 1.30000
# Inserting product: Crucial BX500 2TB 3D NAND SATA 2.5 Inch - 7.50000
# Inserting product: Crucial BX500 500GB 2.5-inch SATA 3D NAND Internal SSD - 1.80000
# Inserting product: Crucial P3 1TB M.2 PCIe Gen3 NVMe Internal SSD – Up to 3500MB/s Sequential Read & 3000 MB/s Sequential Write – CT1000P3SSD8 - 3.50000
# Inserting product: Crucial P3 500GB PCIe 3.0 3D NAND NVMe M.2 SSD, up to 3500MB/s Sequential Read & 1900 MB/s Sequential Write – CT500P3SSD8 - 2.00000
# Inserting product: DAHUA 128GB C800AS128G 2.5 SATAIII  SSD DRIVE 550MB/S - 75000
# Inserting product: Dahua C800A 256GB 2.5 SATA III 6Gb s 3D TLC SSD DHI-SSD-C800AS256G - 85000
# Inserting product: Dahua SSD 256GB NVMe M.2 2280 PCIe Gen3x4 Solid State Drive R:2000 MB/s,W:1050 MB/s DHI-SSD-C900N256G - 1.00000
# Inserting product: Hiksemi Wave 128Gb Internal Soild State Drive - 72000
# Inserting product: HIKVISION E100 128GB SSD - 75000
# Inserting product: HikVision SSD E100 256GB Solid State Drive - 1.20000
# Inserting product: Kingston A400 960 GB SSD Solid State Drive 2.5 Inch SATA 3 - 3.20000
# Inserting product: Kingston NV2 1TB M.2 2280 NVMe Internal SSD PCIe 4.0 Gen 4×4 - 3.50000
# Inserting product: Kingston NV2 2TB NVMe PCIe 4.0 M.2 SSD - 6.50000
# Inserting product: Kingston NV2 500G M.2 2280 NVMe PCIe Internal SSD Up to 3500 MB/s - 2.00000
# Inserting product: KINGSTON NV3 PCIe 4.0 NVMe SSD 1TB UP TO 6000MB s  M.2 2280 3D NAND - 3.85000
# Inserting product: Lexar NM620 1TB SSD, M.2 2280 PCIe Gen3x4 NVMe SSD, Up to 3500MB/s - 3.50000
# Inserting product: Lexar NM620 M.2 2280 NVMe SSD 512GB up to 3500MB/s Read, 2400MB/s Write - 2.00000
# Inserting product: MSI SSD 240GB SSD 2.5″ SATA III R:500MB/s,W:400MB/s -SPATIUM S270 S78-440N070-P83 - 1.00000
# Inserting product: MSI SSD 480GB SSD 2.5″ SATA III R:500MB/s,W:450MB/s -SPATIUM S270 S78-440E350-P83 - 2.10000
# Inserting product: MSI SSD 960GB SSD 2.5″ SATA III R:500MB/s,W:450MB/s -SPATIUM S270 - 2.69900
# Inserting product: PATRIOT P300 256 GB Solid State Gaming Drive - 1.20000
# Inserting product: TEAMGROUP SSD TEAM MP33-256GB M.2 NVMe - 1.10000
# Inserting product: Western Digital Green 240GB SATA 2.5 Inch Internal SSD - 1.00000
# Inserting product: ADATA Premier 16GB (1x16GB) DDR5 4800MHz LAPTOP RAM - 2.90000
# Inserting product: Crucial 16GB DDR4-3200 NOTEBOOK - 2.20000
# Inserting product: Crucial 16GB DDR4-3200 UDIMM - 2.00000
# Inserting product: Crucial 16GB DDR5 4800 MHz UDIMM Memory Module (1 x 16GB) - 2.29900
# Inserting product: Kingston Fury Beast 8 GB 3200 MHz DDR4 CL16 Desktop Memory Single Stick - 1.20000
# Inserting product: Lexar RAM For Laptop 16GB DDR4 3200MHz - 1.90000
# Inserting product: Lexar Thor DDR4 RAM 16GB Kit (2x8GB) 3200MHz CL16 Desktop Memory, XMP 2.0 High Performance Computer Memory - 1.85000
# Inserting product: Patriot Viper Elite 5 Gaming RGB DDR5 WHITE RAM 32GB (2X16GB) 6600MT/s CL34  UDIMM Desktop Gaming Memory Kit - 6.90000
# Inserting product: Patriot Viper Elite 5 Gaming RGB DDR5 WHITE RAM 48GB (2X24GB) 6600MT/s CL34  UDIMM Desktop Gaming Memory Kit - 9.30000
# Inserting product: Patriot Viper Steel 16GB DDR4 3200 MHz CL16 - 2.00000
# Inserting product: Patriot Viper Steel DDR4 8GB 3200MHz CL16 - 1.45000
# Inserting product: Patriot Viper Steel RGB DDR4 RAM 16GB (1X16GB) 3200MHz CL18 - 1.80000
# Inserting product: Patriot Viper Steel RGB DDR4 RAM 32GB (2X16GB) 3200MHz CL16 UDIMM Desktop Gaming Memory Kit - 4.00000
# Inserting product: Patriot Viper Steel RGB DDR4 Ram 8GB  3200MHz CL18 - 1.60000
# Inserting product: Patriot Viper Venom RGB DDR5 32GB (2 x 16GB) 6400MHz CL32 - 8.50000
# Inserting product: Patriot Viper Xtreme 5 DDR5 NON RGB RAM 32GB (2X16GB)  8000MTCL38 RGB SILVER - 10.00000
# Inserting product: TeamGroup Vulcan RAM 32GB (2x16GB) 6000MHz DDR5 - 5.59900
# Inserting product: ANTEC AX90 4FAN ARGB + PSU ANTEC ATOM G750 80+ GOLD - 6.30000
# Inserting product: Antec Case C5 7 Fan ARGB - 6.40000
# Inserting product: Antec Case C8 ARGB 3FAN (2×160MM+1×140MM) - 8.40000
# Inserting product: Antec Case C8 WHITE ARGB 3FAN (2×160MM+1×140MM) - 8.40000
# Inserting product: Antec Case NX416 ARGB - 4.50000
# Inserting product: Antec Case NX416 ARGB White - 4.20000
# Inserting product: ANTEC CX300 AB75 4FAN ARGB +ATOM B750 BRONZE - 5.40000
# Inserting product: ANTEC CX300 AV65 4FAN ARGB +ATOM 80+ V650EC PSU - 4.30000
# Inserting product: Antec Flux Wood Mesh, 5 x PWM Fans Included, High-Airflow Front Panel with Walnut Wood, Type-C, 420mm Radiator & Back Connect Motherboard Support - 5.29900
# Inserting product: Antec P101 Silent Performance Series Mid-Tower PC Computer Case with Sound Dampening Panels, 4 X 120/140mm Cooling Fans Pre-Installed - 6.00000
# Inserting product: Antec P20C Black Massive Metal Mesh Front Panel 3 x 120mm FANS - 5.50000
# Inserting product: Antec P20C White Massive Metal Mesh Front Panel 3 x 120mm FANS - 4.60000
# Inserting product: Antec Performance 1 FT 4-FAN Full Tower E-ATX Gaming Case - 9.50000
# Inserting product: Antec Performance 1 FT Case 4 Fan Full Tower White - 8.30000
# Inserting product: Case Technozone C-500 With 3RGB FAN+ PSU 600W 80PLUS - 3.90000
# Inserting product: COOLER MASTER CMP 520 + Power ELITE NEX N600 600W  3FANS ARGB - 5.00000
# Inserting product: COOLER MASTER ELITE 301  3x 120mm ARGB fans + ELITE NEX PN700 700W PSU – USB Type-C Support - 4.50000
# Inserting product: Cooler Master Elite 301 3FAN ARGB +  ELITE NEX PN600W PSU - 4.50000
# Inserting product: COOLER MASTER MASTERBOX TD500 MESH V2 -3FAN ARGB FANS INCLUDED USB 3.2 GEN 2 Type C Support - 5.00000
# Inserting product: GIGABYTE AORUS C500 Glass – Black Mid Tower PC Gaming Case, Tempered Glass, USB Type-C, 4X ARBG Fans Included - 13.50000
# Inserting product: Gigabyte AORUS C700 Glass Full Size ATX Tempered Glass Gaming Computer Case, GB-AC700G - 30.00000
# Inserting product: Redragon IRONHIDE GC-801 GAMING CASE - 6.50000
# Inserting product: Redragon Steeljaw GC-608 GAMING CASE - 5.00000
# Inserting product: Redragon Tailgate GC-702 GAMING CASE - 6.00000
# Inserting product: XIGMATEK AQUA III ARGB 7 FAN MID TOWER CASE - 4.00000
# Inserting product: Xigmatek Cubi II  Type C 7 Fan Argb BTF  Mid Tower Case - 5.10000
# Inserting product: XIGMATEK ELYSIUM II Super EATX,Left/Right/Top TG,16PCS 140mm Square Ring ARGB Fan, 2PCS Galaxy II Fan Control Box & Remote Kits - 20.00000
# Inserting product: XIGMATEK Endorphin Air V2 4 Argb FAN Mid Tower Case - 4.80000
# Inserting product: XIGMATEK Endorphin Air V2 ARCTIC 4 Argb FAN Mid Tower Case - 4.85000
# Inserting product: XIGMATEK Endorphin Ultra 5 Argb FAN Super Tower Case With Type-C Port - 5.60000
# Inserting product: Xigmatek Endorphin WD Arctic Argb Super Tower Case - 6.00000
# Inserting product: XIGMATEK Endorphin WD Argb Super Tower Case - 5.90000
# Inserting product: XIGMATEK Gaming Y Pro ARGB LED Strip EATX Gaming Case - 3.30000
# Inserting product: XIGMATEK HERO II AIR 4F ARGB + 600W +80 WHITE - 3.25000
# Inserting product: XIGMATEK HERO II AIR 4F ARGB + 700W +80 WHITE - 3.50000
# Inserting product: Xigmatek Meta Arctic Type C 4 Fan Argb BTF Super Tower Case - 5.20000
# Inserting product: XIGMATEK Phantom 4-FAN Argb Mid Tower Case - 3.60000
# Inserting product: XIGMATEK SKY II 4F RAINBOW RGB + 600W +80 WHITE - 2.70000
# Inserting product: XIGMATEK VISION FULL TOWER CASE ARGB 7 FAN - 7.50000
# Inserting product: XIGMATEK VISION PRO FULL TOWER CASE ARGB 8 FAN - 8.50000
# Inserting product: XIGMATEK Zoser Arctic 4 Argb FAN Super Tower Case - 4.85000
# Inserting product: XIGMATEK Zoser Type C –  4 Argb FAN Super Tower Case - 3.90000
# Inserting product: XIGMATEK/MASTER X II SUPER TOWER 4F ARGB + 600W +80 WHITE - 3.60000
# Inserting product: ANTEC NeoECO NE1000G M ATX3.0 1000W Full Modular PCIE 5.0 80+ Gold Certified - 10.00000
# Inserting product: ANTEC NeoECO NE1300G M ATX3.0 1300W Full Modular PCIE 5.0 80+ Gold Certified - 10.50000
# Inserting product: COOLER MASTER G GOLD 750W V2 ATX 3.1 - 6.10000
# Inserting product: COOLER MASTER PSU MWE 750W +80 PLUS BRONZE V3 230V ATX 3.1 - 4.00000
# Inserting product: COUGAR POWER SUPPLY VTE X2 ARGB – 650W +80 BRONZE - 2.35000
# Inserting product: XIGMATEK FURY GD 850W 80+ GOLD FULL MODULAR POWER Supply - 5.50000
# Inserting product: Antec  Cooling Air A30 Neo - 1.00000
# Inserting product: Antec A400i Neon RGB CPU Cooler - 1.50000
# Inserting product: ANTEC CONNECT 3FAN*120 REVERSE ARGB - 1.29900
# Inserting product: Antec Connect C120 ARGB 120mm 4-pin PWM | LED: 3-pin Vibration Absorbing and Anti-Noise Pads Easy Assemble 3pack Case Fans - 1.29900
# Inserting product: Antec FrigusAir 400 ARGB CPU Air Cooler - 1.85000
# Inserting product: Antec Symphony 240MM ARGB Newly Designed All-in-One Liquid Cooler Liquid CPU cooler - 5.50000
# Inserting product: ANTEC SYMPHONY 360MM ARGB Newly Designed All-in-One Liquid Cooler - 5.30000
# Inserting product: Antec Vortex 240MM ARGB CPU Liquid Cooler - 4.50000
# Inserting product: Antec Vortex 360 All-In-One ARGB CPU Liquid Cooler - 5.49900
# Inserting product: COOLER MASTER HYBER 212 SPECTRUM V3 - 2.00000
# Inserting product: COOLER MASTER HYPER 622 HALO BLACK ARGB  WHITE - 4.00000
# Inserting product: Cooler Master MasterGel Regular High Performance Thermal GREASE - 35000
# Inserting product: FAN CASE LC -120 ARGB - 20000
# Inserting product: GAMDIAS AURA GL360 V2 ARGB Liquid CPU Cooler - 4.20000
# Inserting product: GAMDIAS BOREAS E2-410 CPU Air Cooler BLACK - 2.00000
# Inserting product: GAMDIAS BOREAS E2-410 CPU Air Cooler White - 2.10000
# Inserting product: GAMDIAS CHIONE M4-240 IPS LCD ARGB Liquid CPU Cooler - 4.00000
# Inserting product: INTEL LGA 1200 CPU COOLER - 49000
# Inserting product: MSI LIQUID MAG CORELIQUID M360 ARGB - 6.10000
# Inserting product: MSI MAG CORELIQUID C240 ARGB - 5.00000
# Inserting product: SILVERSTONE Air Blazer 120i Lite 3X1 ARGB FANS KIT - 2.00000
# Inserting product: Technozone RGB Case Fan-3000 - 1.60000
# Inserting product: Thermaltake Fan Cooling Pure 12 LED Blue - 45000
# Inserting product: Thermaltake Fan Cooling Pure 12 LED Red - 45000
# Inserting product: Xander X-2 2G Thermal Grease - 30000
# Inserting product: Xigmatek AIR-KILLER S Fan – Black - 1.40000
# Inserting product: Xigmatek AK4 Digital LED Display ARGB Air Cpu Cooler - 1.85000
# Inserting product: Xigmatek Connect 240 Argb 3.4 Smart LCD Aio Liquid Cpu Cooler - 6.00000
# Inserting product: Xigmatek Connect 360 Argb 3.4 Smart LCD Aio Liquid Cpu Cooler - 6.70000
# Inserting product: Xigmatek Frozr-O II 360 Arctic Argb Aio Liquid Cpu Cooler – Digital LCD Pump Head – ARGB Controller - 7.60000
# Inserting product: Xigmatek Frozr-O II 360 Argb Aio Liquid Cpu Cooler – Digital LCD Pump Head – ARGB Controller - 7.50000
# Inserting product: Xigmatek Infinity G20A Arctic Argb 3 Fans With Controller Fan - 1.35000
# Inserting product: Xigmatek Infinity G20A Argb 3 Fans With Controller Fan - 1.30000
# Inserting product: XIGMATEK LIQUID FENIX 360 ARGB ARCTIC - 4.35000
# Inserting product: XIGMATEK LIQUID FENIX 360 ARGB BLACK - 4.30000
# Inserting product: XIGMATEK Liquid Killer X 240 ARGB AIO - 3.45000
# Inserting product: XIGMATEK Liquid Killer X 360 ARGB AIO - 4.35000
# Inserting product: Xigmatek LK 240 Digital Argb Aio Digital Segment LCD Liquid Cpu Cooler - 3.50000
# Inserting product: Xigmatek LK 360 Digital Arctic Argb Digital Segment LCD Aio Liquid Cpu Cooler - 5.00000
# Inserting product: Xigmatek LK 360 Digital Argb Aio Digital Segment LCD Liquid Cpu Cooler - 4.90000
# Inserting product: XIGMATEK Starlink Black (3PCS Black Easy Clip On & Smart Link Fan,2PCS ARGB & PWM Cable,Mini ARGB Controller,Color Box) - 1.40000
# Inserting product: XIGMATEK Starz Arctic 3 ARGB FAN + CONTROL BOX - 1.20000
# Inserting product: XIGMATEK Starz Pro 3 ARGB FAN + CONTROL BOX - 1.35000
# Inserting product: Xigmatek Thermal-Killer S Thermal Grease 3G - 25000
# Inserting product: Xigmatek Windpower WP964 RGB - 1.10000
# Inserting product: Dell Optiplex 3000 Tower PC i3-12100 Ram 4GB DDR4 – 256GB SSD – Integrated Graphics -Intel® Graphics - 22.19900
# Inserting product: DELL OptiPlex 7000 Tower Desktop – 12th Intel Core i7-12700 12-Cores, 8GB DDR5 RAM, 1TB HDD - 47.49900
# Inserting product: Dell OptiPlex 7090 Tower PC – Intel Core i7-11700 – 1TB – 4GB RAM – Integrated Intel Graphics - 43.19900
# Inserting product: BUNDLE intel Core i9-14900KF + PNY GeForce RTX 4070 Super VERTO OC 12GB - 99.99900
# Inserting product: BUNDLE intel Core i9-14900KF + PNY GeForce RTX 4070 Super VERTO OC 12GB - 99.99900
# Inserting product: ” Meetion CP5050 Gaming Notebook Cooler” - 1.20000
# Inserting product: “AULA F3030 Mechanical Gaming Keyboard “ - 78000
# Inserting product: “L’AVVENTO (MO18A) Dual Mode Bluetooth – 2.4GHz Mouse with Re-Chargeable Battery  “ - 65000
# Inserting product: “Meetion CP3030 Gaming Notebook Cooler “ - 80000
# Inserting product: “Meetion GM21 2023 RGB BACKLIGHT GAMING MOUSE” - 48000
# Inserting product: “MOUSE LGC CMU02 WIRELESS “ - 24000
# Inserting product: “Redragon BM-2638 Wireless Mouse “ - 49000
# Inserting product: “Redragon Kumara K552-RGB-1 Mechanical Gaming Keyboard with Blue Switches “ - 1.97000
# Inserting product: 2B (CR003) – USB 2.0 – Card Reader All in one 480 Mbps - 34000
# Inserting product: 2B (KB306) Business Series Wireless Keyboard and Mouse Combo - 1.09900
# Inserting product: 2B (KB665) Business Wired Multimedia Keyboard 2M Shilded Cable – Black - 35000
# Inserting product: 2B GP193 Wireless Single Gamepad PC & PlayStation 4 – Black Shell - 1.60000
# Inserting product: AULA F3087 Mechanical Gaming Keyboard - 1.20000
# Inserting product: AULA S11 Gaming Mouse Honeycomb Design RGB Multi Light Precision Sensor 3600dpi - 28000
# ...
# Inserting product: Redragon GB-82 Travel Laptop Backpack, Business Workstation Computer Gaming Backpack w/ Durable Double-Layer Fabric Liner, USB Jack & Large Front Pocket, Fits Up to 18″ Laptop - 1.00000
# Inserting product: REDRAGON H112 GAMING HEADSET WITH MICROPHONE FOR PC, WIRED OVER EAR PC GAMING HEADPHONES ,WORKS WITH PC, LAPTOP, TABLET, PS4, XBOX ONE - 1.09900
# Inserting product: Redragon H280 MEDEA RGB - 1.50000
# Inserting product: Redragon K505 RGB LED Backlit Gaming Keyboard - 1.30000
# Inserting product: Redragon K506-1 GAMING KEYBOARD - 1.20000
# Inserting product: Redragon K509-RGB PC Gaming Keyboard 104 Key - 1.15000
# Inserting product: Redragon K552-2 KUMARA RED Backlight Gaming Mechanical Keyboard – METAL ABS CONSTRUCTION – Anti-Ghosting - 1.60000
# Inserting product: Redragon K552-R KUMARA Mechanical Gaming Keyboard 87 Key Rainbow LED Backlit Wired with Anti-Dust Proof Switches - 1.60000
# Inserting product: REDRAGON K607 APS TKL Low Profile Mechanical Gaming Keyboard – RGB Backlit – Blue Switches – Type C Detachable Cable - 1.90000
# Inserting product: Redragon KING OF WAR C601 GAMING CHAIR - 10.50000
# Inserting product: Redragon M692 Wireless Gaming Mouse - 1.00000
# Inserting product: Redragon M710 MEMEANLION CHROMA RGB Gaming Mouse - 99000
# Inserting product: Redragon M711 COBRA Gaming Mouse - 79900
# Inserting product: Redragon NOTHOSAUR M606 GAMING MOUSE - 59900
# Inserting product: Redragon Pelias H130 Wired Gaming Headset - 79000
# Inserting product: Redragon S101-5 Gaming Keyboard Mouse Combo K503RGB + M601(3212)RGB - 1.90000
# Inserting product: Redragon Spider queen C602 gaming chair - 10.00000
# Inserting product: T-DAGGER BORA T-TGK313 Rainbow TKL Gaming Mechanical Keyboard - 75000
# Inserting product: T-DAGGER T-TGM208 Gaming Mouse - 60000
# Inserting product: T-DAGGER T-TMP200 Mouse Pad – Size 360x300x3mm – High Speed Tracking Movements - 33000
# Inserting product: TechnoZone E 26 Gaming Mechanical Keyboard - 1.80000
# Inserting product: TechnoZone GMS-WT-5 RGB Gaming Mouse Pad 30×80 CM – Black - 35000
# Inserting product: TechnoZone K60 USB Wired Gaming Headset - 1.29900
# Inserting product: TechnoZone K63 Backlit LED Gaming Headset – Black - 1.59900
# Inserting product: TechnoZone Mouse pad RGB RGB Gaming 30 x 25 CM- Black - 20000
# Inserting product: TechnoZone S1 Head Phone Stand - 5000
# Inserting product: TechnoZone V 64 Gaming Mouse - 1.00000
# Inserting product: TechnoZone V 68 Gaming Mouse - 80000
# Inserting product: TechnoZone V 70 FPS Gaming Mouse - 1.00000
# Inserting product: TechnoZone V5 Wired Gaming Mouse - 73000
# Inserting product: Travel Plug Adapter – Converter - 6000
# Inserting product: شنطة/GALERIA BACK - 55000
# Inserting product: شنطة/GALERIA SLEEVE - 45000
# Inserting product: CAT 15.6-inch USB Business Travel Laptop Backpack – Blue - 1.60000
# Inserting product: E-train (BG11A)-(BG11B) Laptop Messenger Shoulder Bag up to 15.6″ – Grey – Black - 60000
# Inserting product: E-train (BG82L) Laptop Backpack with Zipper Puller fits up to 15.6″ – Blue*Gray - 50000
# Inserting product: E-train (BG91A) Laptop Backpack Fits up to 15.6″ – BLACK - 55000
# Inserting product: EgyBox Back1 - 60000
# Inserting product: Egybox Laptop Bag  mini - 30000
# Inserting product: Egybox Laptop Bag 15.6 Inch Model CO - 65000
# Inserting product: Egybox Laptop bag model am multicolor 15.6 Inch - 25000
# Inserting product: EGYBOX LELE - 50000
# Inserting product: EgyBox ND1 - 27000
# Inserting product: EGYBOX RO - 50000
# Inserting product: Etrain Laptop Backpack up to 15.6 – Black - 48000
# Inserting product: HP Commuter Laptop Backpack Bag 15.6″ 5EE94AA - 95000
# Inserting product: HP-15.6″-SMB-Backpack case with double safety – Black - 1.80000
# Inserting product: L’avvento (BG56L) Discovery Laptop Backpack fit up to 15.6” – Blue - 80000
# Inserting product: L’AVVENTO (BG696) Laptop Backpack fits up to 15.6″ - 75000
# Inserting product: L’AVVENTO (BG704) Laptop Shoulder Bag fits up to 15.6″ – Black - 1.50000
# Inserting product: L’AVVENTO (BG705) Laptop Shoulder Bag fits up to 15.6″ – Black - 1.55000
# Inserting product: L’avvento (BG73A-B) laptops Discovery Backpack Bag – 15.6 inch - 77000
# Inserting product: L’avvento (BG924) Laptop Backpack 15.6″, made of Polyester Gray * Blue - 80000
# Inserting product: L’avvento BG04 Discovery Laptop Anti-Theft Backpack Bag – Up to 15.6” - 90000
# Inserting product: L’AVVENTO BG56B Discovery Laptop Backpack fit up to 15.6” Laptops ,Padded Tablet and iPad Compartment – Black - 1.20000
# Inserting product: L’AVVENTO BG57B Laptop Backpack fits up to 15.6″ – Black - 83000
# Inserting product: L’AVVENTO BG728 Laptop Backpack, Made by High Quality Material with Zipper Puller fits up to 15.6″ with USB Power Socket - 69000
# Inserting product: L’AVVENTO BG74B Discovery Backpack fit with Laptops up to 15.6″, Material Nylon +PU, Black - 1.30000
# Inserting product: L’AVVENTO BG796 Laptop Backpack, Made by High Quality Material with Zipper Puller fits up to 15.6″ with USB Power Socket - 74000
# Inserting product: Meinaili 15.6 Inch Laptop Backpack Multifunctional Outdoor Backpack Schoolbag Waterproof – 2026 Black - 1.70000
# Inserting product: Rahala 2209 17-Inch THREE Compartment Laptop Travel Waterproof Business With USB Charging, Black - 1.30000
# Inserting product: Rahala 5306 laptop backpack bag 15.6-Inch – Black - 1.45000
# Inserting product: Rahala Laptop Backpack Bag 2300 -15.6″ – Black - 2.30000
# Inserting product: Redragon GB-76 Travel Laptop Backpack, Business Workstation Computer Gaming Backpack w/ Durable Double-Layer Fabric Liner, Modern Line Logo Print & Large Front Pocket, Fits Up to 18″ Laptop - 1.20000
# Inserting product: Redragon GB-82 Travel Laptop Backpack, Business Workstation Computer Gaming Backpack w/ Durable Double-Layer Fabric Liner, USB Jack & Large Front Pocket, Fits Up to 18″ Laptop - 1.00000
# Inserting product: Smile Lap Shirt - 20000
# Inserting product: أتش بى Pavilion شنطة ظهر للألعاب 15.6 بوصة – موديل 6EU57AA – أسود - 1.50000
# Inserting product: شنطة/GALERIA BACK - 55000
# Inserting product: شنطة/GALERIA SLEEVE - 45000
# Inserting product: HP H100 Wired Gaming Headset With Mic – Black - 60000
# Inserting product: Hp H160 Wired Over-Ear Headphone With Mic Black - 50000
# Inserting product: Lenovo Thinkplus G83B USB Gaming Headset - 75000
# Inserting product: Marvo scorpion hg8901 wired rgb gaming headset - 90000
# Inserting product: Meetion HP010 Stereo Wired Gaming Headset - 60000
# Inserting product: Meetion HP020 Stereo Wired Gaming Headset - 85000
# Inserting product: Meetion HP021 Stereo Wired Gaming Headset - 55000
# Inserting product: Meetion HP030 Backlit HIFI 7.1 Stereo Wired Gaming Headset - 1.00000
# Inserting product: Meetion HP099 RGB Backlit Stereo Wired Gaming Headset - 1.35000
# Inserting product: ONIKUMA K20 RGB Advanced 4D Gaming Headset – 7.1 Surround Sound – 50MM Driver – Noise Cancelling Mic with Mute & Volume Control – PS4, Xbox One, Switch, PC - 55000
# Inserting product: REDRAGON H112 GAMING HEADSET WITH MICROPHONE FOR PC, WIRED OVER EAR PC GAMING HEADPHONES ,WORKS WITH PC, LAPTOP, TABLET, PS4, XBOX ONE - 1.09900
# Inserting product: Redragon H280 MEDEA RGB - 1.50000
# Inserting product: Redragon Pelias H130 Wired Gaming Headset - 79000
# Inserting product: TechnoZone K60 USB Wired Gaming Headset - 1.29900
# Inserting product: TechnoZone K63 Backlit LED Gaming Headset – Black - 1.59900
# Inserting product: TechnoZone S1 Head Phone Stand - 5000
# Inserting product: ” Meetion CP5050 Gaming Notebook Cooler” - 1.20000
# Inserting product: “Meetion CP3030 Gaming Notebook Cooler “ - 80000
# Inserting product: Gamma GT-17 Laptop Cooling Fan, 2 Fan, Supports Up to 17 Inch Laptop, LED Light, Black - 45000
# Inserting product: MARVO FN-40 RGB Laptop Cooler Cooling Pad, Supports Up to 17 inch - 1.20000
# Inserting product: Marvo Laptop Cooling Stand FN-41 - 1.10000
# Inserting product: Meetion CP4040 Gaming Notebook Cooler - 1.00000
# Inserting product: Metal Stand for School Laptop and Tablet - 23000
# Inserting product: “AULA F3030 Mechanical Gaming Keyboard “ - 78000
# Inserting product: “Redragon Kumara K552-RGB-1 Mechanical Gaming Keyboard with Blue Switches “ - 1.97000
# Inserting product: 2B (KB306) Business Series Wireless Keyboard and Mouse Combo - 1.09900
# Inserting product: 2B (KB665) Business Wired Multimedia Keyboard 2M Shilded Cable – Black - 35000
# Inserting product: AULA F3087 Mechanical Gaming Keyboard - 1.20000
# Inserting product: E-train (KB012) MultiMedia Compact Keyboard 104-Key - 19900
# Inserting product: HP Wireless Keyboard & Mouse – Black - 1.59900
# Inserting product: Logitech K120 Wired Keyboard - 65000
# Inserting product: LOGITECH K400 Plus Wireless Touch Keyboard – BLACK - 1.90000
# Inserting product: Manhattan Wired Keyboard and Optical Mouse Set – (KB717) –  Black - 60000
# Inserting product: Manhattan Wireless Keyboard and Optical Mouse Set  – (KB717) – Black - 1.00000
# Inserting product: Meetion C100 Wired Keyboard And Mouse Combo - 39000
# Inserting product: Meetion C4130 Wireless Ergonomic Keyboard And Mouse Combo - 79900
# Inserting product: Meetion C490 (4 IN 1) Mouse+Arabic Keyboard+Headset+Mouse Pad Backlit Gaming Combo Kits - 1.50000
# Inserting product: Meetion CO015 (4 IN 1) keyboard+mouse+adapter+Mouse Pad Console Gaming Combo Kits - 1.50000
# Inserting product: Meetion K210 Wireless And Bluetooth Dual Mode Keyboard - 95000
# Inserting product: Meetion K300 Silent Wired Keyboard - 42500
# Inserting product: Meetion KB015 One Handed Wired Keyboard - 52500
# Inserting product: Meetion MK005 60% Blue switch Arabic Wired Mechanical Keyboard - 1.35000
# Inserting product: Meetion MK007PRO Blue switch Arabic Wired Mechanical Keyboard - 2.20000
# Inserting product: Meetion MK009 PRO Hotswap Red switch Mechanical Keyboard - 1.39900
# Inserting product: Meetion MK04TKL RGB Backlit Blue switch Arabic Wired Mechanical Keyboard - 1.40000
# Inserting product: Meetion MK600MX Blue switch Arabic Wired Mechanical Keyboard - 1.20000
# Inserting product: Meetion MT-K100 USB Standard Wired Keyboard - 25000
# Inserting product: Redragon K505 RGB LED Backlit Gaming Keyboard - 1.30000
# Inserting product: Redragon K506-1 GAMING KEYBOARD - 1.20000
# Inserting product: Redragon K509-RGB PC Gaming Keyboard 104 Key - 1.15000
# Inserting product: Redragon K552-2 KUMARA RED Backlight Gaming Mechanical Keyboard – METAL ABS CONSTRUCTION – Anti-Ghosting - 1.60000
# Inserting product: Redragon K552-R KUMARA Mechanical Gaming Keyboard 87 Key Rainbow LED Backlit Wired with Anti-Dust Proof Switches - 1.60000
# Inserting product: REDRAGON K607 APS TKL Low Profile Mechanical Gaming Keyboard – RGB Backlit – Blue Switches – Type C Detachable Cable - 1.90000
# Inserting product: Redragon S101-5 Gaming Keyboard Mouse Combo K503RGB + M601(3212)RGB - 1.90000
# Inserting product: T-DAGGER BORA T-TGK313 Rainbow TKL Gaming Mechanical Keyboard - 75000
# Inserting product: TechnoZone E 26 Gaming Mechanical Keyboard - 1.80000
# Inserting product: “L’AVVENTO (MO18A) Dual Mode Bluetooth – 2.4GHz Mouse with Re-Chargeable Battery  “ - 65000
# Inserting product: “Meetion GM21 2023 RGB BACKLIGHT GAMING MOUSE” - 48000
# Inserting product: “MOUSE LGC CMU02 WIRELESS “ - 24000
# Inserting product: “Redragon BM-2638 Wireless Mouse “ - 49000
# Inserting product: 2B (KB306) Business Series Wireless Keyboard and Mouse Combo - 1.09900
# Inserting product: AULA S11 Gaming Mouse Honeycomb Design RGB Multi Light Precision Sensor 3600dpi - 28000
# Inserting product: Aula S31 USB Wired Gaming Mouse Black - 23000
# Inserting product: E-train (MO10A) Wireless Optical Mouse 1200DPI - 37000
# Inserting product: HP MO 096 HP 100 BLACK - 75000
# Inserting product: HP MO 171 HP 150 MOUSE - 70000
# Inserting product: HP Mouse Z3700 Wireless – V0L79AA – Black - 1.20000
# Inserting product: HP Wireless Mouse 220 – Snow White - 90000
# Inserting product: L’AVVENTO (MO34B) 2.4GHz Wireless Mouse – Black - 62000
# Inserting product: Lenovo 120 Wired Mouse, Black (MS-370OU) - 34000
# Inserting product: lenovo 150 WIRLESS MOUSE , MS -3700R - 54000
# Inserting product: Logitech G102 Light Sync Gaming Mouse with Customizable RGB Lighting, 6 Programmable Buttons Light Weight - 1.35000
# Inserting product: Logitech M190 Full-Size Wireless Mouse 2.4Ghz - 95000
# Inserting product: Logitech M240 Silent Wireless Mouse - 1.20000
# Inserting product: Logitech M275 Wireless Mous - 1.02000
# Inserting product: Logitech Wireless Mouse M185 - 90000
# Inserting product: MANhattan MO 707 Comfort II - 25000
# Inserting product: Manhattan MO707 Comfort II Wired Optical Mouse 1000 DPI Ambidextrous 1.2 m Cable – Black - 30000
# Inserting product: Manhattan Performance III Wireless Optical USB Mouse 1000 DPI - 35000
# Inserting product: Manhattan Wired Optical Mouse USB – 179331 – Black - 28000
# Inserting product: Manhattan Wireless Mouse, 2.4 GHz, 1600 dpi, Black, MO747 - 75000
# Inserting product: Marvo Gaming Mouse G924 High-precision 10,000 DPI Optical Ambidextrous Ergonomic Design with 6 Different Lighting Modes – Black - 86000
# Inserting product: Marvo Gaming Mouse M519 With RGB Lighting 12000 DPI Optical Sensor With 7 Lighting Modes Up to1000Hz – Black - 65000
# Inserting product: MARVO M513 RGB Gaming Mouse – Black - 60000
# Inserting product: Marvo Scorpion M112S Wired Rainbow Gaming Mouse 4000Dpi - 35000
# Inserting product: MARVO Scorpion M115 Gaming Mouse - 50000
# Inserting product: Meetion GM20 Chromatic Wired Gaming Mouse - 55000
# Inserting product: Meetion GM22 Dazzling Wired Gaming Mouse - 60000
# Inserting product: Meetion GM23 2023 RGB Circulation Backlit White Wired Gaming Mouse - 75000
# Inserting product: Meetion M390 Ergonomic Vertical Wired Mouse - 60000
# Inserting product: Meetion R390 Ergonomic Wireless Vertical Rechargeable Mouse - 69900
# Inserting product: Meetion R545 Wireless Mouse - 22500
# Inserting product: Microsoft Wireless Mobile Mouse 1850 – Black (U7Z-00001) - 1.20000
# Inserting product: Redragon M692 Wireless Gaming Mouse - 1.00000
# Inserting product: Redragon M710 MEMEANLION CHROMA RGB Gaming Mouse - 99000
# Inserting product: Redragon M711 COBRA Gaming Mouse - 79900
# Inserting product: Redragon NOTHOSAUR M606 GAMING MOUSE - 59900
# Inserting product: T-DAGGER T-TGM208 Gaming Mouse - 60000
# Inserting product: TechnoZone V 64 Gaming Mouse - 1.00000
# Inserting product: TechnoZone V 68 Gaming Mouse - 80000
# Inserting product: TechnoZone V 70 FPS Gaming Mouse - 1.00000
# Inserting product: TechnoZone V5 Wired Gaming Mouse - 73000
# Inserting product: Havit HV-MP861 Mousepad With Premium Fine-Mesh & Anti-Slip Rubber Base,700*300*3Mm, Black - 31500
# Inserting product: Meetion  P100 Non slip Rubber Gaming Mouse Pad - 50000
# Inserting product: Meetion P010 RGB Backlit Gaming Mouse Pad - 29900
# Inserting product: Meetion P110 Non slip Rubber Square Gaming Mouse Pad - 30000
# Inserting product: Meetion PD005 Gaming Mouse Pad - 7000
# Inserting product: Meetion PD015 Soft Rubber Gaming Mouse Pad - 10000
# Inserting product: Meetion PD121 Large RGB Gaming Mouse Pad - 65000
# Inserting product: MOUSE PAD 30×70 - 30000
# Inserting product: T-DAGGER T-TMP200 Mouse Pad – Size 360x300x3mm – High Speed Tracking Movements - 33000
# Inserting product: TechnoZone GMS-WT-5 RGB Gaming Mouse Pad 30×80 CM – Black - 35000
# Inserting product: TechnoZone Mouse pad RGB RGB Gaming 30 x 25 CM- Black - 20000
# Inserting product: E-train (PS077) Power Strip 16A with Overload Protection 4 Output Plugs + 1 USB + 1 Type-C 2.4A Charging Ports 2M – On-Off Switch - 68000
# Inserting product: E-Train Power Strip 3 Port  PS073 1.5M - 45000
# Inserting product: I LOOK Power Strip 9 outlets with Switch - 55000
# Inserting product: iLOCK 3 Port Wall Joint 3500w – Black - 6000
# Inserting product: iLOCK power strip 3 universal outlets without earthing – (Basic) (black) - 36000
# Inserting product: Power Strip 3 Universal Outlets with 16A Switch - 60000
# Inserting product: Power Strip Systemmax 4Port/2USB – SMPG-4P2U 2.1A - 45000
# Inserting product: Travel Plug Adapter – Converter - 6000

# %%
# %pip install psycopg2
# %pip install requests
# %pip install beautifulsoup4
# Out:
# Collecting psycopg2Note: you may need to restart the kernel to use updated packages.
#
#   Downloading psycopg2-2.9.10-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Downloading psycopg2-2.9.10-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.2 MB 326.8 kB/s eta 0:00:04
#    --- ------------------------------------ 0.1/1.2 MB 585.1 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.2 MB 821.4 kB/s eta 0:00:02
#    ------- -------------------------------- 0.2/1.2 MB 919.0 kB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.2 MB 983.0 kB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.2 MB 1.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.4/1.2 MB 1.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.2 MB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.2 MB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 0.9/1.2 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.0/1.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 1.1/1.2 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
#    ---------------------------------------- 0.0/164.9 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/164.9 kB 960.0 kB/s eta 0:00:01
#    ----------------------- -------------- 102.4/164.9 kB 980.4 kB/s eta 0:00:01
#    ----------------------------- ---------- 122.9/164.9 kB 1.0 MB/s eta 0:00:01
#    -------------------------------------  163.8/164.9 kB 893.0 kB/s eta 0:00:01
#    -------------------------------------- 164.9/164.9 kB 822.8 kB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    --------------- ----------------------- 41.0/102.4 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 102.4/102.4 kB 1.2 MB/s eta 0:00:00
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.4 kB ? eta -:--:--
#    ------------------- -------------------- 61.4/128.4 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 122.9/128.4 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 128.4/128.4 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.12.14 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 urllib3-2.3.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Mohamed\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/147.9 kB 435.7 kB/s eta 0:00:01
#    ------------------ -------------------- 71.7/147.9 kB 563.7 kB/s eta 0:00:01
#    ------------------------------------ - 143.4/147.9 kB 853.3 kB/s eta 0:00:01
#    -------------------------------------- 147.9/147.9 kB 882.6 kB/s eta 0:00:00
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3 soupsieve-2.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
